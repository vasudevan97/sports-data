# %%
import requests
import pandas as pd

url = "https://api.sportradar.com/tennis/trial/v3/en/competitions.json?api_key=gCNmEyNAwK1dQ2CMzKHz8bzSBjT7uNx77cdZNAEn"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)
data=response.json()

# %%
data
# Out:
# {'generated_at': '2025-02-05T10:23:26+00:00',
#  'competitions': [{'id': 'sr:competition:620',
#    'name': 'Hopman Cup',
#    'type': 'mixed',
#    'gender': 'mixed',
#    'category': {'id': 'sr:category:181', 'name': 'Hopman Cup'}},
#   {'id': 'sr:competition:660',
#    'name': 'World Team Cup',
#    'type': 'mixed',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:990',
#    'name': 'ATP Challenger Tour Finals',
#    'parent_id': 'sr:competition:6239',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:1207',
#    'name': 'Championship International Series',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_championships'},
#   {'id': 'sr:competition:2100',
#    'name': 'Davis Cup',
#    'type': 'mixed',
#    'gender': 'men',
#    'category': {'id': 'sr:category:76', 'name': 'Davis Cup'}},
#   {'id': 'sr:competition:2102',
#    'name': 'Billie Jean King Cup',
#    'type': 'mixed',
#    'gender': 'women',
#    'category': {'id': 'sr:category:74', 'name': 'Billie Jean King Cup'}},
#   {'id': 'sr:competition:2555',
#    'name': 'Wimbledon Men Singles',
#    'parent_id': 'sr:competition:2553',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2557',
#    'name': 'Wimbledon Men Doubles',
#    'parent_id': 'sr:competition:2553',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2559',
#    'name': 'Wimbledon Women Singles',
#    'parent_id': 'sr:competition:2553',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2561',
#    'name': 'Wimbledon Women Doubles',
#    'parent_id': 'sr:competition:2553',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2563',
#    'name': 'Wimbledon Mixed Doubles',
#    'parent_id': 'sr:competition:2553',
#    'type': 'mixed_doubles',
#    'gender': 'mixed',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2567',
#    'name': 'Australian Open Men Singles',
#    'parent_id': 'sr:competition:2565',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2569',
#    'name': 'Australian Open Men Doubles',
#    'parent_id': 'sr:competition:2565',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2571',
#    'name': 'Australian Open Women Singles',
#    'parent_id': 'sr:competition:2565',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2573',
#    'name': 'Australian Open Women Doubles',
#    'parent_id': 'sr:competition:2565',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2575',
#    'name': 'Australian Open Mixed Doubles',
#    'parent_id': 'sr:competition:2565',
#    'type': 'mixed_doubles',
#    'gender': 'mixed',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2579',
#    'name': 'French Open Men Singles',
#    'parent_id': 'sr:competition:2577',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2581',
#    'name': 'French Open Men Doubles',
#    'parent_id': 'sr:competition:2577',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2583',
#    'name': 'French Open Women Singles',
#    'parent_id': 'sr:competition:2577',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2585',
#    'name': 'French Open Women Doubles',
#    'parent_id': 'sr:competition:2577',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2587',
#    'name': 'French Open Mixed Doubles',
#    'parent_id': 'sr:competition:2577',
#    'type': 'mixed_doubles',
#    'gender': 'mixed',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2591',
#    'name': 'US Open Men Singles',
#    'parent_id': 'sr:competition:2589',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2593',
#    'name': 'US Open Men Doubles',
#    'parent_id': 'sr:competition:2589',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2595',
#    'name': 'US Open Women Singles',
#    'parent_id': 'sr:competition:2589',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2597',
#    'name': 'US Open Women Doubles',
#    'parent_id': 'sr:competition:2589',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2599',
#    'name': 'US Open Mixed Doubles',
#    'parent_id': 'sr:competition:2589',
#    'type': 'mixed_doubles',
#    'gender': 'mixed',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'grand_slam'},
#   {'id': 'sr:competition:2603',
#    'name': 'ATP Doha, Qatar Men Singles',
#    'parent_id': 'sr:competition:2601',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2605',
#    'name': 'ATP Doha, Qatar Men Doubles',
#    'parent_id': 'sr:competition:2601',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2613',
#    'name': 'ATP Basel, Switzerland Men Singles',
#    'parent_id': 'sr:competition:2611',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2615',
#    'name': 'ATP Basel, Switzerland Men Doubles',
#    'parent_id': 'sr:competition:2611',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2619',
#    'name': 'ATP Brisbane, Australia Men Singles',
#    'parent_id': 'sr:competition:2617',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2621',
#    'name': 'ATP Brisbane, Australia Men Doubles',
#    'parent_id': 'sr:competition:2617',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2625',
#    'name': 'ATP Chennai, India Men Singles',
#    'parent_id': 'sr:competition:2623',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2627',
#    'name': 'ATP Chennai, India Men Doubles',
#    'parent_id': 'sr:competition:2623',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2631',
#    'name': 'ATP Auckland, New Zealand Men Singles',
#    'parent_id': 'sr:competition:2629',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2633',
#    'name': 'ATP Auckland, New Zealand Men Doubles',
#    'parent_id': 'sr:competition:2629',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2637',
#    'name': 'ATP Sydney, Australia Men Singles',
#    'parent_id': 'sr:competition:2635',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2639',
#    'name': 'ATP Sydney, Australia Men Doubles',
#    'parent_id': 'sr:competition:2635',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2649',
#    'name': 'ATP Zagreb, Croatia Men Singles',
#    'parent_id': 'sr:competition:2647',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2651',
#    'name': 'ATP Zagreb, Croatia Men Double',
#    'parent_id': 'sr:competition:2647',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2661',
#    'name': 'ATP Paris, France Men Singles',
#    'parent_id': 'sr:competition:2659',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2663',
#    'name': 'ATP Paris, France Men Doubles',
#    'parent_id': 'sr:competition:2659',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2667',
#    'name': 'ATP Dubai, UAE Men Singles',
#    'parent_id': 'sr:competition:2665',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2669',
#    'name': 'ATP Dubai, UAE Men Doubles',
#    'parent_id': 'sr:competition:2665',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2673',
#    'name': 'WTA Pattaya City, Thailand Women Singles',
#    'parent_id': 'sr:competition:2671',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_international'},
#   {'id': 'sr:competition:2675',
#    'name': 'WTA Pattaya City, Thailand Women Doubles',
#    'parent_id': 'sr:competition:2671',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_international'},
#   {'id': 'sr:competition:2679',
#    'name': 'ATP Rotterdam, Netherlands Men Singles',
#    'parent_id': 'sr:competition:2677',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2681',
#    'name': 'ATP Rotterdam, Netherlands Men Doubles',
#    'parent_id': 'sr:competition:2677',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2697',
#    'name': 'ATP Memphis, USA Men Singles',
#    'parent_id': 'sr:competition:2695',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2699',
#    'name': 'ATP Memphis, USA Men Doubles',
#    'parent_id': 'sr:competition:2695',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2703',
#    'name': 'WTA Bogota, Colombia Women Singles',
#    'parent_id': 'sr:competition:2701',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2705',
#    'name': 'WTA Bogota, Colombia Women Doubles',
#    'parent_id': 'sr:competition:2701',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2709',
#    'name': 'ATP Acapulco, Mexico Men Singles',
#    'parent_id': 'sr:competition:2707',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2711',
#    'name': 'ATP Acapulco, Mexico Men Doubles',
#    'parent_id': 'sr:competition:2707',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2715',
#    'name': 'WTA Monterrey, Mexico Women Singles',
#    'parent_id': 'sr:competition:2713',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:2717',
#    'name': 'WTA Monterrey, Mexico Women Doubles',
#    'parent_id': 'sr:competition:2713',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:2721',
#    'name': 'ATP Marseille, France Men Singles',
#    'parent_id': 'sr:competition:2719',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2723',
#    'name': 'ATP Marseille, France Men Doubles',
#    'parent_id': 'sr:competition:2719',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2727',
#    'name': 'ATP Buenos Aires, Argentina Men Singles',
#    'parent_id': 'sr:competition:2725',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2729',
#    'name': 'ATP Buenos Aires, Argentina Men Doubles',
#    'parent_id': 'sr:competition:2725',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2733',
#    'name': 'ATP Delray Beach, USA Men Singles',
#    'parent_id': 'sr:competition:2731',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2735',
#    'name': 'ATP Delray Beach, USA Men Doubles',
#    'parent_id': 'sr:competition:2731',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2739',
#    'name': 'ATP Indian Wells, USA Men Singles',
#    'parent_id': 'sr:competition:2737',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2741',
#    'name': 'ATP Indian Wells, USA Men Doubles',
#    'parent_id': 'sr:competition:2737',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2745',
#    'name': 'ATP Miami, USA Men Singles',
#    'parent_id': 'sr:competition:2743',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2747',
#    'name': 'ATP Miami, USA Men Doubles',
#    'parent_id': 'sr:competition:2743',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2751',
#    'name': 'ATP Houston, USA Men Singles',
#    'parent_id': 'sr:competition:2749',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2753',
#    'name': 'ATP Houston, USA Men Doubles',
#    'parent_id': 'sr:competition:2749',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2757',
#    'name': 'ATP Casablanca, Morocco Men Singles',
#    'parent_id': 'sr:competition:2755',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2759',
#    'name': 'ATP Casablanca, Morocco Men Doubles',
#    'parent_id': 'sr:competition:2755',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2763',
#    'name': 'WTA Charleston, USA Women Singles',
#    'parent_id': 'sr:competition:2761',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:2765',
#    'name': 'WTA Charleston, USA Women Doubles',
#    'parent_id': 'sr:competition:2761',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:2769',
#    'name': 'ATP Barcelona, Spain Men Singles',
#    'parent_id': 'sr:competition:2767',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2771',
#    'name': 'ATP Barcelona, Spain Men Doubles',
#    'parent_id': 'sr:competition:2767',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2775',
#    'name': 'ATP Stuttgart, Germany Men Singles',
#    'parent_id': 'sr:competition:2773',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2777',
#    'name': 'ATP Stuttgart, Germany Men Doubles',
#    'parent_id': 'sr:competition:2773',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2781',
#    'name': 'ATP Rome, Italy Men Singles',
#    'parent_id': 'sr:competition:2779',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2783',
#    'name': 'ATP Rome, Italy Men Doubles',
#    'parent_id': 'sr:competition:2779',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2787',
#    'name': 'ATP Madrid, Spain Men Singles',
#    'parent_id': 'sr:competition:2785',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2789',
#    'name': 'ATP Madrid, Spain Men Doubles',
#    'parent_id': 'sr:competition:2785',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2793',
#    'name': 'Berlin, Germany Women Singles',
#    'parent_id': 'sr:competition:2791',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:2795',
#    'name': 'Berlin, Germany Women Doubles',
#    'parent_id': 'sr:competition:2791',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:2805',
#    'name': 'WTA Hobart, Australia Women Singles',
#    'parent_id': 'sr:competition:2803',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2807',
#    'name': 'WTA Hobart, Australia Women Doubles',
#    'parent_id': 'sr:competition:2803',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2817',
#    'name': 'WTA Marrakech, Morocco Women Singles',
#    'parent_id': 'sr:competition:2815',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_international'},
#   {'id': 'sr:competition:2819',
#    'name': 'WTA Marrakech, Morocco Women Doubles',
#    'parent_id': 'sr:competition:2815',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_international'},
#   {'id': 'sr:competition:2823',
#    'name': 'WTA Strasbourg, France Women Singles',
#    'parent_id': 'sr:competition:2821',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:2825',
#    'name': 'WTA Strasbourg, France Women Doubles',
#    'parent_id': 'sr:competition:2821',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:2829',
#    'name': 'ATP Challenger Amersfoort, Netherlands Men Singles',
#    'parent_id': 'sr:competition:2827',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:2831',
#    'name': 'ATP Challenger Amersfoort, Netherlands Men Doubles',
#    'parent_id': 'sr:competition:2827',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:2835',
#    'name': 'ATP Munich, Germany Men Singles',
#    'parent_id': 'sr:competition:2833',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2837',
#    'name': 'ATP Munich, Germany Men Doubles',
#    'parent_id': 'sr:competition:2833',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2853',
#    'name': 'WTA Birmingham, Great Britain Women Singles',
#    'parent_id': 'sr:competition:2851',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2855',
#    'name': 'WTA Birmingham, Great Britain Women Doubles',
#    'parent_id': 'sr:competition:2851',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2859',
#    'name': 'ATP Halle, Germany Men Singles',
#    'parent_id': 'sr:competition:2857',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2861',
#    'name': 'ATP Halle, Germany Men Doubles',
#    'parent_id': 'sr:competition:2857',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2865',
#    'name': 'ATP London, Great Britain Men Singles',
#    'parent_id': 'sr:competition:2863',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2867',
#    'name': 'ATP London, Great Britain Men Doubles',
#    'parent_id': 'sr:competition:2863',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2871',
#    'name': 'ATP S-Hertogenbosch, Netherlands Men Singles',
#    'parent_id': 'sr:competition:2869',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2873',
#    'name': 'ATP S-Hertogenbosch, Netherlands Men Doubles',
#    'parent_id': 'sr:competition:2869',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2877',
#    'name': 'WTA Eastbourne, Great Britain Women Singles',
#    'parent_id': 'sr:competition:7629',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2879',
#    'name': 'WTA Eastbourne, Great Britain Women Doubles',
#    'parent_id': 'sr:competition:7629',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2883',
#    'name': 'ATP Newport, USA Men Singles',
#    'parent_id': 'sr:competition:2881',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2885',
#    'name': 'ATP Newport, USA Men Doubles',
#    'parent_id': 'sr:competition:2881',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2889',
#    'name': 'ATP Bastad, Sweden Men Singles',
#    'parent_id': 'sr:competition:2887',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2891',
#    'name': 'ATP Bastad, Sweden Men Doubles',
#    'parent_id': 'sr:competition:2887',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2895',
#    'name': 'WTA Budapest, Hungary Women Singles',
#    'parent_id': 'sr:competition:2893',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2897',
#    'name': 'WTA Budapest, Hungary Women Doubles',
#    'parent_id': 'sr:competition:2893',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2901',
#    'name': 'WTA Palermo, Italy Women Singles',
#    'parent_id': 'sr:competition:2899',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2903',
#    'name': 'WTA Palermo, Italy Women Doubles',
#    'parent_id': 'sr:competition:2899',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2907',
#    'name': 'WTA Prague, Czech Republic Women Singles',
#    'parent_id': 'sr:competition:2905',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2909',
#    'name': 'WTA Prague, Czech Republic Women Doubles',
#    'parent_id': 'sr:competition:2905',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2913',
#    'name': 'Portoroz, Slovenia Women Singles',
#    'parent_id': 'sr:competition:2911',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2915',
#    'name': 'Portoroz, Slovenia Women Doubles',
#    'parent_id': 'sr:competition:2911',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'}},
#   {'id': 'sr:competition:2935',
#    'name': 'ATP Hamburg, Germany Men Singles',
#    'parent_id': 'sr:competition:2933',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2937',
#    'name': 'ATP Hamburg, Germany Men Doubles',
#    'parent_id': 'sr:competition:2933',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2941',
#    'name': 'WTA San Jose, USA Women Singles',
#    'parent_id': 'sr:competition:2689',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:2943',
#    'name': 'WTA San Jose, USA Women Doubles',
#    'parent_id': 'sr:competition:2689',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:2947',
#    'name': 'WTA Istanbul, Turkey Women Singles',
#    'parent_id': 'sr:competition:2945',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2949',
#    'name': 'WTA Istanbul, Turkey Women Doubles',
#    'parent_id': 'sr:competition:2945',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:2959',
#    'name': 'ATP Gstaad, Switzerland Men Singles',
#    'parent_id': 'sr:competition:2957',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2961',
#    'name': 'ATP Gstaad, Switzerland Men Doubles',
#    'parent_id': 'sr:competition:2957',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2965',
#    'name': 'ATP Umag, Croatia Men Singles',
#    'parent_id': 'sr:competition:2963',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2967',
#    'name': 'ATP Umag, Croatia Men Doubles',
#    'parent_id': 'sr:competition:2963',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:2971',
#    'name': 'ATP Washington, USA Men Singles',
#    'parent_id': 'sr:competition:2969',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2973',
#    'name': 'ATP Washington, USA Men Doubles',
#    'parent_id': 'sr:competition:2969',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:2977',
#    'name': 'WTA Montreal, Canada Women Singles',
#    'parent_id': 'sr:competition:2975',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_1000'},
#   {'id': 'sr:competition:2979',
#    'name': 'WTA Montreal, Canada Women Doubles',
#    'parent_id': 'sr:competition:2975',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_1000'},
#   {'id': 'sr:competition:2983',
#    'name': 'ATP Cincinnati, USA Men Singles',
#    'parent_id': 'sr:competition:2981',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2985',
#    'name': 'ATP Cincinnati, USA Men Doubles',
#    'parent_id': 'sr:competition:2981',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2989',
#    'name': 'WTA New Haven, USA Women Singles',
#    'parent_id': 'sr:competition:2987',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_premier'},
#   {'id': 'sr:competition:2991',
#    'name': 'WTA New Haven, USA Women Doubles',
#    'parent_id': 'sr:competition:2987',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_premier'},
#   {'id': 'sr:competition:2995',
#    'name': 'ATP Toronto, Canada Men Singles',
#    'parent_id': 'sr:competition:2993',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:2997',
#    'name': 'ATP Toronto, Canada Men Doubles',
#    'parent_id': 'sr:competition:2993',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:3001',
#    'name': 'ATP Metz, France Men Singles',
#    'parent_id': 'sr:competition:2999',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3003',
#    'name': 'ATP Metz, France Men Doubles',
#    'parent_id': 'sr:competition:2999',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3007',
#    'name': 'ATP Bucharest, Romania Men Singles',
#    'parent_id': 'sr:competition:3005',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3009',
#    'name': 'ATP Bucharest, Romania Men Doubles',
#    'parent_id': 'sr:competition:3005',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3013',
#    'name': 'WTA Guangzhou, China Women Singles',
#    'parent_id': 'sr:competition:3011',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:3015',
#    'name': 'WTA Guangzhou, China Women Doubles',
#    'parent_id': 'sr:competition:3011',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:3025',
#    'name': 'ATP Beijing, China Men Singles',
#    'parent_id': 'sr:competition:3023',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:3027',
#    'name': 'ATP Beijing, China Men Doubles',
#    'parent_id': 'sr:competition:3023',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:3031',
#    'name': 'ATP Tokyo, Japan Men Singles',
#    'parent_id': 'sr:competition:3029',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:3033',
#    'name': 'ATP Tokyo, Japan Men Doubles',
#    'parent_id': 'sr:competition:3029',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:3037',
#    'name': 'WTA Quebec City, Canada Women Singles',
#    'parent_id': 'sr:competition:3035',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_international'},
#   {'id': 'sr:competition:3039',
#    'name': 'WTA Quebec City, Canada Women Doubles',
#    'parent_id': 'sr:competition:3035',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_international'},
#   {'id': 'sr:competition:3043',
#    'name': 'WTA Seoul, Korea Republic Women Singles',
#    'parent_id': 'sr:competition:3041',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:3045',
#    'name': 'WTA Seoul, Korea Republic Women Doubles',
#    'parent_id': 'sr:competition:3041',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:3049',
#    'name': 'WTA Tashkent, Uzbekistan Women Singles',
#    'parent_id': 'sr:competition:3047',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_international'},
#   {'id': 'sr:competition:3051',
#    'name': 'WTA Tashkent, Uzbekistan Women Doubles',
#    'parent_id': 'sr:competition:3047',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_international'},
#   {'id': 'sr:competition:3055',
#    'name': 'WTA Linz, Austria Women Singles',
#    'parent_id': 'sr:competition:3053',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:3057',
#    'name': 'WTA Linz, Austria Women Doubles',
#    'parent_id': 'sr:competition:3053',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:3061',
#    'name': 'WTA Osaka, Japan Women Singles',
#    'parent_id': 'sr:competition:3059',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:3063',
#    'name': 'WTA Osaka, Japan Women Doubles',
#    'parent_id': 'sr:competition:3059',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:3067',
#    'name': 'ATP Moscow, Russia Men Singles',
#    'parent_id': 'sr:competition:3065',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3069',
#    'name': 'ATP Moscow, Russia Men Doubles',
#    'parent_id': 'sr:competition:3065',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3073',
#    'name': 'WTA Luxembourg, Luxembourg Women Singles',
#    'parent_id': 'sr:competition:3071',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:3075',
#    'name': 'WTA Luxembourg, Luxembourg Women Doubles',
#    'parent_id': 'sr:competition:3071',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:3085',
#    'name': 'ATP Shanghai, China Men Singles',
#    'parent_id': 'sr:competition:3083',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:3087',
#    'name': 'ATP Shanghai, China Men Doubles',
#    'parent_id': 'sr:competition:3083',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:3091',
#    'name': 'ATP Stockholm, Sweden Men Singles',
#    'parent_id': 'sr:competition:3089',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3093',
#    'name': 'ATP Stockholm, Sweden Men Doubles',
#    'parent_id': 'sr:competition:3089',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3097',
#    'name': 'ATP Lyon, France Men Singles',
#    'parent_id': 'sr:competition:3095',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3099',
#    'name': 'ATP Lyon, France Men Doubles',
#    'parent_id': 'sr:competition:3095',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3103',
#    'name': 'ATP Vienna, Austria Men Singles',
#    'parent_id': 'sr:competition:3101',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:3105',
#    'name': 'ATP Vienna, Austria Men Doubles',
#    'parent_id': 'sr:competition:3101',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_500'},
#   {'id': 'sr:competition:3109',
#    'name': 'ATP St. Petersburg, Russia Men Singles',
#    'parent_id': 'sr:competition:3107',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3111',
#    'name': 'ATP St. Petersburg, Russia Men Doubles',
#    'parent_id': 'sr:competition:3107',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3121',
#    'name': 'ATP Monte Carlo, Monaco Men Singles',
#    'parent_id': 'sr:competition:3119',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:3123',
#    'name': 'ATP Monte Carlo, Monaco Men Doubles',
#    'parent_id': 'sr:competition:3119',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_1000'},
#   {'id': 'sr:competition:3145',
#    'name': 'WTA Antwerp, Belgium Women Singles',
#    'parent_id': 'sr:competition:3143',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_premier'},
#   {'id': 'sr:competition:3147',
#    'name': 'WTA Antwerp, Belgium Women Doubles',
#    'parent_id': 'sr:competition:3143',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_premier'},
#   {'id': 'sr:competition:3151',
#    'name': 'ATP Kitzbuhel, Austria Men Singles',
#    'parent_id': 'sr:competition:3149',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3153',
#    'name': 'ATP Kitzbuhel, Austria Men Doubles',
#    'parent_id': 'sr:competition:3149',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3163',
#    'name': 'San Diego, USA Women Singles',
#    'parent_id': 'sr:competition:3161',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:3165',
#    'name': 'San Diego, USA Women Doubles',
#    'parent_id': 'sr:competition:3161',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_500'},
#   {'id': 'sr:competition:3181',
#    'name': 'ATP Nottingham, Great Britain Men Singles',
#    'parent_id': 'sr:competition:3179',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3183',
#    'name': 'ATP Nottingham, Great Britain Men Doubles',
#    'parent_id': 'sr:competition:3179',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3215',
#    'name': 'ATP Challenger Charlottesville, USA Men Doubles',
#    'parent_id': 'sr:competition:3213',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3217',
#    'name': 'ATP Challenger Charlottesville, USA Men Singles',
#    'parent_id': 'sr:competition:3213',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3221',
#    'name': 'ATP Challenger Noumea, New Caledonia Men Singles',
#    'parent_id': 'sr:competition:3219',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3223',
#    'name': 'ATP Challenger Noumea, New Caledonia Men Doubles',
#    'parent_id': 'sr:competition:3219',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3227',
#    'name': 'ATP Challenger Sao Paulo, Brazil Men Singles',
#    'parent_id': 'sr:competition:3225',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3229',
#    'name': 'ATP Challenger Sao Paulo, Brazil Men Doubles',
#    'parent_id': 'sr:competition:3225',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3233',
#    'name': 'ATP Challenger Salinas, Ecuador Men Singles',
#    'parent_id': 'sr:competition:3231',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3235',
#    'name': 'ATP Challenger Salinas, Ecuador Men Doubles',
#    'parent_id': 'sr:competition:3231',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3239',
#    'name': 'ATP Santiago, Chile Men Singles',
#    'parent_id': 'sr:competition:3237',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3241',
#    'name': 'ATP Santiago, Chile Men Doubles',
#    'parent_id': 'sr:competition:3237',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3245',
#    'name': 'ATP Atlanta, USA Men Singles',
#    'parent_id': 'sr:competition:3243',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3247',
#    'name': 'ATP Atlanta, USA Men Doubles',
#    'parent_id': 'sr:competition:3243',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3251',
#    'name': 'ATP Belgrade, Serbia Men Singles',
#    'parent_id': 'sr:competition:3249',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3253',
#    'name': 'ATP Belgrade, Serbia Men Doubles',
#    'parent_id': 'sr:competition:3249',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3257',
#    'name': 'ATP Kuala Lumpur, Malaysia Men Singles',
#    'parent_id': 'sr:competition:3255',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3259',
#    'name': 'ATP Kuala Lumpur, Malaysia Men Doubles',
#    'parent_id': 'sr:competition:3255',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3263',
#    'name': 'ATP Nice, France Men Singles',
#    'parent_id': 'sr:competition:3261',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3265',
#    'name': 'ATP Nice, France Men Doubles',
#    'parent_id': 'sr:competition:3261',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:3281',
#    'name': 'ATP Challenger Barletta, Italy Men Singles',
#    'parent_id': 'sr:competition:3279',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3283',
#    'name': 'ATP Challenger Barletta, Italy Men Doubles',
#    'parent_id': 'sr:competition:3279',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3287',
#    'name': 'ATP Challenger Bergamo, Italy Men Singles',
#    'parent_id': 'sr:competition:3285',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3289',
#    'name': 'ATP Challenger Bergamo, Italy Men Doubles',
#    'parent_id': 'sr:competition:3285',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:3293',
#    'name': 'ATP Challenger Floridablanca-Bucaramanga, Colombia Men Singles',
#    'parent_id': 'sr:competition:3291',
#    'type': 'singles',
# ...
#   {'id': 'sr:competition:12299',
#    'name': 'ATP Challenger Raanana, Israel Men Doubles',
#    'parent_id': 'sr:competition:12295',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12309',
#    'name': 'ATP Challenger Launceston, Australia Men Singles',
#    'parent_id': 'sr:competition:12307',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12311',
#    'name': 'ATP Challenger Launceston, Australia Men Doubles',
#    'parent_id': 'sr:competition:12307',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12315',
#    'name': 'ATP Geneva, Switzerland Men Singles',
#    'parent_id': 'sr:competition:12313',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:12317',
#    'name': 'ATP Geneva, Switzerland Men Doubles',
#    'parent_id': 'sr:competition:12313',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:12321',
#    'name': 'ATP Istanbul, Turkey Men Singles',
#    'parent_id': 'sr:competition:12319',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:12323',
#    'name': 'ATP Istanbul, Turkey Men Doubles',
#    'parent_id': 'sr:competition:12319',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:12327',
#    'name': 'ATP Quito, Ecuador Men Singles',
#    'parent_id': 'sr:competition:12325',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:12329',
#    'name': 'ATP Quito, Ecuador Men Doubles',
#    'parent_id': 'sr:competition:12325',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:12333',
#    'name': 'WTA Nottingham, Great Britain Women Singles',
#    'parent_id': 'sr:competition:12331',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:12335',
#    'name': 'WTA Nottingham, Great Britain Women Doubles',
#    'parent_id': 'sr:competition:12331',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:6', 'name': 'WTA'},
#    'level': 'wta_250'},
#   {'id': 'sr:competition:12375',
#    'name': 'ATP Challenger Batman, Turkey Men Singles',
#    'parent_id': 'sr:competition:12373',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12377',
#    'name': 'ATP Challenger Batman, Turkey Men Doubles',
#    'parent_id': 'sr:competition:12373',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12381',
#    'name': 'ATP Challenger Puebla, Mexico Men Singles',
#    'parent_id': 'sr:competition:12379',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12383',
#    'name': 'ATP Challenger Puebla, Mexico Men Doubles',
#    'parent_id': 'sr:competition:12379',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12429',
#    'name': 'ATP Challenger Ilkley, Great Britain Men Singles',
#    'parent_id': 'sr:competition:12427',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12431',
#    'name': 'ATP Challenger Ilkley, Great Britain Men Doubles',
#    'parent_id': 'sr:competition:12427',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12435',
#    'name': 'ATP Challenger Manchester, Great Britain Men Singles',
#    'parent_id': 'sr:competition:12433',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12437',
#    'name': 'ATP Challenger Manchester, Great Britain Men Doubles',
#    'parent_id': 'sr:competition:12433',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12441',
#    'name': 'ATP Challenger Surbiton, Great Britain Men Singles',
#    'parent_id': 'sr:competition:12439',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12443',
#    'name': 'ATP Challenger Surbiton, Great Britain Men Doubles',
#    'parent_id': 'sr:competition:12439',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12447',
#    'name': 'ATP Challenger Poprad Tatry, Slovakia Men Singles',
#    'parent_id': 'sr:competition:12445',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12449',
#    'name': 'ATP Challenger Poprad Tatry, Slovakia Men Doubles',
#    'parent_id': 'sr:competition:12445',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12453',
#    'name': 'ATP Challenger Perugia, Italy Men Singles',
#    'parent_id': 'sr:competition:12451',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12455',
#    'name': 'ATP Challenger Perugia, Italy Men Doubles',
#    'parent_id': 'sr:competition:12451',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12459',
#    'name': 'ATP Challenger Moscow, Russia Men Singles',
#    'parent_id': 'sr:competition:12457',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12461',
#    'name': 'ATP Challenger Moscow, Russia Men Doubles',
#    'parent_id': 'sr:competition:12457',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12549',
#    'name': 'ATP Estoril, Portugal Men Singles',
#    'parent_id': 'sr:competition:12547',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:12551',
#    'name': 'ATP Estoril, Portugal Men Doubles',
#    'parent_id': 'sr:competition:12547',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:3', 'name': 'ATP'},
#    'level': 'atp_250'},
#   {'id': 'sr:competition:12657',
#    'name': 'ITF Men Jassowal, India Men Singles',
#    'parent_id': 'sr:competition:12655',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:785', 'name': 'ITF Men'}},
#   {'id': 'sr:competition:12659',
#    'name': 'ITF Men Jassowal, India Men Doubles',
#    'parent_id': 'sr:competition:12655',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:785', 'name': 'ITF Men'}},
#   {'id': 'sr:competition:12663',
#    'name': 'ITF Women Eastbourne, Great Britain Women Singles',
#    'parent_id': 'sr:competition:12661',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12665',
#    'name': 'ITF Women Eastbourne, Great Britain Women Doubles',
#    'parent_id': 'sr:competition:12661',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12687',
#    'name': 'ITF Men Sarajevo, Bosnia/Herzegovina Men Singles',
#    'parent_id': 'sr:competition:12685',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:785', 'name': 'ITF Men'}},
#   {'id': 'sr:competition:12689',
#    'name': 'ITF Men Sarajevo, Bosnia/Herzegovina Men Doubles',
#    'parent_id': 'sr:competition:12685',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:785', 'name': 'ITF Men'}},
#   {'id': 'sr:competition:12723',
#    'name': 'ITF Women Grand Baie La Croisette, Mauritius Women Singles',
#    'parent_id': 'sr:competition:12721',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12725',
#    'name': 'ITF Women Grand Baie La Croisette, Mauritius Women Doubles',
#    'parent_id': 'sr:competition:12721',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12741',
#    'name': 'ITF Women Baton Rouge, USA Women Singles',
#    'parent_id': 'sr:competition:12739',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12743',
#    'name': 'ITF Women Baton Rouge, USA Women Doubles',
#    'parent_id': 'sr:competition:12739',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12747',
#    'name': 'ITF Women Kaohsiung, Chinese Taipei Women Singles',
#    'parent_id': 'sr:competition:12745',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12749',
#    'name': 'ITF Women Kaohsiung, Chinese Taipei Women Doubles',
#    'parent_id': 'sr:competition:12745',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12819',
#    'name': 'ITF Women Bursa, Turkey Women Singles',
#    'parent_id': 'sr:competition:12817',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12821',
#    'name': 'ITF Women Bursa, Turkey Women Doubles',
#    'parent_id': 'sr:competition:12817',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12837',
#    'name': 'ATP Challenger Manerbio, Italy Men Singles',
#    'parent_id': 'sr:competition:12835',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12839',
#    'name': 'ATP Challenger Manerbio, Italy Men Doubles',
#    'parent_id': 'sr:competition:12835',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12843',
#    'name': 'ATP Challenger Agri, Turkey Men Singles',
#    'parent_id': 'sr:competition:12841',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12845',
#    'name': 'ATP Challenger Agri, Turkey Men Doubles',
#    'parent_id': 'sr:competition:12841',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12849',
#    'name': 'ATP Challenger Cary, USA Men Singles',
#    'parent_id': 'sr:competition:12847',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12851',
#    'name': 'ATP Challenger Cary, USA Men Doubles',
#    'parent_id': 'sr:competition:12847',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12855',
#    'name': 'ATP Challenger Columbus, USA Men Singles',
#    'parent_id': 'sr:competition:12853',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12857',
#    'name': 'ATP Challenger Columbus, USA Men Doubles',
#    'parent_id': 'sr:competition:12853',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:72', 'name': 'Challenger'}},
#   {'id': 'sr:competition:12891',
#    'name': 'WTA 125K Dalian, China Women Singles',
#    'parent_id': 'sr:competition:12889',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:871', 'name': 'WTA 125K'}},
#   {'id': 'sr:competition:12893',
#    'name': 'WTA 125K Dalian, China Women Doubles',
#    'parent_id': 'sr:competition:12889',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:871', 'name': 'WTA 125K'}},
#   {'id': 'sr:competition:12897',
#    'name': 'WTA 125K Carlsbad, USA Women Singles',
#    'parent_id': 'sr:competition:12895',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:871', 'name': 'WTA 125K'}},
#   {'id': 'sr:competition:12899',
#    'name': 'WTA 125K Carlsbad, USA Women Doubles',
#    'parent_id': 'sr:competition:12895',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:871', 'name': 'WTA 125K'}},
#   {'id': 'sr:competition:12903',
#    'name': 'WTA 125K Hua Hin, Thailand Women Singles',
#    'parent_id': 'sr:competition:12901',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:871', 'name': 'WTA 125K'}},
#   {'id': 'sr:competition:12905',
#    'name': 'WTA 125K Hua Hin, Thailand Women Doubles',
#    'parent_id': 'sr:competition:12901',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:871', 'name': 'WTA 125K'}},
#   {'id': 'sr:competition:12909',
#    'name': 'ITF Men Erzurum, Turkey Men Singles',
#    'parent_id': 'sr:competition:12907',
#    'type': 'singles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:785', 'name': 'ITF Men'}},
#   {'id': 'sr:competition:12911',
#    'name': 'ITF Men Erzurum, Turkey Men Doubles',
#    'parent_id': 'sr:competition:12907',
#    'type': 'doubles',
#    'gender': 'men',
#    'category': {'id': 'sr:category:785', 'name': 'ITF Men'}},
#   {'id': 'sr:competition:12975',
#    'name': 'ITF Women Graz, Austria Women Singles',
#    'parent_id': 'sr:competition:12973',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12977',
#    'name': 'ITF Women Graz, Austria Women Doubles',
#    'parent_id': 'sr:competition:12973',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12981',
#    'name': 'ITF Women Koper, Slovenia Women Singles',
#    'parent_id': 'sr:competition:12979',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12983',
#    'name': 'ITF Women Koper, Slovenia Women Doubles',
#    'parent_id': 'sr:competition:12979',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12987',
#    'name': 'ITF Women Cakovec, Croatia Women Singles',
#    'parent_id': 'sr:competition:12985',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12989',
#    'name': 'ITF Women Cakovec, Croatia Women Doubles',
#    'parent_id': 'sr:competition:12985',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:12999',
#    'name': 'ITF Women Kiryat Gat, Israel Women Singles',
#    'parent_id': 'sr:competition:12997',
#    'type': 'singles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   {'id': 'sr:competition:13001',
#    'name': 'ITF Women Kiryat Gat, Israel Women Doubles',
#    'parent_id': 'sr:competition:12997',
#    'type': 'doubles',
#    'gender': 'women',
#    'category': {'id': 'sr:category:213', 'name': 'ITF Women'}},
#   ...]}

# %%
Id=[]
Name=[]
c_id=[]
c_name=[]
type=[]
gender=[]
parent_id=[]

for i in data['competitions']:
    Id.append(i['id'].split(':')[-1])

    Name.append(i['name'])
    c_id.append(i['category']['id'].split(':')[-1])
    type.append(i['type'])
    c_name.append(i['category']['name'])
    gender.append(i['gender'])
    parent_id.append(i.get('parent_id', None).split(':')[-1] if i.get('parent_id', None) is not None else None)

# %%
parent_id
# Out:
# [None,
#  None,
#  '6239',
#  None,
#  None,
#  None,
#  '2553',
#  '2553',
#  '2553',
#  '2553',
#  '2553',
#  '2565',
#  '2565',
#  '2565',
#  '2565',
#  '2565',
#  '2577',
#  '2577',
#  '2577',
#  '2577',
#  '2577',
#  '2589',
#  '2589',
#  '2589',
#  '2589',
#  '2589',
#  '2601',
#  '2601',
#  '2611',
#  '2611',
#  '2617',
#  '2617',
#  '2623',
#  '2623',
#  '2629',
#  '2629',
#  '2635',
#  '2635',
#  '2647',
#  '2647',
#  '2659',
#  '2659',
#  '2665',
#  '2665',
#  '2671',
#  '2671',
#  '2677',
#  '2677',
#  '2695',
#  '2695',
#  '2701',
#  '2701',
#  '2707',
#  '2707',
#  '2713',
#  '2713',
#  '2719',
#  '2719',
#  '2725',
#  '2725',
#  '2731',
#  '2731',
#  '2737',
#  '2737',
#  '2743',
#  '2743',
#  '2749',
#  '2749',
#  '2755',
#  '2755',
#  '2761',
#  '2761',
#  '2767',
#  '2767',
#  '2773',
#  '2773',
#  '2779',
#  '2779',
#  '2785',
#  '2785',
#  '2791',
#  '2791',
#  '2803',
#  '2803',
#  '2815',
#  '2815',
#  '2821',
#  '2821',
#  '2827',
#  '2827',
#  '2833',
#  '2833',
#  '2851',
#  '2851',
#  '2857',
#  '2857',
#  '2863',
#  '2863',
#  '2869',
#  '2869',
#  '7629',
#  '7629',
#  '2881',
#  '2881',
#  '2887',
#  '2887',
#  '2893',
#  '2893',
#  '2899',
#  '2899',
#  '2905',
#  '2905',
#  '2911',
#  '2911',
#  '2933',
#  '2933',
#  '2689',
#  '2689',
#  '2945',
#  '2945',
#  '2957',
#  '2957',
#  '2963',
#  '2963',
#  '2969',
#  '2969',
#  '2975',
#  '2975',
#  '2981',
#  '2981',
#  '2987',
#  '2987',
#  '2993',
#  '2993',
#  '2999',
#  '2999',
#  '3005',
#  '3005',
#  '3011',
#  '3011',
#  '3023',
#  '3023',
#  '3029',
#  '3029',
#  '3035',
#  '3035',
#  '3041',
#  '3041',
#  '3047',
#  '3047',
#  '3053',
#  '3053',
#  '3059',
#  '3059',
#  '3065',
#  '3065',
#  '3071',
#  '3071',
#  '3083',
#  '3083',
#  '3089',
#  '3089',
#  '3095',
#  '3095',
#  '3101',
#  '3101',
#  '3107',
#  '3107',
#  '3119',
#  '3119',
#  '3143',
#  '3143',
#  '3149',
#  '3149',
#  '3161',
#  '3161',
#  '3179',
#  '3179',
#  '3213',
#  '3213',
#  '3219',
#  '3219',
#  '3225',
#  '3225',
#  '3231',
#  '3231',
#  '3237',
#  '3237',
#  '3243',
#  '3243',
#  '3249',
#  '3249',
#  '3255',
#  '3255',
#  '3261',
#  '3261',
#  '3279',
#  '3279',
#  '3285',
#  '3285',
#  '3291',
#  '3291',
#  '3297',
#  '3297',
#  '3309',
#  '3309',
#  '3319',
#  '3319',
#  '3325',
#  '3325',
#  '3341',
#  '3341',
#  '3347',
#  '3347',
#  '3365',
#  '3365',
#  '3377',
#  '3377',
#  '3389',
#  '3389',
#  '3423',
#  '3423',
#  '3429',
#  '3429',
#  '3435',
#  '3435',
#  '3445',
#  '3445',
#  '3451',
#  '3451',
#  '3467',
#  '3467',
#  '3473',
#  '3473',
#  '3479',
#  '3479',
#  '3491',
#  '3491',
#  '3497',
#  '3497',
#  '3503',
#  '3503',
#  '3509',
#  '3509',
#  '3523',
#  '3527',
#  '3527',
#  '3533',
#  '3533',
#  '3539',
#  '3539',
#  '3545',
#  '3545',
#  '3551',
#  '3551',
#  '3569',
#  '3569',
#  '3579',
#  '3579',
#  '3585',
#  '3585',
#  '3597',
#  '3597',
#  '3603',
#  '3607',
#  '3607',
#  '3613',
#  '3613',
#  '3641',
#  '3641',
#  '3647',
#  '3647',
#  '3653',
#  '3653',
#  '3667',
#  '3667',
#  '3673',
#  '3673',
#  '3679',
#  '3679',
#  '3685',
#  '3685',
#  '3691',
#  '3691',
#  '3707',
#  '3707',
#  '3713',
#  '3713',
#  '3719',
#  '3719',
#  '3725',
#  '3725',
#  '3731',
#  '3731',
#  '3743',
#  '3743',
#  '3749',
#  '3759',
#  '3775',
#  '3775',
#  '3787',
#  '3787',
#  '3793',
#  '3793',
#  '3799',
#  '3799',
#  '3811',
#  '3811',
#  '3817',
#  '3817',
#  '3823',
#  '3823',
#  '32985',
#  '32985',
#  '3835',
#  '3835',
#  '3853',
#  '3853',
#  '3859',
#  '3859',
#  '3865',
#  '3865',
#  '3871',
#  '3871',
#  '3877',
#  '3877',
#  '3897',
#  '3897',
#  '3903',
#  '3903',
#  '3913',
#  '3913',
#  '3919',
#  '3919',
#  '3925',
#  '3925',
#  '3931',
#  '3931',
#  '3943',
#  '3943',
#  '3949',
#  '3949',
#  '3955',
#  '3955',
#  '3961',
#  '3961',
#  '3973',
#  '3973',
#  '3985',
#  '3985',
#  '3991',
#  '3991',
#  '3997',
#  '3997',
#  '4009',
#  '4009',
#  '4081',
#  '4081',
#  '4141',
#  '4141',
#  '4147',
#  '4147',
#  '4183',
#  '4183',
#  '4207',
#  '4207',
#  '4219',
#  '4219',
#  '4297',
#  '4297',
#  '4309',
#  '4309',
#  '4327',
#  '4327',
#  '4391',
#  '4391',
#  '4413',
#  '4413',
#  '4487',
#  '4487',
#  '4505',
#  '4505',
#  '2707',
#  '2707',
#  '4535',
#  '4535',
#  '4557',
#  '4557',
#  '4575',
#  '4575',
#  '2737',
#  '2737',
#  '4629',
#  '4629',
#  '4635',
#  '4635',
#  '4659',
#  '4659',
#  '4665',
#  '4665',
#  '4683',
#  '4683',
#  '2743',
#  '2743',
#  '4767',
#  '4767',
#  '2779',
#  '2779',
#  '4791',
#  '4791',
#  '4809',
#  '4809',
#  '4833',
#  '4833',
#  '4845',
#  '4845',
#  '4875',
#  '4875',
#  '4905',
#  '4905',
#  '2785',
#  '2785',
#  '4929',
#  '4929',
#  '4971',
#  '4971',
#  '5165',
#  '5165',
#  '5195',
#  '5195',
#  '5237',
#  '5237',
#  '5303',
#  '5303',
#  '5405',
#  '5405',
#  '5521',
#  '5521',
#  '5557',
#  '5557',
#  '5641',
#  '5641',
#  '5691',
#  '5691',
#  '5697',
#  '5697',
#  '5753',
#  '5753',
#  '5771',
#  '5771',
#  '5777',
#  '5777',
#  '5783',
#  '5783',
#  '5789',
#  '5789',
#  '5795',
#  '5795',
#  '5801',
#  '5801',
#  '5835',
#  '5881',
#  '5881',
#  '5899',
#  '5899',
#  '5941',
#  '5941',
#  '5953',
#  '5953',
#  '5971',
#  '5971',
#  '5995',
#  '5995',
#  '6029',
#  '6029',
#  '6065',
#  '6065',
#  '6095',
#  '6095',
#  '6101',
#  '6101',
#  '6107',
#  '6107',
#  '6125',
#  '6125',
#  '6149',
#  '6149',
#  '6215',
#  '6215',
#  '6249',
#  '6249',
#  '6303',
#  '6303',
#  '6315',
#  '6315',
#  '6327',
#  '6327',
#  '6393',
#  '6393',
#  '6447',
#  '6447',
#  '6453',
#  '6453',
#  '43123',
#  '43123',
#  '6495',
#  '6495',
#  '43121',
#  '43121',
#  '6519',
#  '6519',
#  '6573',
#  '6573',
#  '6579',
#  '6579',
#  '6627',
#  '6627',
#  '6699',
#  '6699',
#  '6705',
#  '6705',
#  '6807',
#  '6807',
#  '6843',
#  '6843',
#  '6915',
#  '6915',
#  '6927',
#  '6939',
#  '6939',
#  '6981',
#  '6981',
#  '6993',
#  '6993',
#  '6999',
#  '6999',
#  '7005',
#  '7005',
#  '7041',
#  '7041',
#  '7053',
#  '7053',
#  '7083',
#  '7083',
#  '7113',
#  '7113',
#  '7179',
#  '7179',
#  '7197',
#  '7197',
#  '7263',
#  '7263',
#  '7329',
#  '7329',
#  '7353',
#  '7353',
#  '7389',
#  '7389',
#  '7455',
#  '7455',
#  '7479',
#  '7479',
#  '7497',
#  '7497',
#  '7503',
#  '7503',
#  '7509',
#  '7509',
#  '2869',
#  '2869',
#  '7629',
#  '7629',
#  '7719',
#  '7719',
#  '7791',
#  '7791',
#  '7797',
#  '7797',
#  '7869',
#  '7869',
#  '7947',
#  '7947',
#  '7989',
#  '7989',
#  '8007',
#  '8007',
#  '8049',
#  '8049',
#  '8079',
#  '8079',
#  '8109',
#  '8109',
#  '2969',
#  '2969',
#  '8181',
#  '8181',
#  '8181',
#  '8181',
#  '8181',
#  '8211',
#  '8211',
#  '8277',
#  '8277',
#  '8283',
#  '8283',
#  '8289',
#  '8289',
#  '8295',
#  '8295',
#  '8343',
#  '8343',
#  '2981',
#  '2981',
#  '8367',
#  '8367',
#  '8379',
#  '8379',
#  '8421',
#  '8421',
#  '8445',
#  '8445',
#  '8451',
#  '8451',
#  '8457',
#  '8457',
#  '8469',
#  '8469',
#  '8493',
#  '8493',
#  '8499',
#  '8499',
#  '8583',
#  '8583',
#  '8595',
#  '8595',
#  '8601',
#  '8601',
#  '8637',
#  '8637',
#  '8643',
#  '8643',
#  '8709',
#  '8709',
#  '8733',
#  '8733',
#  '8745',
#  '8745',
#  '8775',
#  '8775',
#  '8793',
#  '8793',
#  '8811',
#  '8811',
#  '8817',
#  '8817',
#  '3023',
#  '3023',
#  '8865',
#  '8865',
#  '8883',
#  '8883',
#  '8919',
#  '8919',
#  '8937',
#  '8937',
#  '3065',
#  '3065',
#  '8973',
#  '8973',
#  '9009',
#  '9009',
#  '9027',
#  '9027',
#  '9039',
#  '9039',
#  '9075',
#  '9075',
#  '9117',
#  '9117',
#  '9135',
#  '9135',
#  '9171',
#  '9171',
#  '9177',
#  '9177',
#  '9243',
#  '9243',
#  '9297',
#  '9297',
#  '9327',
#  '9327',
#  '9351',
#  '9351',
#  '9417',
#  '9417',
#  '9453',
#  '9453',
#  '9459',
#  '9459',
#  '9465',
#  '9465',
#  '9495',
#  '9495',
#  '9501',
#  '9537',
#  '9537',
#  '9561',
#  '9561',
#  '9621',
#  '9627',
#  '9627',
#  '9639',
#  '9639',
#  '9645',
#  '9645',
#  '9657',
#  '9657',
#  '9663',
#  '9663',
#  '9675',
#  '9675',
#  '9693',
#  '9693',
#  '9729',
#  '9729',
#  '9735',
#  '9735',
#  '9777',
#  '9777',
#  '9789',
#  '9789',
#  '9801',
#  '9801',
#  '9807',
#  '9807',
#  '9813',
#  '9813',
#  '9873',
#  '9873',
#  '9927',
#  '9927',
#  '9951',
#  '9951',
#  '10023',
#  '10023',
#  '10029',
#  '10029',
#  '10035',
#  '10035',
#  '10041',
#  '10041',
#  '10053',
#  '10053',
#  '10071',
#  '10071',
#  '10089',
#  '10089',
#  '10149',
#  '10149',
#  '10155',
#  '10155',
#  '10179',
#  '10179',
#  '10221',
#  '10221',
#  '10251',
#  '10251',
#  '10281',
#  '10281',
#  '10311',
#  '10311',
#  '10341',
#  '10341',
#  '10377',
#  '10377',
#  '10419',
#  '10419',
#  '10437',
#  '10437',
#  '10449',
#  '10449',
#  '10455',
#  '10455',
#  '10473',
#  '10473',
#  '10485',
#  '10485',
#  '10491',
#  '10491',
#  '10515',
#  '10515',
#  '10527',
#  '10527',
#  '10533',
#  '10533',
#  '10641',
#  '10641',
#  '10653',
#  '10653',
#  '10671',
#  '10671',
#  '10683',
#  '10683',
#  '10701',
#  '10701',
#  '10755',
#  '10755',
#  '10779',
#  '10779',
#  '10821',
#  '10821',
#  '10893',
#  '10893',
#  '10947',
#  '10947',
#  '10965',
#  '10965',
#  '10971',
#  '10971',
#  '11001',
#  '11001',
#  '11031',
#  '11031',
#  '11049',
#  '11049',
#  '11055',
#  '11055',
#  '11079',
#  '11079',
#  '11127',
#  '11127',
#  '11109',
#  '11109',
#  '11115',
#  '11115',
#  '11121',
#  '11121',
#  '11127',
#  '11127',
#  '11181',
#  '11181',
#  '11199',
#  '11199',
#  '11223',
#  '11223',
#  '11229',
#  '11229',
#  '11265',
#  '11265',
#  '11283',
#  '11283',
#  '11295',
#  '11295',
#  '11331',
#  '11331',
#  '11353',
#  '11353',
#  '11365',
#  '11365',
#  '11395',
#  '11395',
#  '11401',
#  '11401',
#  '11419',
#  '11425',
#  '11425',
#  '11431',
#  '11431',
#  '11437',
#  '11437',
#  '11461',
#  '11461',
#  '11491',
#  '11491',
#  '11497',
#  '11497',
#  '11503',
#  '11503',
#  '11575',
#  '11575',
#  '11581',
#  '11581',
#  '11587',
#  '11587',
#  '11593',
#  '11593',
#  '11599',
#  '11599',
#  '11803',
#  '11803',
#  '11839',
#  '11839',
#  '11857',
#  '11857',
#  '11869',
#  '11869',
#  '11911',
#  '11911',
#  '11953',
#  '11953',
#  '12013',
#  '12013',
#  '12043',
#  '12043',
#  '12049',
#  '12049',
#  '12055',
#  '12055',
#  '12061',
#  '12061',
#  '12115',
#  '12115',
#  '12175',
#  '12175',
#  '12181',
#  '12181',
#  '12199',
#  '12199',
#  '12205',
#  '12205',
#  '12217',
#  '12217',
#  None,
#  '12239',
#  '12253',
#  '12253',
#  '12277',
#  '12277',
#  '12283',
#  '12283',
#  '12289',
#  '12289',
#  '12295',
#  '12295',
#  '12307',
#  '12307',
#  '12313',
#  '12313',
#  '12319',
#  '12319',
#  '12325',
#  '12325',
#  '12331',
#  '12331',
#  '12373',
#  '12373',
#  '12379',
#  '12379',
#  '12427',
#  '12427',
#  '12433',
#  '12433',
#  '12439',
#  '12439',
#  '12445',
#  '12445',
#  '12451',
#  '12451',
#  '12457',
#  '12457',
#  '12547',
#  '12547',
#  '12655',
#  '12655',
#  '12661',
#  '12661',
#  '12685',
#  '12685',
#  '12721',
#  '12721',
#  '12739',
#  '12739',
#  '12745',
#  '12745',
#  '12817',
#  '12817',
#  '12835',
#  '12835',
#  '12841',
#  '12841',
#  '12847',
#  '12847',
#  '12853',
#  '12853',
#  '12889',
#  '12889',
#  '12895',
#  '12895',
#  '12901',
#  '12901',
#  '12907',
#  '12907',
#  '12973',
#  '12973',
#  '12979',
#  '12979',
#  '12985',
#  '12985',
#  '12997',
#  '12997',
#  ...]

# %%
data_dict={'category_id':c_id,
'category_name':c_name}

# %%
df_category_table=pd.DataFrame(data_dict)

# %%
df_category_table
# Out:
#      category_id category_name
# 0            181    Hopman Cup
# 1              3           ATP
# 2             72    Challenger
# 3              6           WTA
# 4             76     Davis Cup
# ...          ...           ...
# 5877        2517     UTR Women
# 5878        2517     UTR Women
# 5879        2517     UTR Women
# 5880           3           ATP
# 5881           3           ATP
#
# [5882 rows x 2 columns]

# %%
df_category_table=df_category_table.drop_duplicates(subset=['category_id'])

# %%
data_dict2={'competition_id':Id,
           'competition_name':Name,
           'gender':gender,
           'parent_id':parent_id,
           'type':type,
           'category_id':c_id}

# %%
df_competition_Table=pd.DataFrame(data_dict2)

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('postgresql://postgres:1997@localhost:5432/Project')

# %%
from sqlalchemy import text
import psycopg2

# %%
#
df_competition_Table.to_sql('competition_table',engine,if_exists='replace',index=False)
# Out:
# 882

# %% [markdown]
# Next Project titile

# %%
import requests

url = "https://api.sportradar.com/tennis/trial/v3/en/complexes.json?api_key=gCNmEyNAwK1dQ2CMzKHz8bzSBjT7uNx77cdZNAEn"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)
data2=response.json()

# %%
data2
# Out:
# {'generated_at': '2025-02-05T11:15:06+00:00',
#  'complexes': [{'id': 'sr:complex:705',
#    'name': 'Nacional',
#    'venues': [{'id': 'sr:venue:70045',
#      'name': 'Cancha Central',
#      'city_name': 'Santiago',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'}]},
#   {'id': 'sr:complex:1078',
#    'name': 'Estadio de la Cartuja',
#    'venues': [{'id': 'sr:venue:74856',
#      'name': 'Centre Court',
#      'city_name': 'Seville',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:74858',
#      'name': 'Court One',
#      'city_name': 'Seville',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'}]},
#   {'id': 'sr:complex:1495',
#    'name': 'Sibur Arena',
#    'venues': [{'id': 'sr:venue:1496',
#      'name': 'COURT 1',
#      'city_name': 'Saint Petersburg',
#      'country_name': 'Russia',
#      'country_code': 'RUS',
#      'timezone': 'Europe/Moscow'},
#     {'id': 'sr:venue:1500',
#      'name': 'CENTER COURT',
#      'city_name': 'Saint Petersburg',
#      'country_name': 'Russia',
#      'country_code': 'RUS',
#      'timezone': 'Europe/Moscow'},
#     {'id': 'sr:venue:62149',
#      'name': 'Sibur Arena',
#      'city_name': 'Saint Petersburg',
#      'country_name': 'Russia',
#      'country_code': 'RUS',
#      'timezone': 'Europe/Moscow'},
#     {'id': 'sr:venue:62153',
#      'name': 'TC Dynamo',
#      'city_name': 'Saint Petersburg',
#      'country_name': 'Russia',
#      'country_code': 'RUS',
#      'timezone': 'Europe/Moscow'}]},
#   {'id': 'sr:complex:2375',
#    'name': 'Complexo de Tenis do Jamor',
#    'venues': [{'id': 'sr:venue:57912',
#      'name': 'Central',
#      'city_name': 'Oeiras',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:70805',
#      'name': 'Campo 3',
#      'city_name': 'Oeiras',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:70807',
#      'name': 'Campo 4',
#      'city_name': 'Oeiras',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:77423',
#      'name': 'Campo 1',
#      'city_name': 'Oeiras',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:77437',
#      'name': 'Campo 8',
#      'city_name': 'Oeiras',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'}]},
#   {'id': 'sr:complex:4032', 'name': 'Shree Shiv Chhatrapati Sports Complex'},
#   {'id': 'sr:complex:5520', 'name': 'O2 Arena'},
#   {'id': 'sr:complex:5526',
#    'name': 'Ostravar Arena',
#    'venues': [{'id': 'sr:venue:13912',
#      'name': 'Centre Court',
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'},
#     {'id': 'sr:venue:13914',
#      'name': 'Court 3',
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'},
#     {'id': 'sr:venue:13916',
#      'name': 'Court 6',
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'},
#     {'id': 'sr:venue:13942',
#      'name': 'Court 4',
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'},
#     {'id': 'sr:venue:55221',
#      'name': 'Court 1',
#      'capacity': 1,
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'},
#     {'id': 'sr:venue:55223',
#      'name': 'Court 2',
#      'capacity': 1,
#      'city_name': 'Ostrava',
#      'country_name': 'Czechia',
#      'country_code': 'CZE',
#      'timezone': 'Europe/Prague'}]},
#   {'id': 'sr:complex:6310',
#    'name': 'Varazdin Arena',
#    'venues': [{'id': 'sr:venue:77271',
#      'name': 'Table 1',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77273',
#      'name': 'Table 2',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77275',
#      'name': 'Table 3',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77277',
#      'name': 'Table 4',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77279',
#      'name': 'Table 5',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77281',
#      'name': 'Table 6',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77283',
#      'name': 'Table 7',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:77285',
#      'name': 'Table 8',
#      'city_name': 'Varazdin',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'}]},
#   {'id': 'sr:complex:6484',
#    'name': 'Arena Montpellier',
#    'venues': [{'id': 'sr:venue:2146',
#      'name': 'Court 1',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:19477',
#      'name': 'Court Patrice Dominguez',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:30567',
#      'name': 'Court Central',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:30569',
#      'name': 'Court 2',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:39934',
#      'name': 'Court 3',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:6736', 'name': 'Arenes de Metz'},
#   {'id': 'sr:complex:6888', 'name': 'Palais des sports de Pau'},
#   {'id': 'sr:complex:6890',
#    'name': 'Palais des Sports Orleans',
#    'venues': [{'id': 'sr:venue:66107',
#      'name': 'Court 2',
#      'city_name': 'Orchies',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66109',
#      'name': 'Court 3',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66111',
#      'name': 'Court 4',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:70605',
#      'name': 'Court 5',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:74195',
#      'name': 'Center Court',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:74197',
#      'name': 'Court 1',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:6904', 'name': 'Stade Pierre-de-Coubertin'},
#   {'id': 'sr:complex:7048',
#    'name': 'Palacio de Deportes Jose Maria Martin Carpena',
#    'venues': [{'id': 'sr:venue:72565',
#      'name': 'Pista Cental',
#      'city_name': 'Malaga',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:72567',
#      'name': 'Pista 2',
#      'city_name': 'Malaga',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:72569',
#      'name': 'Pista 3',
#      'city_name': 'Malaga',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:72571',
#      'name': 'Pista 4',
#      'city_name': 'Malaga',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'}]},
#   {'id': 'sr:complex:7052', 'name': 'Pabellon Municipal Fuente San Luis'},
#   {'id': 'sr:complex:7208', 'name': 'Unipol Arena'},
#   {'id': 'sr:complex:7778', 'name': 'Arena Gripe'},
#   {'id': 'sr:complex:9725',
#    'name': 'Arena Armeets Sofia',
#    'venues': [{'id': 'sr:venue:17756',
#      'name': 'Center Court',
#      'city_name': 'Sofia',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'},
#     {'id': 'sr:venue:17758',
#      'name': 'Court 1',
#      'city_name': 'Sofia',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'},
#     {'id': 'sr:venue:23352',
#      'name': 'Court 3',
#      'city_name': 'Sofia',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'},
#     {'id': 'sr:venue:23354',
#      'name': 'Court 4',
#      'city_name': 'Sofia',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'},
#     {'id': 'sr:venue:23356',
#      'name': 'Court 2',
#      'city_name': 'Sofia',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'}]},
#   {'id': 'sr:complex:10063',
#    'name': 'Kindarena',
#    'venues': [{'id': 'sr:venue:66889',
#      'name': 'Center Court',
#      'city_name': 'Rouen',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66925',
#      'name': 'Amelie Mauresmo',
#      'city_name': 'Rouen',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66979',
#      'name': 'Celine Dumerc',
#      'city_name': 'Rouen',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:74546',
#      'name': 'Court 1',
#      'city_name': 'Rouen',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:11769',
#    'name': 'Estadio German Becker',
#    'venues': [{'id': 'sr:venue:67857',
#      'name': 'Cancha Central',
#      'city_name': 'Temuco',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'},
#     {'id': 'sr:venue:67859',
#      'name': 'Cancha 1',
#      'city_name': 'Temuco',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'},
#     {'id': 'sr:venue:67861',
#      'name': 'Cancha 2',
#      'city_name': 'Temuco',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'},
#     {'id': 'sr:venue:67863',
#      'name': 'Cancha 3',
#      'city_name': 'Temuco',
#      'country_name': 'Chile',
#      'country_code': 'CHL',
#      'timezone': 'America/Santiago'}]},
#   {'id': 'sr:complex:12241',
#    'name': 'Palais des sports de Gerland',
#    'venues': [{'id': 'sr:venue:30465',
#      'name': 'Indoor 1',
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:30467',
#      'name': 'Indoor 2',
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:30469',
#      'name': 'Indoor 3',
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:39773',
#      'name': 'Court 23',
#      'capacity': 1,
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:39842',
#      'name': 'Court 14',
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:39844',
#      'name': 'Court 15',
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:58692',
#      'name': 'Court 12',
#      'capacity': 1,
#      'city_name': 'Lyon',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:15014',
#    'name': 'Palais Des Sport',
#    'venues': [{'id': 'sr:venue:15010',
#      'name': 'La Foret 3',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:16880',
#      'name': 'Central Court',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:23652',
#      'name': 'La Foret 2',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66105',
#      'name': 'Court 1',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66137',
#      'name': 'La Foret 4',
#      'capacity': 1,
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:66139',
#      'name': 'La Foret 1',
#      'capacity': 1,
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:70603',
#      'name': 'Court 2',
#      'city_name': 'Orleans',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:15371',
#    'name': 'Palasport',
#    'venues': [{'id': 'sr:venue:67869',
#      'name': 'Court 2',
#      'city_name': 'Andria',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:67871',
#      'name': 'Court 3',
#      'city_name': 'Andria',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:68095',
#      'name': 'Campo Tato Paride',
#      'city_name': 'Andria',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:68097',
#      'name': 'Campo Arpex',
#      'city_name': 'Andria',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'}]},
#   {'id': 'sr:complex:16020',
#    'name': 'Salle Steredenn',
#    'venues': [{'id': 'sr:venue:16022',
#      'name': 'Atg 3',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:18015',
#      'name': 'Atg 4',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:28371',
#      'name': 'Tcsb 4',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:28373',
#      'name': 'Tcsb 3',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:62697',
#      'name': 'Court Steredenn',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:80523',
#      'name': 'Court TCSB',
#      'city_name': 'Saint-Brieuc',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:16069',
#    'name': 'Garanti Koza Arena',
#    'venues': [{'id': 'sr:venue:14874',
#      'name': 'Court Limak Enerji',
#      'city_name': 'Istanbul',
#      'country_name': 'Turkiye',
#      'country_code': 'TUR',
#      'timezone': 'Europe/Istanbul'}]},
#   {'id': 'sr:complex:16612',
#    'name': 'Porsche-Arena',
#    'venues': [{'id': 'sr:venue:1765',
#      'name': 'Centre Court',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:77411',
#      'name': 'Court 1',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:77413',
#      'name': 'Court 2',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'}]},
#   {'id': 'sr:complex:17254', 'name': "Poliesportiu d'Andorra"},
#   {'id': 'sr:complex:17945',
#    'name': 'Rotterdam Ahoy',
#    'venues': [{'id': 'sr:venue:1648',
#      'name': 'Court 1',
#      'city_name': 'Rotterdam',
#      'country_name': 'Netherlands',
#      'country_code': 'NLD',
#      'timezone': 'Europe/Brussels'},
#     {'id': 'sr:venue:3696',
#      'name': 'Court 2',
#      'city_name': 'Rotterdam',
#      'country_name': 'Netherlands',
#      'country_code': 'NLD',
#      'timezone': 'Europe/Brussels'},
#     {'id': 'sr:venue:22854',
#      'name': 'Centre Court',
#      'city_name': 'Rotterdam',
#      'country_name': 'Netherlands',
#      'country_code': 'NLD',
#      'timezone': 'Europe/Brussels'}]},
#   {'id': 'sr:complex:18201',
#    'name': 'The O2',
#    'venues': [{'id': 'sr:venue:66121',
#      'name': 'Centre Court',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'}]},
#   {'id': 'sr:complex:18221',
#    'name': 'Bluesun Tennis Center',
#    'venues': [{'id': 'sr:venue:18223',
#      'name': 'Cedevita Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:18225',
#      'name': 'Cockta Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:18227',
#      'name': 'Kala Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:21412',
#      'name': 'INA Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:21422',
#      'name': 'Raiffeisen Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:30195',
#      'name': 'Lukas Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:39715',
#      'name': 'Center Court',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'},
#     {'id': 'sr:venue:39717',
#      'name': 'Court 1',
#      'city_name': 'Bol',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'}]},
#   {'id': 'sr:complex:19166', 'name': 'Shlomo Group Arena'},
#   {'id': 'sr:complex:19737',
#    'name': 'Club Sonoma, Estadio Gnp Seguros',
#    'venues': [{'id': 'sr:venue:1695',
#      'name': 'Center Court',
#      'city_name': 'Monterrey',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:1696',
#      'name': 'Court 1',
#      'city_name': 'Monterrey',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:62341',
#      'name': 'Court 4',
#      'city_name': 'Monterrey',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'}]},
#   {'id': 'sr:complex:19951',
#    'name': 'Accor Arena',
#    'venues': [{'id': 'sr:venue:1520',
#      'name': 'Court Central',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1521',
#      'name': 'Court 1',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1522',
#      'name': 'Court 2',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:21870',
#    'name': 'Stadium Goran Ivanisevic in ITC Stella Maris',
#    'venues': [{'id': 'sr:venue:21868',
#      'name': 'Next Gen Arena',
#      'city_name': 'Umag',
#      'country_name': 'Croatia',
#      'country_code': 'HRV',
#      'timezone': 'Europe/Zagreb'}]},
#   {'id': 'sr:complex:21910',
#    'name': 'Roy Emerson Arena',
#    'venues': [{'id': 'sr:venue:1938',
#      'name': 'Roy Emerson Arena',
#      'city_name': 'Gstaad',
#      'country_name': 'Switzerland',
#      'country_code': 'CHE',
#      'timezone': 'Europe/Zurich'},
#     {'id': 'sr:venue:1939',
#      'name': 'Court 1',
#      'city_name': 'Gstaad',
#      'country_name': 'Switzerland',
#      'country_code': 'CHE',
#      'timezone': 'Europe/Zurich'},
#     {'id': 'sr:venue:1953',
#      'name': 'Sportzentrum 1',
#      'city_name': 'Gstaad',
#      'country_name': 'Switzerland',
#      'country_code': 'CHE',
#      'timezone': 'Europe/Zurich'},
#     {'id': 'sr:venue:2461',
#      'name': 'Sportzentrum 3',
#      'city_name': 'Gstaad',
#      'country_name': 'Switzerland',
#      'country_code': 'CHE',
#      'timezone': 'Europe/Zurich'}]},
#   {'id': 'sr:complex:26983',
#    'name': 'Club de Tenis Puente Romano',
#    'venues': [{'id': 'sr:venue:1728',
#      'name': 'Centre Court',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:1729',
#      'name': 'Court 1',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:1730',
#      'name': 'Court 7',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:28357',
#      'name': 'Court 2',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:33908',
#      'name': 'Court 3',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:33916',
#      'name': 'Court 4',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:57732',
#      'name': 'Estadio Manolo Santana',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:62729',
#      'name': 'Court 8',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:62731',
#      'name': 'Court 9',
#      'city_name': 'Marbella',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'}]},
#   {'id': 'sr:complex:26985',
#    'name': 'National Tennis Center',
#    'venues': [{'id': 'sr:venue:1383',
#      'name': 'Astana Arena',
#      'capacity': 30000,
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'map_coordinates': '51.108244,71.402584',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:2595',
#      'name': 'Astana',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:14620',
#      'name': 'Center Court',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:14622',
#      'name': 'Court 1',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:14624',
#      'name': 'Court 2',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:14626',
#      'name': 'Court 3',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:14628',
#      'name': 'Court 6',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:18439',
#      'name': 'Court 4',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:31557',
#      'name': 'Court 9',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:32005',
#      'name': 'Indoor Center Court',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:43100',
#      'name': 'Court 5',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'},
#     {'id': 'sr:venue:59164',
#      'name': 'Indoor Court 3',
#      'city_name': 'Astana',
#      'country_name': 'Kazakhstan',
#      'country_code': 'KAZ',
#      'timezone': 'Asia/Almaty'}]},
#   {'id': 'sr:complex:27093',
#    'name': 'Canberra Tennis Centre',
#    'venues': [{'id': 'sr:venue:25218',
#      'name': 'Court 4',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:25292',
#      'name': 'Centre Court',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:25296',
#      'name': 'Court 7',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:25298',
#      'name': 'Court 5',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:68975',
#      'name': 'Court 1',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:68977',
#      'name': 'Court 6',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'},
#     {'id': 'sr:venue:75825',
#      'name': 'Court 2',
#      'city_name': 'Canberra',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/ACT'}]},
#   {'id': 'sr:complex:27095',
#    'name': 'BT Arena',
#    'venues': [{'id': 'sr:venue:59476',
#      'name': 'Center Court',
#      'city_name': 'Cluj Napoca',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'},
#     {'id': 'sr:venue:59478',
#      'name': 'Court 2',
#      'city_name': 'Cluj Napoca',
#      'country_name': 'Romania',
#      'country_code': 'ROU',
#      'timezone': 'Europe/Bucharest'}]},
#   {'id': 'sr:complex:28457',
#    'name': 'Valletta Cambiaso ASD',
#    'venues': [{'id': 'sr:venue:14846',
#      'name': 'Center Court',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:14848',
#      'name': 'Court 1',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:14850',
#      'name': 'Court 2',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:14852',
#      'name': 'Campo 3',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:58750',
#      'name': 'Court 3',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:58754',
#      'name': 'Court 4',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:66059',
#      'name': 'Centrale',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:66061',
#      'name': 'Campo 1',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'},
#     {'id': 'sr:venue:66063',
#      'name': 'Campo 2',
#      'city_name': 'Genoa',
#      'country_name': 'Italy',
#      'country_code': 'ITA',
#      'timezone': 'Europe/Rome'}]},
#   {'id': 'sr:complex:28617',
#    'name': 'Porsche Arena',
#    'venues': [{'id': 'sr:venue:1766',
#      'name': 'Court 1',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:2345',
#      'name': 'Court 2',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:2421',
#      'name': 'Court 18',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:16273',
#      'name': 'Court 3',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'},
#     {'id': 'sr:venue:30921',
#      'name': 'Court 4',
#      'city_name': 'Stuttgart',
#      'country_name': 'Germany',
#      'country_code': 'DEU',
#      'timezone': 'Europe/Berlin'}]},
#   {'id': 'sr:complex:28926',
#    'name': 'Royal Arena',
#    'venues': [{'id': 'sr:venue:73239',
#      'name': 'Court 1',
#      'city_name': 'Copenhagen',
#      'country_name': 'Denmark',
#      'country_code': 'DNK',
#      'timezone': 'Europe/Copenhagen'},
#     {'id': 'sr:venue:73241',
#      'name': 'Court 2',
#      'city_name': 'Copenhagen',
#      'country_name': 'Denmark',
#      'country_code': 'DNK',
#      'timezone': 'Europe/Copenhagen'},
#     {'id': 'sr:venue:73243',
#      'name': 'Court 3',
#      'city_name': 'Copenhagen',
#      'country_name': 'Denmark',
#      'country_code': 'DNK',
#      'timezone': 'Europe/Copenhagen'},
#     {'id': 'sr:venue:73245',
#      'name': 'Court 4',
#      'city_name': 'Copenhagen',
#      'country_name': 'Denmark',
#      'country_code': 'DNK',
#      'timezone': 'Europe/Copenhagen'}]},
#   {'id': 'sr:complex:32327',
#    'name': 'Taipei Arena',
#    'venues': [{'id': 'sr:venue:13904',
#      'name': 'Centre Court',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:13906',
#      'name': 'Court 2',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:15298',
#      'name': 'Court 1',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31685',
#      'name': 'Court 3',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31687',
#      'name': 'Show court',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31689',
#      'name': 'Court 4',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31947',
#      'name': 'Court 6',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31951',
#      'name': 'Court 7',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31953',
#      'name': 'Court 5',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'},
#     {'id': 'sr:venue:31955',
#      'name': 'Court 8',
#      'city_name': 'Taipei',
#      'country_name': 'Chinese Taipei',
#      'country_code': 'TPE',
#      'timezone': 'Asia/Taipei'}]},
#   {'id': 'sr:complex:32403', 'name': 'Ohio State University GC'},
#   {'id': 'sr:complex:32668', 'name': 'Shenzhen Bay Sports Center'},
#   {'id': 'sr:complex:32812',
#    'name': 'Singapore Indoor Stadium',
#    'venues': [{'id': 'sr:venue:15250',
#      'name': 'Centre Court',
#      'city_name': 'Kallang',
#      'country_name': 'Singapore',
#      'country_code': 'SGP',
#      'timezone': 'Asia/Singapore'},
#     {'id': 'sr:venue:71439',
#      'name': 'Court 2',
#      'city_name': 'Kallang',
#      'country_name': 'Singapore',
#      'country_code': 'SGP',
#      'timezone': 'Asia/Singapore'},
#     {'id': 'sr:venue:71441',
#      'name': 'Court 3',
#      'city_name': 'Kallang',
#      'country_name': 'Singapore',
#      'country_code': 'SGP',
#      'timezone': 'Asia/Singapore'},
#     {'id': 'sr:venue:71443',
#      'name': 'Court 4',
#      'city_name': 'Kallang',
#      'country_name': 'Singapore',
#      'country_code': 'SGP',
#      'timezone': 'Asia/Singapore'}]},
#   {'id': 'sr:complex:33186',
#    'name': 'Palais des Sports de Marseille',
#    'venues': [{'id': 'sr:venue:1665',
#      'name': 'Central',
#      'city_name': 'Marseille',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1666',
#      'name': 'Court 1',
#      'city_name': 'Marseille',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:38311',
#      'name': 'Court 2',
#      'city_name': 'Marseille',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:33188',
#    'name': 'Caja Magica',
#    'venues': [{'id': 'sr:venue:56690',
#      'name': 'Pista 2',
#      'city_name': 'Madrid',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:56692',
#      'name': 'Pista 3',
#      'city_name': 'Madrid',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'},
#     {'id': 'sr:venue:68305',
#      'name': 'Court Central',
#      'city_name': 'Madrid',
#      'country_name': 'Spain',
#      'country_code': 'ESP',
#      'timezone': 'Europe/Madrid'}]},
#   {'id': 'sr:complex:33190',
#    'name': 'All England Lawn Tennis and Croquet Club',
#    'venues': [{'id': 'sr:venue:1846',
#      'name': 'Court 1',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1848',
#      'name': 'Court 9',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1849',
#      'name': 'Court 10',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1855',
#      'name': 'Court 3',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1856',
#      'name': 'Court 12',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1884',
#      'name': 'Court 4',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1886',
#      'name': 'Court 6',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1887',
#      'name': 'Court 7',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1888',
#      'name': 'Court 8',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1889',
#      'name': 'Court 11',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1890',
#      'name': 'Court 13',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1891',
#      'name': 'Court 14',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1892',
#      'name': 'Court 15',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1893',
#      'name': 'Court 16',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1894',
#      'name': 'Court 18',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:1900',
#      'name': 'Court 17',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:19070',
#      'name': 'Centre Court',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:21634',
#      'name': 'Court 2',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'},
#     {'id': 'sr:venue:21642',
#      'name': 'Court 5',
#      'city_name': 'London',
#      'country_name': 'England',
#      'country_code': 'ENG',
#      'timezone': 'Europe/London'}]},
#   {'id': 'sr:complex:33192',
#    'name': 'Stade Roland Garros',
#    'venues': [{'id': 'sr:venue:1809',
#      'name': 'Court 6',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1810',
#      'name': 'Court 7',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1811',
#      'name': 'Court 8',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1812',
#      'name': 'Court 9',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1813',
#      'name': 'Court 10',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1814',
#      'name': 'Court 11',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1815',
#      'name': 'Court 12',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1816',
#      'name': 'Court 13',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1817',
#      'name': 'Court 14',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1818',
#      'name': 'Court 15',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1819',
#      'name': 'Court 16',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1826',
#      'name': 'Court Philippe Chatrier',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1827',
#      'name': 'Court Suzanne Lenglen',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1828',
#      'name': 'Court 3',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1829',
#      'name': 'Court 4',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:1830',
#      'name': 'Court 5',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:39589',
#      'name': 'Court Simonne Mathieu',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:33194', 'name': 'Complexe Al Amal'},
#   {'id': 'sr:complex:33196',
#    'name': 'Melbourne Park',
#    'venues': [{'id': 'sr:venue:1572',
#      'name': 'Court 3',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1573',
#      'name': 'Court 4',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1574',
#      'name': 'Court 5',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1575',
#      'name': 'Court 6',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1576',
#      'name': 'Court 7',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1577',
#      'name': 'Court 8',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1578',
#      'name': 'Court 10',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1579',
#      'name': 'Court 11',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1580',
#      'name': 'Court 9',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1581',
#      'name': 'Court 12',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1582',
#      'name': 'Court 13',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1583',
#      'name': 'Court 14',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1584',
#      'name': 'Court 15',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1586',
#      'name': 'Rod Laver Arena',
#      'capacity': 14820,
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1587',
#      'name': 'John Cain Arena',
#      'capacity': 10500,
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'map_coordinates': '-37.822568, 144.980913',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1588',
#      'name': 'Margaret Court Arena',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1589',
#      'name': '1573 Arena',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1590',
#      'name': 'Court 18',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1591',
#      'name': 'Court 19',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:1592',
#      'name': 'Court 21',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:10536',
#      'name': 'Court 20',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:10538',
#      'name': 'Court 22',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:57064',
#      'name': 'Court 16',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:57072',
#      'name': 'Court 17',
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'},
#     {'id': 'sr:venue:61865',
#      'name': 'Kia Arena',
#      'capacity': 5000,
#      'city_name': 'Melbourne',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
#      'timezone': 'Australia/Melbourne'}]},
#   {'id': 'sr:complex:33198',
#    'name': 'Qi zhong Forest Sports City Arena',
#    'venues': [{'id': 'sr:venue:23520',
#      'name': 'Indoor West',
#      'city_name': 'Shanghai',
#      'country_name': 'China',
#      'country_code': 'CHN',
#      'timezone': 'Asia/Shanghai'},
#     {'id': 'sr:venue:24396',
#      'name': 'Indoor 1',
#      'city_name': 'Shanghai',
#      'country_name': 'China',
#      'country_code': 'CHN',
#      'timezone': 'Asia/Shanghai'}]},
#   {'id': 'sr:complex:33200',
#    'name': 'Wake Forest University Tennis Complex',
#    'venues': [{'id': 'sr:venue:2575',
#      'name': 'Center Court',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:2577',
#      'name': 'Court 2',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:2579',
#      'name': 'Court 3',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:2581',
#      'name': 'Court 4',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:2583',
#      'name': 'Court 5',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:16760',
#      'name': 'Stadium',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'}]},
#   {'id': 'sr:complex:33204', 'name': 'Clube de Ténis do Estoril'},
#   {'id': 'sr:complex:33206',
#    'name': 'The Drive',
#    'venues': [{'id': 'sr:venue:49715',
#      'name': 'Show Court 1',
#      'city_name': 'Adelaide',
#      'country_name': 'Australia',
#      'country_code': 'AUS',
# ...
#      'country_code': 'EGY',
#      'timezone': 'Africa/Cairo'},
#     {'id': 'sr:venue:79643',
#      'name': 'Court 5',
#      'city_name': 'Giza',
#      'country_name': 'Egypt',
#      'country_code': 'EGY',
#      'timezone': 'Africa/Cairo'},
#     {'id': 'sr:venue:79645',
#      'name': 'Court 6',
#      'city_name': 'Giza',
#      'country_name': 'Egypt',
#      'country_code': 'EGY',
#      'timezone': 'Africa/Cairo'},
#     {'id': 'sr:venue:79647',
#      'name': 'Court 7',
#      'city_name': 'Giza',
#      'country_name': 'Egypt',
#      'country_code': 'EGY',
#      'timezone': 'Africa/Cairo'},
#     {'id': 'sr:venue:79649',
#      'name': 'Court 8',
#      'city_name': 'Giza',
#      'country_name': 'Egypt',
#      'country_code': 'EGY',
#      'timezone': 'Africa/Cairo'},
#     {'id': 'sr:venue:79651',
#      'name': 'Court 9',
#      'city_name': 'Giza',
#      'country_name': 'Egypt',
#      'country_code': 'EGY',
#      'timezone': 'Africa/Cairo'},
#     {'id': 'sr:venue:79653',
#      'name': 'Court 10',
#      'city_name': 'Giza',
#      'country_name': 'Egypt',
#      'country_code': 'EGY',
#      'timezone': 'Africa/Cairo'}]},
#   {'id': 'sr:complex:79665',
#    'name': 'Montreux Tennis Club',
#    'venues': [{'id': 'sr:venue:33964',
#      'name': 'Central',
#      'city_name': 'Montreux',
#      'country_name': 'Switzerland',
#      'country_code': 'CHE',
#      'timezone': 'Europe/Zurich'},
#     {'id': 'sr:venue:33974',
#      'name': 'Court 1',
#      'city_name': 'Montreux',
#      'country_name': 'Switzerland',
#      'country_code': 'CHE',
#      'timezone': 'Europe/Zurich'}]},
#   {'id': 'sr:complex:79837',
#    'name': 'Club Campestre Farallones',
#    'venues': [{'id': 'sr:venue:79945',
#      'name': 'Cancha Central',
#      'city_name': 'Santiago de Cali',
#      'country_name': 'Colombia',
#      'country_code': 'COL',
#      'timezone': 'America/Bogota'},
#     {'id': 'sr:venue:79947',
#      'name': 'Cancha 1',
#      'city_name': 'Santiago de Cali',
#      'country_name': 'Colombia',
#      'country_code': 'COL',
#      'timezone': 'America/Bogota'},
#     {'id': 'sr:venue:79949',
#      'name': 'Cancha 2',
#      'city_name': 'Santiago de Cali',
#      'country_name': 'Colombia',
#      'country_code': 'COL',
#      'timezone': 'America/Bogota'}]},
#   {'id': 'sr:complex:79851', 'name': 'Fly Palmy Arena'},
#   {'id': 'sr:complex:79853', 'name': 'Tennis Club Lokomotiv'},
#   {'id': 'sr:complex:79855', 'name': 'Palm Hills Sports Club'},
#   {'id': 'sr:complex:79861',
#    'name': 'Tennis Club de Avenir Sportif de la Marsa'},
#   {'id': 'sr:complex:80737',
#    'name': 'International Tennis Center',
#    'venues': [{'id': 'sr:venue:80745',
#      'name': 'Center Court',
#      'city_name': 'Jiujiang',
#      'country_name': 'China',
#      'country_code': 'CHN',
#      'timezone': 'Asia/Shanghai'},
#     {'id': 'sr:venue:80747',
#      'name': 'Court 1',
#      'city_name': 'Jiujiang',
#      'country_name': 'China',
#      'country_code': 'CHN',
#      'timezone': 'Asia/Shanghai'},
#     {'id': 'sr:venue:80749',
#      'name': 'Court 2',
#      'city_name': 'Jiujiang',
#      'country_name': 'China',
#      'country_code': 'CHN',
#      'timezone': 'Asia/Shanghai'},
#     {'id': 'sr:venue:80811',
#      'name': 'Indoor 1',
#      'city_name': 'Jiujiang',
#      'country_name': 'China',
#      'country_code': 'CHN',
#      'timezone': 'Asia/Shanghai'}]},
#   {'id': 'sr:complex:80851',
#    'name': 'Beograndska Arena',
#    'venues': [{'id': 'sr:venue:80873',
#      'name': 'Centre Court',
#      'city_name': 'Belgrade',
#      'country_name': 'Serbia',
#      'country_code': 'SRB',
#      'timezone': 'Europe/Belgrade'},
#     {'id': 'sr:venue:80875',
#      'name': 'Grandstand',
#      'city_name': 'Belgrade',
#      'country_name': 'Serbia',
#      'country_code': 'SRB',
#      'timezone': 'Europe/Belgrade'}]},
#   {'id': 'sr:complex:80961', 'name': 'Inalpi Arena'},
#   {'id': 'sr:complex:80963',
#    'name': 'All In Country Club Decines',
#    'venues': [{'id': 'sr:venue:81011',
#      'name': 'COURT CENTRAL',
#      'city_name': 'Decines-Charpieu',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:81013',
#      'name': 'COURT 1',
#      'city_name': 'Decines-Charpieu',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'},
#     {'id': 'sr:venue:81015',
#      'name': 'COURT 2',
#      'city_name': 'Decines-Charpieu',
#      'country_name': 'France',
#      'country_code': 'FRA',
#      'timezone': 'Europe/Paris'}]},
#   {'id': 'sr:complex:81249',
#    'name': 'Las Hadas Golf & Country Club',
#    'venues': [{'id': 'sr:venue:81315',
#      'name': 'Cancha Central',
#      'city_name': 'Manzanillo',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:81317',
#      'name': 'Cancha 1',
#      'city_name': 'Manzanillo',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:81319',
#      'name': 'Cancha 2',
#      'city_name': 'Manzanillo',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:81321',
#      'name': 'Cancha 3',
#      'city_name': 'Manzanillo',
#      'country_name': 'Mexico',
#      'country_code': 'MEX',
#      'timezone': 'America/Mexico_City'}]},
#   {'id': 'sr:complex:81543',
#    'name': 'Headington Family Tennis Center',
#    'venues': [{'id': 'sr:venue:81559',
#      'name': 'Headington Family Tennis Center - Court 2',
#      'city_name': 'Norman',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:81561',
#      'name': 'Headington Family Tennis Center - Court 4',
#      'city_name': 'Norman',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:81571',
#      'name': 'Headington Family Tennis Center - Court 1',
#      'city_name': 'Norman',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:81573',
#      'name': 'Headington Family Tennis Center - Court 3',
#      'city_name': 'Norman',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:81575',
#      'name': 'Headington Family Tennis Center - Court 5',
#      'city_name': 'Norman',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:81581',
#      'name': 'Headington Family Tennis Center - Court 6',
#      'city_name': 'Norman',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'}]},
#   {'id': 'sr:complex:81613',
#    'name': 'Royal SC Tennis',
#    'venues': [{'id': 'sr:venue:81601',
#      'name': 'Royal SC Tennis - Court 02',
#      'city_name': 'Noda',
#      'country_name': 'Japan',
#      'country_code': 'JPN',
#      'timezone': 'Asia/Tokyo'},
#     {'id': 'sr:venue:81603',
#      'name': 'Royal SC Tennis - Court 04',
#      'city_name': 'Noda',
#      'country_name': 'Japan',
#      'country_code': 'JPN',
#      'timezone': 'Asia/Tokyo'},
#     {'id': 'sr:venue:81605',
#      'name': 'Royal SC Tennis - Court 06',
#      'city_name': 'Noda',
#      'country_name': 'Japan',
#      'country_code': 'JPN',
#      'timezone': 'Asia/Tokyo'},
#     {'id': 'sr:venue:81607',
#      'name': 'Royal SC Tennis - Court 05',
#      'city_name': 'Noda',
#      'country_name': 'Japan',
#      'country_code': 'JPN',
#      'timezone': 'Asia/Tokyo'},
#     {'id': 'sr:venue:81609',
#      'name': 'Royal SC Tennis - Court 03',
#      'city_name': 'Noda',
#      'country_name': 'Japan',
#      'country_code': 'JPN',
#      'timezone': 'Asia/Tokyo'},
#     {'id': 'sr:venue:81611',
#      'name': 'Royal SC Tennis - Court 01',
#      'city_name': 'Noda',
#      'country_name': 'Japan',
#      'country_code': 'JPN',
#      'timezone': 'Asia/Tokyo'}]},
#   {'id': 'sr:complex:81635',
#    'name': 'LSU',
#    'venues': [{'id': 'sr:venue:81593',
#      'name': 'LSU - Court 04',
#      'city_name': 'Baton Rouge',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:81595',
#      'name': 'LSU - Court 02',
#      'city_name': 'Baton Rouge',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:81621',
#      'name': 'LSU - Court 03',
#      'city_name': 'Baton Rouge',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:81623',
#      'name': 'LSU - Court 01',
#      'city_name': 'Baton Rouge',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'},
#     {'id': 'sr:venue:81691',
#      'name': 'LSU - Court 06',
#      'city_name': 'Baton Rouge',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Chicago'}]},
#   {'id': 'sr:complex:81651',
#    'name': 'Robson Tennis Center',
#    'venues': [{'id': 'sr:venue:81615',
#      'name': 'Robson Tennis Center - Court 1',
#      'city_name': 'Tucson',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Phoenix'},
#     {'id': 'sr:venue:81617',
#      'name': 'Robson Tennis Center - Court 2',
#      'city_name': 'Tucson',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Phoenix'},
#     {'id': 'sr:venue:81649',
#      'name': 'Robson Tennis Center - Court 3',
#      'city_name': 'Tucson',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Phoenix'}]},
#   {'id': 'sr:complex:81661',
#    'name': 'Wake Forest Tennis Center',
#    'venues': [{'id': 'sr:venue:81407',
#      'name': 'Wake Forest Tennis Center - Indoor - Court 01',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:81409',
#      'name': 'Wake Forest Tennis Center - Indoor - Court 02',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:81411',
#      'name': 'Wake Forest Tennis Center - Indoor - Court 03',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:81413',
#      'name': 'Wake Forest Tennis Center - Indoor - Court 04',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:81415',
#      'name': 'Wake Forest Tennis Center - Indoor - Court 05',
#      'city_name': 'Winston Salem',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'}]},
#   {'id': 'sr:complex:81673',
#    'name': 'Palmira Tennis Club',
#    'venues': [{'id': 'sr:venue:81675',
#      'name': 'Palmira Tennis Club - Court 04',
#      'city_name': 'Bonita Springs',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Los_Angeles'},
#     {'id': 'sr:venue:81677',
#      'name': 'Palmira Tennis Club - Court 02',
#      'city_name': 'Bonita Springs',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Los_Angeles'},
#     {'id': 'sr:venue:81679',
#      'name': 'Palmira Tennis Club - Court 01',
#      'city_name': 'Bonita Springs',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Los_Angeles'},
#     {'id': 'sr:venue:81693',
#      'name': 'Court 1',
#      'city_name': 'Florida City (FL)',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:81695',
#      'name': 'Court 2',
#      'city_name': 'Florida City (FL)',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Mexico_City'},
#     {'id': 'sr:venue:81697',
#      'name': 'Court 4',
#      'city_name': 'Florida City (FL)',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/Mexico_City'}]},
#   {'id': 'sr:complex:81681',
#    'name': 'Tennis Courts of the SW University Neofit Rilski',
#    'venues': [{'id': 'sr:venue:81683',
#      'name': 'Tennis Courts of the SW University Neofit Rilski - Court 3',
#      'city_name': 'Blagoevgrad',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'},
#     {'id': 'sr:venue:81687',
#      'name': 'Tennis Courts of the SW University Neofit Rilski - Court 1',
#      'city_name': 'Blagoevgrad',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'},
#     {'id': 'sr:venue:81689',
#      'name': 'Tennis Courts of the SW University Neofit Rilski - Court 2',
#      'city_name': 'Blagoevgrad',
#      'country_name': 'Bulgaria',
#      'country_code': 'BGR',
#      'timezone': 'Europe/Sofia'}]},
#   {'id': 'sr:complex:81713',
#    'name': 'Penina Hotel & Golf Resort',
#    'venues': [{'id': 'sr:venue:81715',
#      'name': 'Penina Hotel & Golf Resort - 2. FREDGIL',
#      'city_name': 'Alvor',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:81741',
#      'name': 'Clube Tenis Portimao - Court FREDGIL (Indoor)',
#      'city_name': 'Alvor',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:81743',
#      'name': 'Clube Tenis Portimao - Court Portimão (Indoor)',
#      'city_name': 'Alvor',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:81755',
#      'name': 'Penina Hotel & Golf Resort - 4. Court Gold Nutrition',
#      'city_name': 'Alvor',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:81757',
#      'name': 'Penina Hotel and Golf Resort - 3. Court Portimao',
#      'city_name': 'Alvor',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'},
#     {'id': 'sr:venue:81759',
#      'name': 'Penina Hotel and Golf Resort - 1. Court Penina',
#      'city_name': 'Alvor',
#      'country_name': 'Portugal',
#      'country_code': 'PRT',
#      'timezone': 'Europe/Lisbon'}]},
#   {'id': 'sr:complex:81717',
#    'name': 'Bloomington',
#    'venues': [{'id': 'sr:venue:81719',
#      'name': 'Bloomington - Court 8',
#      'city_name': 'Bloomington',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:81721',
#      'name': 'Bloomington - Court 7',
#      'city_name': 'Bloomington',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:81723',
#      'name': 'Bloomington - Court 6',
#      'city_name': 'Bloomington',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'},
#     {'id': 'sr:venue:81725',
#      'name': 'Bloomington - Court 5',
#      'city_name': 'Bloomington',
#      'country_name': 'USA',
#      'country_code': 'USA',
#      'timezone': 'America/New_York'}]},
#   {'id': 'sr:complex:81745', 'name': 'Clube Tenis Portimao'},
#   {'id': 'sr:complex:81751',
#    'name': 'Kallang Tennis Centre',
#    'venues': [{'id': 'sr:venue:81765',
#      'name': 'Center Court',
#      'city_name': 'Singapore City',
#      'country_name': 'Singapore',
#      'country_code': 'SGP',
#      'timezone': 'Asia/Singapore'},
#     {'id': 'sr:venue:81767',
#      'name': 'Court 1',
#      'city_name': 'Singapore City',
#      'country_name': 'Singapore',
#      'country_code': 'SGP',
#      'timezone': 'Asia/Singapore'}]},
#   {'id': 'sr:complex:81809',
#    'name': 'Courts De Tennis De La Cité Nationale Sportive El Menza'},
#   {'id': 'sr:complex:81811', 'name': 'Sala Polivalenta Craiova'},
#   {'id': 'sr:complex:81813', 'name': 'New Sport Palace'},
#   {'id': 'sr:complex:81815', 'name': 'Complejo de Raquetas'},
#   {'id': 'sr:complex:81817', 'name': 'DLTA Complex'},
#   {'id': 'sr:complex:81819', 'name': 'Monte-Carlo Country Club'},
#   {'id': 'sr:complex:81821', 'name': 'TENIS ESKRIM DAGCILIK KULÜBÜ'},
#   {'id': 'sr:complex:81823', 'name': 'Beeline Arena'},
#   {'id': 'sr:complex:81827', 'name': 'Coque Luxenbourg'}]}

# %%
complex_id=[]
complex_name=[]

# %%
data_compex={'complex_id':complex_id,
             'complex_name':complex_name}

# %%
comp_table=pd.DataFrame(data_compex)

# %%
comp_table.to_sql('complexes_table',engine,if_exists='replace',index=False)
# Out:
# 632

# %%
for i in data2['complexes']:
    complex_id.append(i['id'].split(':')[-1])
    complex_name.append(i['name'])

# %%
venues_id=[]
venues_name=[]
city_name=[]
country_name=[]
country_code=[]
timezone=[]
complex_id=[]

# %%
country_name
# Out:
# ['Chile',
#  'Spain',
#  'Spain',
#  'Russia',
#  'Russia',
#  'Russia',
#  'Russia',
#  'Portugal',
#  'Portugal',
#  'Portugal',
#  'Portugal',
#  'Portugal',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'France',
#  'France',
#  'France',
#  'France',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'Turkiye',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Netherlands',
#  'Netherlands',
#  'Netherlands',
#  'England',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'France',
#  'France',
#  'France',
#  'Croatia',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Romania',
#  'Romania',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Chinese Taipei',
#  'Singapore',
#  'Singapore',
#  'Singapore',
#  'Singapore',
#  'France',
#  'France',
#  'France',
#  'Spain',
#  'Spain',
#  'Spain',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'China',
#  'China',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'Luxembourg',
#  'Luxembourg',
#  'Luxembourg',
#  'Luxembourg',
#  'Luxembourg',
#  'Russia',
#  'Russia',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Uzbekistan',
#  'Uzbekistan',
#  'China',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'Morocco',
#  'Morocco',
#  'Morocco',
#  'Morocco',
#  'Morocco',
#  'Morocco',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Qatar',
#  'Qatar',
#  'Qatar',
#  'Qatar',
#  'Qatar',
#  'Qatar',
#  'Qatar',
#  'Qatar',
#  'Qatar',
#  'Qatar',
#  'Qatar',
#  'Qatar',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'Mexico',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Austria',
#  'Austria',
#  'China',
#  'China',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Germany',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'England',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Netherlands',
#  'Netherlands',
#  'Netherlands',
#  'Netherlands',
#  'Netherlands',
#  'Netherlands',
#  'Netherlands',
#  'Romania',
#  'Romania',
#  'Romania',
#  'Romania',
#  'Romania',
#  'Romania',
#  'Romania',
#  'Romania',
#  'Romania',
#  'Romania',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'France',
#  'France',
#  'France',
#  'France',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Switzerland',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Serbia',
#  'Serbia',
#  'Serbia',
#  'Serbia',
#  'Serbia',
#  'Serbia',
#  'Serbia',
#  'Serbia',
#  'Serbia',
#  'Serbia',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Thailand',
#  'Thailand',
#  'Thailand',
#  'Thailand',
#  'Thailand',
#  'Thailand',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Slovenia',
#  'Slovenia',
#  'Slovenia',
#  'Slovenia',
#  'Slovenia',
#  'Slovenia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Hungary',
#  'Hungary',
#  'Hungary',
#  'Hungary',
#  'Japan',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'Germany',
#  'Germany',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'Spain',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Dominican Republic',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Germany',
#  'Germany',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'Peru',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'Ecuador',
#  'France',
#  'France',
#  'Uruguay',
#  'Uruguay',
#  'Uruguay',
#  'Uruguay',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'France',
#  'France',
#  'France',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Argentina',
#  'Argentina',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'USA',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Italy',
#  'New Zealand',
#  'New Zealand',
#  'New Zealand',
#  'New Zealand',
#  'New Zealand',
#  'New Zealand',
#  'New Zealand',
#  'New Zealand',
#  'New Zealand',
#  'New Zealand',
#  'New Zealand',
#  ...]

# %%
for i in data2['complexes']:
    for j in i.get('venues',[]):
        venues_id.append(j.get('id',None).split(':')[-1])
        venues_name.append(j.get('name',None))
        city_name.append(j.get('city_name',None))
        country_name.append(j.get('country_name',None))
        country_code.append(j.get('country_code',None))
        timezone.append(j.get('timezone',None))
        complex_id.append(i.get('id',None).split(':')[-1])

# %%
venues_table={'venues_id':venues_id,
              'venues_name':venues_name,
              'city_name':city_name,
              'country_name':country_name,
              'country_code':country_code,
              'timezone':timezone,
              'complex_id':complex_id}

# %%
df_venues_table=pd.DataFrame(venues_table)

# %%
df_venues_table.to_sql('venues_table' , engine, if_exists='replace',index=False)
# Out:
# 212

# %%
df_venues_table
# Out:
#      venues_id            venues_name         city_name country_name  \
# 0        70045         Cancha Central          Santiago          CHL
# 1        74856           Centre Court           Seville          ESP
# 2        74858              Court One           Seville          ESP
# 3         1496                COURT 1  Saint Petersburg          RUS
# 4         1500           CENTER COURT  Saint Petersburg          RUS
# ...        ...                    ...               ...          ...
# 3207     81721  Bloomington - Court 7       Bloomington          USA
# 3208     81723  Bloomington - Court 6       Bloomington          USA
# 3209     81725  Bloomington - Court 5       Bloomington          USA
# 3210     81765           Center Court    Singapore City          SGP
# 3211     81767                Court 1    Singapore City          SGP
#
#      country_code          timezone complex_id
# 0             CHL  America/Santiago        705
# 1             ESP     Europe/Madrid       1078
# 2             ESP     Europe/Madrid       1078
# 3             RUS     Europe/Moscow       1495
# 4             RUS     Europe/Moscow       1495
# ...           ...               ...        ...
# 3207          USA  America/New_York      81717
# 3208          USA  America/New_York      81717
# 3209          USA  America/New_York      81717
# 3210          SGP    Asia/Singapore      81751
# 3211          SGP    Asia/Singapore      81751
#
# [3212 rows x 7 columns]

# %% [markdown]
# Next project

# %%
import requests

url = "https://api.sportradar.com/tennis/trial/v3/en/double_competitors_rankings.json?api_key=gCNmEyNAwK1dQ2CMzKHz8bzSBjT7uNx77cdZNAEn"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)
data3=response.json()
data3
# Out:
# {'generated_at': '2025-02-05T11:35:41+00:00',
#  'rankings': [{'type_id': 2,
#    'name': 'ATP',
#    'year': 2025,
#    'week': 6,
#    'gender': 'men',
#    'competitor_rankings': [{'rank': 1,
#      'movement': 0,
#      'points': 7530,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:49363',
#       'name': 'Pavic, Mate',
#       'country': 'Croatia',
#       'country_code': 'HRV',
#       'abbreviation': 'PAV'}},
#     {'rank': 1,
#      'movement': 0,
#      'points': 7530,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:51836',
#       'name': 'Arevalo-Gonzalez, Marcelo',
#       'country': 'El Salvador',
#       'country_code': 'SLV',
#       'abbreviation': 'ARE'}},
#     {'rank': 3,
#      'movement': 0,
#      'points': 7075,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:637970',
#       'name': 'Patten, Henry',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'PAT'}},
#     {'rank': 4,
#      'movement': 0,
#      'points': 7055,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:14898',
#       'name': 'Heliovaara, Harri',
#       'country': 'Finland',
#       'country_code': 'FIN',
#       'abbreviation': 'HEL'}},
#     {'rank': 5,
#      'movement': 0,
#      'points': 6475,
#      'competitions_played': 21,
#      'competitor': {'id': 'sr:competitor:87690',
#       'name': 'Thompson, Jordan',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'THO'}},
#     {'rank': 6,
#      'movement': 0,
#      'points': 6240,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:36593',
#       'name': 'Krawietz, Kevin',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'KRA'}},
#     {'rank': 7,
#      'movement': 0,
#      'points': 6170,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:15568',
#       'name': 'Granollers, Marcel',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'GRA'}},
#     {'rank': 7,
#      'movement': 0,
#      'points': 6170,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:16160',
#       'name': 'Zeballos, Horacio',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'ZEB'}},
#     {'rank': 9,
#      'movement': 0,
#      'points': 6150,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:52293',
#       'name': 'Putz, Tim',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'PUT'}},
#     {'rank': 10,
#      'movement': 0,
#      'points': 5990,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:15310',
#       'name': 'Bolelli, Simone',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'BOL'}},
#     {'rank': 11,
#      'movement': 0,
#      'points': 5990,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:95801',
#       'name': 'Vavassori, Andrea',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'VAV'}},
#     {'rank': 12,
#      'movement': 0,
#      'points': 5750,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:16608',
#       'name': 'Mektic, Nikola',
#       'country': 'Croatia',
#       'country_code': 'HRV',
#       'abbreviation': 'MEK'}},
#     {'rank': 13,
#      'movement': 0,
#      'points': 5550,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:124658',
#       'name': 'Purcell, Max',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'PUR'}},
#     {'rank': 14,
#      'movement': 0,
#      'points': 5545,
#      'competitions_played': 21,
#      'competitor': {'id': 'sr:competitor:50954',
#       'name': 'Koolhof, Wesley',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'KOO'}},
#     {'rank': 15,
#      'movement': 0,
#      'points': 4025,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:16151',
#       'name': 'Venus, Michael',
#       'country': 'New Zealand',
#       'country_code': 'NZL',
#       'abbreviation': 'VEN'}},
#     {'rank': 16,
#      'movement': 0,
#      'points': 3580,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:53785',
#       'name': 'Skupski, Neal',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'SKU'}},
#     {'rank': 17,
#      'movement': 0,
#      'points': 3230,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:55989',
#       'name': 'Withrow, Jackson',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'WIT'}},
#     {'rank': 17,
#      'movement': 0,
#      'points': 3230,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:210736',
#       'name': 'Lammons, Nathaniel',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'LAM'}},
#     {'rank': 19,
#      'movement': 0,
#      'points': 3120,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:59131',
#       'name': 'Glasspool, Lloyd',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'GLA'}},
#     {'rank': 20,
#      'movement': 0,
#      'points': 3105,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:16409',
#       'name': 'Ebden, Matthew',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'EBD'}},
#     {'rank': 21,
#      'movement': 0,
#      'points': 3000,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:15307',
#       'name': 'Bopanna, Rohan',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'BRO'}},
#     {'rank': 22,
#      'movement': 0,
#      'points': 2970,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:38181',
#       'name': 'Molteni, Andres',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'MOL'}},
#     {'rank': 23,
#      'movement': 1,
#      'points': 2875,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:108099',
#       'name': 'Cash, Julian',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'CAS'}},
#     {'rank': 24,
#      'movement': 1,
#      'points': 2870,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:52202',
#       'name': 'Nys, Hugo',
#       'country': 'Monaco',
#       'country_code': 'MCO',
#       'abbreviation': 'NYS'}},
#     {'rank': 25,
#      'movement': 1,
#      'points': 2800,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:47834',
#       'name': 'Murray, Jamie',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'MUR'}},
#     {'rank': 26,
#      'movement': 1,
#      'points': 2790,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:15548',
#       'name': 'Gonzalez, Maximo',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'GON'}},
#     {'rank': 27,
#      'movement': 1,
#      'points': 2760,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:16275',
#       'name': 'Dodig, Ivan',
#       'country': 'Croatia',
#       'country_code': 'HRV',
#       'abbreviation': 'DOD'}},
#     {'rank': 28,
#      'movement': -5,
#      'points': 2750,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:106349',
#       'name': 'Reboul, Fabien',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'REB'}},
#     {'rank': 29,
#      'movement': 0,
#      'points': 2630,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:206889',
#       'name': 'Galloway, Robert',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'GAL'}},
#     {'rank': 30,
#      'movement': 0,
#      'points': 2600,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:112805',
#       'name': 'Zielinski, Jan',
#       'country': 'Poland',
#       'country_code': 'POL',
#       'abbreviation': 'ZIE'}},
#     {'rank': 31,
#      'movement': 0,
#      'points': 2595,
#      'competitions_played': 23,
#      'competitor': {'id': 'sr:competitor:14553',
#       'name': 'Ram, Rajeev',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'RAM'}},
#     {'rank': 32,
#      'movement': 0,
#      'points': 2550,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:14835',
#       'name': 'Roger-Vasselin, Edouard',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'ROG'}},
#     {'rank': 33,
#      'movement': 1,
#      'points': 2485,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:81059',
#       'name': 'Gille, Sander',
#       'country': 'Belgium',
#       'country_code': 'BEL',
#       'abbreviation': 'GIL'}},
#     {'rank': 34,
#      'movement': 1,
#      'points': 2445,
#      'competitions_played': 31,
#      'competitor': {'id': 'sr:competitor:56629',
#       'name': 'Peers, John',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'PEE'}},
#     {'rank': 35,
#      'movement': 1,
#      'points': 2440,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:104917',
#       'name': 'Vliegen, Joran',
#       'country': 'Belgium',
#       'country_code': 'BEL',
#       'abbreviation': 'VLI'}},
#     {'rank': 36,
#      'movement': -3,
#      'points': 2415,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:106559',
#       'name': 'Doumbia, Sadio',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'DOU'}},
#     {'rank': 37,
#      'movement': 0,
#      'points': 2325,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:59324',
#       'name': 'Pavlasek, Adam',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'PAV'}},
#     {'rank': 38,
#      'movement': 0,
#      'points': 2302,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:76263',
#       'name': 'Matos, Rafael',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'MAT'}},
#     {'rank': 39,
#      'movement': 0,
#      'points': 2295,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:16124',
#       'name': 'Melo, Marcelo',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'MEL'}},
#     {'rank': 40,
#      'movement': 0,
#      'points': 2190,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:230186',
#       'name': 'Verbeek, Sem',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'VER'}},
#     {'rank': 41,
#      'movement': 0,
#      'points': 2160,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:25189',
#       'name': 'Krajicek, Austin',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'KRA'}},
#     {'rank': 42,
#      'movement': 0,
#      'points': 2152,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:114831',
#       'name': 'Erler, Alexander',
#       'country': 'Austria',
#       'country_code': 'AUT',
#       'abbreviation': 'ERL'}},
#     {'rank': 43,
#      'movement': 0,
#      'points': 2130,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:74173',
#       'name': 'Salisbury, Joe',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'SAL'}},
#     {'rank': 44,
#      'movement': 0,
#      'points': 2038,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:78793',
#       'name': 'Miedler, Lucas',
#       'country': 'Austria',
#       'country_code': 'AUT',
#       'abbreviation': 'MIE'}},
#     {'rank': 45,
#      'movement': 1,
#      'points': 1931,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:45105',
#       'name': 'Behar, Ariel',
#       'country': 'Uruguay',
#       'country_code': 'URY',
#       'abbreviation': 'BEH'}},
#     {'rank': 46,
#      'movement': 1,
#      'points': 1895,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:22967',
#       'name': 'Bhambri, Yuki',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'BHA'}},
#     {'rank': 47,
#      'movement': 1,
#      'points': 1895,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:70348',
#       'name': 'Goransson, Andre',
#       'country': 'Sweden',
#       'country_code': 'SWE',
#       'abbreviation': 'GOR'}},
#     {'rank': 48,
#      'movement': 1,
#      'points': 1890,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:15305',
#       'name': 'Gonzalez, Santiago',
#       'country': 'Mexico',
#       'country_code': 'MEX',
#       'abbreviation': 'GON'}},
#     {'rank': 49,
#      'movement': -4,
#      'points': 1835,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:47966',
#       'name': 'Olivetti, Albano',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'OLI'}},
#     {'rank': 50,
#      'movement': 1,
#      'points': 1770,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:48646',
#       'name': 'Barrientos, Nicolas',
#       'country': 'Colombia',
#       'country_code': 'COL',
#       'abbreviation': 'BAR'}},
#     {'rank': 51,
#      'movement': -1,
#      'points': 1765,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:66864',
#       'name': 'Arends, Sander',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'ARE'}},
#     {'rank': 52,
#      'movement': 1,
#      'points': 1718,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:62410',
#       'name': 'Johnson, Luke',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'JOH'}},
#     {'rank': 53,
#      'movement': -1,
#      'points': 1680,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:15588',
#       'name': 'Rojer, Jean-Julien',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'ROJ'}},
#     {'rank': 54,
#      'movement': 0,
#      'points': 1606,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:108755',
#       'name': 'Jebens, Hendrik',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'JEB'}},
#     {'rank': 54,
#      'movement': 0,
#      'points': 1606,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:231188',
#       'name': 'Frantzen, Constantin',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'FRA'}},
#     {'rank': 56,
#      'movement': 0,
#      'points': 1580,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:69362',
#       'name': 'Mansouri, Skander',
#       'country': 'Tunisia',
#       'country_code': 'TUN',
#       'abbreviation': 'MAN'}},
#     {'rank': 57,
#      'movement': 0,
#      'points': 1575,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:47295',
#       'name': 'Andreozzi, Guido',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'AND'}},
#     {'rank': 58,
#      'movement': 0,
#      'points': 1467,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:49306',
#       'name': 'Reyes-Varela, Miguel',
#       'country': 'Mexico',
#       'country_code': 'MEX',
#       'abbreviation': 'REY'}},
#     {'rank': 59,
#      'movement': 2,
#      'points': 1460,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:81763',
#       'name': 'Jacq, Gregoire',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'JAC'}},
#     {'rank': 60,
#      'movement': 3,
#      'points': 1435,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:111195',
#       'name': 'Luz, Orlando',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'LUZ'}},
#     {'rank': 61,
#      'movement': -2,
#      'points': 1419,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:127646',
#       'name': 'Cabral, Francisco',
#       'country': 'Portugal',
#       'country_code': 'PRT',
#       'abbreviation': 'CAB'}},
#     {'rank': 62,
#      'movement': -2,
#      'points': 1401,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:25457',
#       'name': 'Nedovyesov, Aleksandr',
#       'country': 'Kazakhstan',
#       'country_code': 'KAZ',
#       'abbreviation': 'NED'}},
#     {'rank': 63,
#      'movement': -1,
#      'points': 1380,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:16198',
#       'name': 'Escobar, Gonzalo',
#       'country': 'Ecuador',
#       'country_code': 'ECU',
#       'abbreviation': 'ESC'}},
#     {'rank': 64,
#      'movement': 6,
#      'points': 1366,
#      'competitions_played': 31,
#      'competitor': {'id': 'sr:competitor:16042',
#       'name': 'Haase, Robin',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'HAA'}},
#     {'rank': 65,
#      'movement': -1,
#      'points': 1316,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:52244',
#       'name': 'Balaji, N. Sriram',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'BAL'}},
#     {'rank': 66,
#      'movement': -1,
#      'points': 1310,
#      'competitions_played': 43,
#      'competitor': {'id': 'sr:competitor:231090',
#       'name': 'Arribage, Theo',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'ARR'}},
#     {'rank': 67,
#      'movement': -1,
#      'points': 1285,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:300540',
#       'name': 'Machac, Tomas',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'MAC'}},
#     {'rank': 68,
#      'movement': -1,
#      'points': 1270,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:203681',
#       'name': 'Korda, Sebastian',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'KOR'}},
#     {'rank': 69,
#      'movement': -1,
#      'points': 1270,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:104421',
#       'name': 'Mies, Andreas',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'MIE'}},
#     {'rank': 70,
#      'movement': 4,
#      'points': 1266,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:121182',
#       'name': 'Guinard, Manuel',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'GUI'}},
#     {'rank': 71,
#      'movement': -2,
#      'points': 1240,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:75813',
#       'name': 'Zhang, Zhizhen',
#       'country': 'China',
#       'country_code': 'CHN',
#       'abbreviation': 'ZHA'}},
#     {'rank': 72,
#      'movement': -1,
#      'points': 1190,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:41475',
#       'name': 'Arneodo, Romain',
#       'country': 'Monaco',
#       'country_code': 'MCO',
#       'abbreviation': 'ARN'}},
#     {'rank': 73,
#      'movement': -1,
#      'points': 1185,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:17038',
#       'name': 'Smith, John-Patrick',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'SMI'}},
#     {'rank': 74,
#      'movement': 1,
#      'points': 1155,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:152900',
#       'name': 'Rikl, Patrik',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'RIK'}},
#     {'rank': 75,
#      'movement': 4,
#      'points': 1132,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:918463',
#       'name': 'Bollipalli, Rithvik Choudary',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'BOL'}},
#     {'rank': 76,
#      'movement': 4,
#      'points': 1130,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:16043',
#       'name': 'Middelkoop, Matwe',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'MID'}},
#     {'rank': 77,
#      'movement': -1,
#      'points': 1120,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:52065',
#       'name': 'Harrison, Christian',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'HAR'}},
#     {'rank': 78,
#      'movement': 3,
#      'points': 1118,
#      'competitions_played': 38,
#      'competitor': {'id': 'sr:competitor:23899',
#       'name': 'King, Evan',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'KIN'}},
#     {'rank': 79,
#      'movement': -6,
#      'points': 1112,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:204781',
#       'name': 'Nouza, Petr',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'NOU'}},
#     {'rank': 80,
#      'movement': -3,
#      'points': 1103,
#      'competitions_played': 41,
#      'competitor': {'id': 'sr:competitor:112969',
#       'name': 'Schnaitter, Jakob',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'SCH'}},
#     {'rank': 80,
#      'movement': -3,
#      'points': 1103,
#      'competitions_played': 41,
#      'competitor': {'id': 'sr:competitor:936355',
#       'name': 'Wallner, Mark',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'WAL'}},
#     {'rank': 82,
#      'movement': 0,
#      'points': 1056,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:287215',
#       'name': 'Seggerman, Ryan',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'SEG'}},
#     {'rank': 83,
#      'movement': 0,
#      'points': 1042,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:76361',
#       'name': 'Kadhe, Arjun',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'KAD'}},
#     {'rank': 84,
#      'movement': 0,
#      'points': 1039,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:223868',
#       'name': 'Matuszewski, Piotr',
#       'country': 'Poland',
#       'country_code': 'POL',
#       'abbreviation': 'MAT'}},
#     {'rank': 85,
#      'movement': 0,
#      'points': 1035,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:52263',
#       'name': 'Hidalgo, Diego',
#       'country': 'Ecuador',
#       'country_code': 'ECU',
#       'abbreviation': 'HID'}},
#     {'rank': 86,
#      'movement': 0,
#      'points': 1030,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:63438',
#       'name': 'McDonald, Mackenzie',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'MCD'}},
#     {'rank': 87,
#      'movement': 1,
#      'points': 1016,
#      'competitions_played': 39,
#      'competitor': {'id': 'sr:competitor:147104',
#       'name': 'Romios, Matthew Christopher',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'ROM'}},
#     {'rank': 88,
#      'movement': -1,
#      'points': 968,
#      'competitions_played': 39,
#      'competitor': {'id': 'sr:competitor:77653',
#       'name': 'Cornea, Victor',
#       'country': 'Romania',
#       'country_code': 'ROU',
#       'abbreviation': 'COR'}},
#     {'rank': 89,
#      'movement': 0,
#      'points': 960,
#      'competitions_played': 7,
#      'competitor': {'id': 'sr:competitor:57163',
#       'name': 'Zverev, Alexander',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'ZVE'}},
#     {'rank': 90,
#      'movement': 14,
#      'points': 920,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:122368',
#       'name': 'Griekspoor, Tallon',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'GRI'}},
#     {'rank': 91,
#      'movement': -1,
#      'points': 915,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:871495',
#       'name': 'Michelsen, Alex',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'MIC'}},
#     {'rank': 92,
#      'movement': -1,
#      'points': 901,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:197678',
#       'name': 'Tsitsipas, Petros',
#       'country': 'Greece',
#       'country_code': 'GRC',
#       'abbreviation': 'TSI'}},
#     {'rank': 93,
#      'movement': 12,
#      'points': 898,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:234124',
#       'name': 'Stevens, Bart',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'STE'}},
#     {'rank': 94,
#      'movement': -1,
#      'points': 898,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:73572',
#       'name': 'Zormann, Marcelo',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'ZOR'}},
#     {'rank': 95,
#      'movement': 2,
#      'points': 885,
#      'competitions_played': 40,
#      'competitor': {'id': 'sr:competitor:16823',
#       'name': 'Romboli, Fernando',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'ROM'}},
#     {'rank': 96,
#      'movement': -2,
#      'points': 882,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:16492',
#       'name': 'Eysseric, Jonathan',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'EYS'}},
#     {'rank': 97,
#      'movement': -2,
#      'points': 878,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:1020797',
#       'name': 'Trhac, Patrik',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'TRH'}},
#     {'rank': 98,
#      'movement': -6,
#      'points': 877,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:16992',
#       'name': 'Willis, Marcus',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'WIL'}},
#     {'rank': 99,
#      'movement': -3,
#      'points': 855,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:808628',
#       'name': 'Shelton, Ben',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'SHE'}},
#     {'rank': 100,
#      'movement': -2,
#      'points': 847,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:299130',
#       'name': 'Hijikata, Rinky',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'HIJ'}},
#     {'rank': 101,
#      'movement': -2,
#      'points': 841,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:121032',
#       'name': 'Stalder, Reese',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'STA'}},
#     {'rank': 102,
#      'movement': -2,
#      'points': 834,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:60920',
#       'name': 'Nedunchezhiyan, Jeevan',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'NED'}},
#     {'rank': 103,
#      'movement': -2,
#      'points': 830,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:98413',
#       'name': 'Drzewiecki, Karol',
#       'country': 'Poland',
#       'country_code': 'POL',
#       'abbreviation': 'DRZ'}},
#     {'rank': 104,
#      'movement': 42,
#      'points': 820,
#      'competitions_played': 5,
#      'competitor': {'id': 'sr:competitor:102339',
#       'name': 'Van de Zandschulp, Botic',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'VAN'}},
#     {'rank': 105,
#      'movement': -3,
#      'points': 789,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:113221',
#       'name': 'Niklas-Salminen, Patrik',
#       'country': 'Finland',
#       'country_code': 'FIN',
#       'abbreviation': 'NIK'}},
#     {'rank': 106,
#      'movement': 0,
#      'points': 760,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:102151',
#       'name': 'Tabilo, Alejandro',
#       'country': 'Chile',
#       'country_code': 'CHL',
#       'abbreviation': 'TAB'}},
#     {'rank': 107,
#      'movement': 2,
#      'points': 757,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:50037',
#       'name': 'Bortolotti, Marco',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'BOR'}},
#     {'rank': 108,
#      'movement': 0,
#      'points': 742,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:16854',
#       'name': 'Molchanov, Denys',
#       'country': 'Ukraine',
#       'country_code': 'UKR',
#       'abbreviation': 'MOL'}},
#     {'rank': 109,
#      'movement': 17,
#      'points': 740,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:838776',
#       'name': 'Tracy, James',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'TRA'}},
#     {'rank': 110,
#      'movement': 1,
#      'points': 739,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:157396',
#       'name': 'Veldheer, Mick',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'VEL'}},
#     {'rank': 111,
#      'movement': 1,
#      'points': 732,
#      'competitions_played': 18,
#      'competitor': {'id': 'sr:competitor:35766',
#       'name': 'Begemann, Andre',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'BEG'}},
#     {'rank': 112,
#      'movement': 1,
#      'points': 730,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:263917',
#       'name': 'Draxl, Liam',
#       'country': 'Canada',
#       'country_code': 'CAN',
#       'abbreviation': 'DRA'}},
#     {'rank': 113,
#      'movement': 11,
#      'points': 729,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:16573',
#       'name': 'Demoliner, Marcelo',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'DEM'}},
#     {'rank': 114,
#      'movement': 0,
#      'points': 726,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:119150',
#       'name': 'Fancutt, Thomas',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'FAN'}},
#     {'rank': 115,
#      'movement': 0,
#      'points': 720,
#      'competitions_played': 15,
#      'competitor': {'id': 'sr:competitor:163480',
#       'name': 'Bublik, Alexander',
#       'country': 'Kazakhstan',
#       'country_code': 'KAZ',
#       'abbreviation': 'BUB'}},
#     {'rank': 116,
#      'movement': -6,
#      'points': 717,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:77011',
#       'name': 'Martos Gornes, Sergio',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'MAR'}},
#     {'rank': 117,
#      'movement': -1,
#      'points': 706,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:145936',
#       'name': 'Kaliyanda Poonacha, Niki',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'KAL'}},
#     {'rank': 118,
#      'movement': -15,
#      'points': 705,
#      'competitions_played': 18,
#      'competitor': {'id': 'sr:competitor:39712',
#       'name': 'Saville, Luke',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'SAV'}},
#     {'rank': 119,
#      'movement': 21,
#      'points': 702,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:52951',
#       'name': 'Pel, David',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'PEL'}},
#     {'rank': 120,
#      'movement': -3,
#      'points': 701,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:37637',
#       'name': 'Zeballos, Federico',
#       'country': 'Bolivia',
#       'country_code': 'BOL',
#       'abbreviation': 'ZEB'}},
#     {'rank': 120,
#      'movement': -3,
#      'points': 701,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:54609',
#       'name': 'Arias, Boris',
#       'country': 'Bolivia',
#       'country_code': 'BOL',
#       'abbreviation': 'ARI'}},
#     {'rank': 122,
#      'movement': -3,
#      'points': 695,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:53759',
#       'name': 'Prashanth, N. Vijay Sundar',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'PRA'}},
#     {'rank': 123,
#      'movement': -2,
#      'points': 684,
#      'competitions_played': 23,
#      'competitor': {'id': 'sr:competitor:305776',
#       'name': 'Soto, Matias',
#       'country': 'Chile',
#       'country_code': 'CHL',
#       'abbreviation': 'SOT'}},
#     {'rank': 124,
#      'movement': 17,
#      'points': 684,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:243522',
#       'name': 'Paul, Jakub',
#       'country': 'Switzerland',
#       'country_code': 'CHE',
#       'abbreviation': 'PAU'}},
#     {'rank': 125,
#      'movement': 14,
#      'points': 681,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:393598',
#       'name': 'Cash, Robert',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'CAS'}},
#     {'rank': 126,
#      'movement': -4,
#      'points': 676,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:42151',
#       'name': 'Nam, Ji Sung',
#       'country': 'Republic of Korea',
#       'country_code': 'KOR',
#       'abbreviation': 'NAM'}},
#     {'rank': 127,
#      'movement': -4,
#      'points': 675,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:90080',
#       'name': 'Khachanov, Karen',
#       'country': 'Neutral',
#       'abbreviation': 'KHA'}},
#     {'rank': 128,
#      'movement': -3,
#      'points': 669,
#      'competitions_played': 39,
#      'competitor': {'id': 'sr:competitor:256001',
#       'name': 'Ho, Ray',
#       'country': 'Chinese Taipei',
#       'country_code': 'TPE',
#       'abbreviation': 'RAY'}},
#     {'rank': 129,
#      'movement': 2,
#      'points': 663,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:209202',
#       'name': 'Chandrasekar, Anirudh',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'CHA'}},
#     {'rank': 130,
#      'movement': -3,
#      'points': 659,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:69910',
#       'name': 'Bergevi, Filip',
#       'country': 'Sweden',
#       'country_code': 'SWE',
#       'abbreviation': 'BER'}},
#     {'rank': 131,
#      'movement': -3,
#      'points': 652,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:450383',
#       'name': 'Harper, Cleeve',
#       'country': 'Canada',
#       'country_code': 'CAN',
#       'abbreviation': 'HAR'}},
#     {'rank': 132,
#      'movement': -3,
#      'points': 650,
#      'competitions_played': 2,
#      'competitor': {'id': 'sr:competitor:46391',
#       'name': 'Struff, Jan-Lennard',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'STR'}},
#     {'rank': 133,
#      'movement': -3,
#      'points': 648,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:296270',
#       'name': 'Stevenson, David',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'STE'}},
#     {'rank': 134,
#      'movement': -14,
#      'points': 641,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:405977',
#       'name': 'Schoolkate, Tristan',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'SCH'}},
#     {'rank': 135,
#      'movement': -2,
#      'points': 640,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:14508',
#       'name': 'Mahut, Nicolas',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'MAH'}},
#     {'rank': 136,
#      'movement': -2,
#      'points': 630,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:125006',
#       'name': 'Borges, Nuno',
#       'country': 'Portugal',
#       'country_code': 'PRT',
#       'abbreviation': 'BOR'}},
#     {'rank': 137,
#      'movement': -1,
#      'points': 620,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:25458',
#       'name': 'Martinez, Luis David',
#       'country': 'Venezuela',
#       'country_code': 'VEN',
#       'abbreviation': 'MAR'}},
#     {'rank': 138,
#      'movement': 4,
#      'points': 618,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:234044',
#       'name': 'Kirkov, Vasil',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'KIR'}},
#     {'rank': 139,
#      'movement': -4,
#      'points': 618,
#      'competitions_played': 31,
#      'competitor': {'id': 'sr:competitor:111607',
#       'name': 'Ingildsen, Johannes',
#       'country': 'Denmark',
#       'country_code': 'DNK',
#       'abbreviation': 'ING'}},
#     {'rank': 140,
#      'movement': 12,
#      'points': 616,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:95923',
#       'name': 'Paris, Joshua',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'PAR'}},
#     {'rank': 141,
#      'movement': -34,
#      'points': 610,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:47760',
#       'name': 'Weissborn, Tristan-Samuel',
#       'country': 'Austria',
#       'country_code': 'AUT',
#       'abbreviation': 'WEI'}},
#     {'rank': 142,
#      'movement': -5,
#      'points': 609,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:44637',
#       'name': 'Rodriguez, Cristian',
#       'country': 'Colombia',
#       'country_code': 'COL',
#       'abbreviation': 'ROC'}},
#     {'rank': 143,
#      'movement': 0,
#      'points': 596,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:58877',
#       'name': 'Ramanathan, Ramkumar',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'RAM'}},
#     {'rank': 144,
#      'movement': 1,
#      'points': 592,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:240880',
#       'name': 'Hilderbrand, Trey',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'HIL'}},
#     {'rank': 145,
#      'movement': -13,
#      'points': 591,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:134610',
#       'name': 'Blumberg, William',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'BLU'}},
#     {'rank': 146,
#      'movement': 2,
#      'points': 580,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:78387',
#       'name': 'Hach Verdugo, Hans',
#       'country': 'Mexico',
#       'country_code': 'MEX',
#       'abbreviation': 'HAC'}},
#     {'rank': 147,
#      'movement': -3,
#      'points': 579,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:548169',
#       'name': 'Yuzuki, Takeru',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'YUZ'}},
#     {'rank': 148,
#      'movement': 3,
#      'points': 575,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:119140',
#       'name': 'Ellis, Blake',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'ELL'}},
#     {'rank': 149,
#      'movement': -2,
#      'points': 566,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:15809',
#       'name': 'Martin, Fabrice',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'MAR'}},
#     {'rank': 150,
#      'movement': 0,
#      'points': 563,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:113889',
#       'name': 'Liutarevich, Ivan',
#       'country': 'Neutral',
#       'abbreviation': 'LIU'}},
#     {'rank': 151,
#      'movement': -13,
#      'points': 548,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:92845',
#       'name': 'Goldhoff, George',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'GOL'}},
#     {'rank': 152,
#      'movement': 1,
#      'points': 538,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:146040',
#       'name': 'Gomez, Federico Agustin',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'GOM'}},
#     {'rank': 153,
#      'movement': 2,
#      'points': 536,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:124708',
#       'name': 'Cukierman, Daniel',
#       'country': 'Israel',
#       'country_code': 'ISR',
#       'abbreviation': 'CUK'}},
#     {'rank': 154,
#      'movement': 2,
#      'points': 530,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:195458',
#       'name': 'Added, Dan',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'ADD'}},
#     {'rank': 155,
#      'movement': -1,
#      'points': 529,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:110707',
#       'name': 'Pichler, David',
#       'country': 'Austria',
#       'country_code': 'AUT',
#       'abbreviation': 'PIC'}},
#     {'rank': 156,
#      'movement': -7,
#      'points': 528,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:52260',
#       'name': 'Vega, David',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'VEG'}},
#     {'rank': 157,
#      'movement': 0,
#      'points': 525,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:58989',
#       'name': 'Sabanov, Matej',
#       'country': 'Serbia',
#       'country_code': 'SRB',
#       'abbreviation': 'SAB'}},
#     {'rank': 158,
#      'movement': 0,
#      'points': 525,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:98981',
#       'name': 'Jecan, Alexandru',
#       'country': 'Romania',
#       'country_code': 'ROU',
#       'abbreviation': 'JEC'}},
#     {'rank': 159,
#      'movement': 7,
#      'points': 511,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:216502',
#       'name': 'Broom, Charles',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'BRO'}},
#     {'rank': 160,
#      'movement': 1,
#      'points': 511,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:96859',
#       'name': 'Lock, Benjamin',
#       'country': 'Zimbabwe',
#       'country_code': 'ZWE',
#       'abbreviation': 'LOC'}},
#     {'rank': 161,
#      'movement': 1,
#      'points': 510,
#      'competitions_played': 23,
#      'competitor': {'id': 'sr:competitor:25021',
#       'name': 'Cervantes, Inigo',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'CER'}},
#     {'rank': 162,
#      'movement': 1,
#      'points': 501,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:280601',
#       'name': 'Oberleitner, Neil',
#       'country': 'Austria',
#       'country_code': 'AUT',
#       'abbreviation': 'OBE'}},
#     {'rank': 163,
#      'movement': 1,
#      'points': 500,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:145008',
#       'name': 'Uesugi, Kaito',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'UES'}},
#     {'rank': 164,
#      'movement': 1,
#      'points': 495,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:122366',
#       'name': 'Tsitsipas, Stefanos',
#       'country': 'Greece',
#       'country_code': 'GRC',
#       'abbreviation': 'TSI'}},
#     {'rank': 165,
#      'movement': 15,
#      'points': 495,
#      'competitions_played': 23,
#      'competitor': {'id': 'sr:competitor:141882',
#       'name': 'Blancaneaux, Geoffrey',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'BLA'}},
#     {'rank': 166,
#      'movement': 2,
#      'points': 492,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:112061',
#       'name': 'Walkow, Szymon',
#       'country': 'Poland',
#       'country_code': 'POL',
#       'abbreviation': 'WAL'}},
#     {'rank': 167,
#      'movement': 2,
#      'points': 490,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:297448',
#       'name': 'Kiger, Mac',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'KIG'}},
#     {'rank': 168,
#      'movement': -9,
#      'points': 483,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:297502',
#       'name': 'Bayldon, Blake',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'BAY'}},
#     {'rank': 169,
#      'movement': 1,
#      'points': 480,
#      'competitions_played': 5,
#      'competitor': {'id': 'sr:competitor:136042',
#       'name': 'Fritz, Taylor',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'FRI'}},
#     {'rank': 170,
#      'movement': -3,
#      'points': 472,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:227358',
#       'name': 'Walton, Adam',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'WAL'}},
#     {'rank': 171,
#      'movement': 11,
#      'points': 468,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:84671',
#       'name': 'Britto, Luis',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'BRI'}},
#     {'rank': 172,
#      'movement': 2,
#      'points': 462,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:15275',
#       'name': 'Matsui, Toshihide',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'MAT'}},
#     {'rank': 173,
#      'movement': -1,
#      'points': 461,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:390480',
#       'name': 'Watanabe, Seita',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'WAT'}},
#     {'rank': 174,
#      'movement': 21,
#      'points': 457,
#      'competitions_played': 18,
#      'competitor': {'id': 'sr:competitor:295508',
#       'name': 'Vrbensky, Michael',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'VRB'}},
#     {'rank': 175,
#      'movement': -2,
#      'points': 457,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:204495',
#       'name': 'Vocel, Matej',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'VOC'}},
#     {'rank': 176,
#      'movement': 15,
#      'points': 456,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:380004',
#       'name': 'Harper, Patrick',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'HAR'}},
#     {'rank': 177,
#      'movement': -17,
#      'points': 453,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:342826',
#       'name': 'Trotter, James Kent',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'TRO'}},
#     {'rank': 178,
#      'movement': -3,
#      'points': 453,
#      'competitions_played': 18,
#      'competitor': {'id': 'sr:competitor:250231',
#       'name': 'Shimizu, Yuta',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'SHI'}},
#     {'rank': 179,
#      'movement': -3,
#      'points': 449,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:59700',
#       'name': 'Isaro, Pruchya',
#       'country': 'Thailand',
#       'country_code': 'THA',
#       'abbreviation': 'ISA'}},
#     {'rank': 180,
#      'movement': -3,
#      'points': 443,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:64920',
#       'name': 'Myneni, Saketh',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'MYN'}},
#     {'rank': 181,
#      'movement': 0,
#      'points': 435,
#      'competitions_played': 31,
#      'competitor': {'id': 'sr:competitor:263865',
#       'name': 'Reynolds, Finn',
#       'country': 'New Zealand',
#       'country_code': 'NZL',
#       'abbreviation': 'REY'}},
#     {'rank': 182,
#      'movement': -11,
#      'points': 430,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:77223',
#       'name': 'Martinez, Pedro',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'MAR'}},
#     {'rank': 183,
#      'movement': 1,
#      'points': 429,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:628218',
#       'name': 'Karol, Milos',
#       'country': 'Slovakia',
#       'country_code': 'SVK',
#       'abbreviation': 'KAR'}},
#     {'rank': 184,
#      'movement': 2,
#      'points': 425,
# ...
#       'country': 'Neutral',
#       'abbreviation': 'KOV'}},
#     {'rank': 440,
#      'movement': 3,
#      'points': 146,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:185412',
#       'name': 'Labrana, Fernanda',
#       'country': 'Chile',
#       'country_code': 'CHL',
#       'abbreviation': 'LAB'}},
#     {'rank': 441,
#      'movement': 28,
#      'points': 146,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:812476',
#       'name': 'Zaytseva, Ksenia',
#       'country': 'Neutral',
#       'abbreviation': 'ZAY'}},
#     {'rank': 442,
#      'movement': 4,
#      'points': 145,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:831262',
#       'name': 'Yamalapalli, Sahaja',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'YAM'}},
#     {'rank': 443,
#      'movement': 2,
#      'points': 145,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:522258',
#       'name': 'Ricci, Beatrice',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'RIC'}},
#     {'rank': 444,
#      'movement': 4,
#      'points': 144,
#      'competitions_played': 6,
#      'competitor': {'id': 'sr:competitor:517296',
#       'name': 'Falei, Aliona',
#       'country': 'Neutral',
#       'abbreviation': 'FAL'}},
#     {'rank': 445,
#      'movement': 5,
#      'points': 143,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:171026',
#       'name': 'Tsygourova, Katerina',
#       'country': 'Switzerland',
#       'country_code': 'CHE',
#       'abbreviation': 'TSY'}},
#     {'rank': 446,
#      'movement': 5,
#      'points': 142,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:1027517',
#       'name': 'Ebeling Koning, Loes',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'EBE'}},
#     {'rank': 447,
#      'movement': 5,
#      'points': 142,
#      'competitions_played': 17,
#      'competitor': {'id': 'sr:competitor:341196',
#       'name': 'Back, Dayeon',
#       'country': 'Republic of Korea',
#       'country_code': 'KOR',
#       'abbreviation': 'BAC'}},
#     {'rank': 448,
#      'movement': -1,
#      'points': 142,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:371556',
#       'name': 'Jeong, Boyoung',
#       'country': 'Republic of Korea',
#       'country_code': 'KOR',
#       'abbreviation': 'JEO'}},
#     {'rank': 449,
#      'movement': -50,
#      'points': 141,
#      'competitions_played': 3,
#      'competitor': {'id': 'sr:competitor:499484',
#       'name': 'Montgomery, Robin',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'MON'}},
#     {'rank': 450,
#      'movement': 3,
#      'points': 141,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:380368',
#       'name': 'Sebestova, Ivana',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'SEB'}},
#     {'rank': 451,
#      'movement': 3,
#      'points': 140,
#      'competitions_played': 7,
#      'competitor': {'id': 'sr:competitor:329535',
#       'name': 'Tauson, Clara',
#       'country': 'Denmark',
#       'country_code': 'DNK',
#       'abbreviation': 'TAU'}},
#     {'rank': 452,
#      'movement': -27,
#      'points': 140,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:655811',
#       'name': 'Avdeeva, Julia',
#       'country': 'Neutral',
#       'abbreviation': 'AVD'}},
#     {'rank': 453,
#      'movement': 2,
#      'points': 140,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:88290',
#       'name': 'Bejenaru, Karola Patricia',
#       'country': 'Romania',
#       'country_code': 'ROU',
#       'abbreviation': 'BEJ'}},
#     {'rank': 454,
#      'movement': 2,
#      'points': 140,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:522848',
#       'name': 'Rocchetti, Sofia',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'ROC'}},
#     {'rank': 455,
#      'movement': 41,
#      'points': 139,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:98733',
#       'name': 'Burillo Escorihuela, Irene',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'BUR'}},
#     {'rank': 456,
#      'movement': 2,
#      'points': 139,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:906635',
#       'name': 'Shubladze, Alexandra',
#       'country': 'Neutral',
#       'abbreviation': 'SHU'}},
#     {'rank': 457,
#      'movement': 4,
#      'points': 138,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:880229',
#       'name': 'Cayetano, Eryn',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'CAY'}},
#     {'rank': 458,
#      'movement': 4,
#      'points': 138,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:583869',
#       'name': 'Pavlou, Dimitra',
#       'country': 'Greece',
#       'country_code': 'GRC',
#       'abbreviation': 'PAV'}},
#     {'rank': 459,
#      'movement': 4,
#      'points': 138,
#      'competitions_played': 21,
#      'competitor': {'id': 'sr:competitor:96981',
#       'name': 'Xun, Fang Ying',
#       'country': 'China',
#       'country_code': 'CHN',
#       'abbreviation': 'XUN'}},
#     {'rank': 460,
#      'movement': 5,
#      'points': 137,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:52388',
#       'name': 'Hesse, Amandine',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'HES'}},
#     {'rank': 461,
#      'movement': 3,
#      'points': 137,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:310982',
#       'name': 'Naklo, Thasaporn',
#       'country': 'Thailand',
#       'country_code': 'THA',
#       'abbreviation': 'NAK'}},
#     {'rank': 462,
#      'movement': 39,
#      'points': 137,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:804342',
#       'name': 'Stoiber, Ranah Akua',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'STO'}},
#     {'rank': 463,
#      'movement': 3,
#      'points': 137,
#      'competitions_played': 23,
#      'competitor': {'id': 'sr:competitor:111149',
#       'name': 'Samir, Sandra',
#       'country': 'Egypt',
#       'country_code': 'EGY',
#       'abbreviation': 'SAM'}},
#     {'rank': 464,
#      'movement': 3,
#      'points': 136,
#      'competitions_played': 3,
#      'competitor': {'id': 'sr:competitor:595220',
#       'name': 'Stakusic, Marina',
#       'country': 'Canada',
#       'country_code': 'CAN',
#       'abbreviation': 'STA'}},
#     {'rank': 465,
#      'movement': 3,
#      'points': 136,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:431743',
#       'name': 'Okutoyi, Angella',
#       'country': 'Kenya',
#       'country_code': 'KEN',
#       'abbreviation': 'OKU'}},
#     {'rank': 466,
#      'movement': 4,
#      'points': 136,
#      'competitions_played': 17,
#      'competitor': {'id': 'sr:competitor:476218',
#       'name': 'Kawaguchi, Natsumi',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'KAW'}},
#     {'rank': 467,
#      'movement': 4,
#      'points': 135,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:739667',
#       'name': 'Pedone, Giorgia',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'PED'}},
#     {'rank': 468,
#      'movement': -33,
#      'points': 135,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:569009',
#       'name': 'Ccuno, Romina',
#       'country': 'Peru',
#       'country_code': 'PER',
#       'abbreviation': 'CCU'}},
#     {'rank': 469,
#      'movement': 3,
#      'points': 134,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:342788',
#       'name': 'Curmi, Francesca',
#       'country': 'Malta',
#       'country_code': 'MLT',
#       'abbreviation': 'CUR'}},
#     {'rank': 470,
#      'movement': 3,
#      'points': 133,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:265743',
#       'name': 'Burdina, Evgeniya',
#       'country': 'Neutral',
#       'abbreviation': 'BUR'}},
#     {'rank': 471,
#      'movement': 3,
#      'points': 132,
#      'competitions_played': 8,
#      'competitor': {'id': 'sr:competitor:46661',
#       'name': 'Gamiz, Andrea',
#       'country': 'Venezuela',
#       'country_code': 'VEN',
#       'abbreviation': 'GAM'}},
#     {'rank': 472,
#      'movement': -28,
#      'points': 132,
#      'competitions_played': 17,
#      'competitor': {'id': 'sr:competitor:315623',
#       'name': 'Wang, Jiaqi',
#       'country': 'China',
#       'country_code': 'CHN',
#       'abbreviation': 'WAN'}},
#     {'rank': 473,
#      'movement': 2,
#      'points': 132,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:340365',
#       'name': 'Milovanovic, Elena',
#       'country': 'Serbia',
#       'country_code': 'SRB',
#       'abbreviation': 'MIL'}},
#     {'rank': 474,
#      'movement': 7,
#      'points': 132,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:858867',
#       'name': 'Pace, Francesca',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'PAC'}},
#     {'rank': 475,
#      'movement': 3,
#      'points': 131,
#      'competitions_played': 2,
#      'competitor': {'id': 'sr:competitor:71034',
#       'name': 'Sramkova, Rebecca',
#       'country': 'Slovakia',
#       'country_code': 'SVK',
#       'abbreviation': 'SRA'}},
#     {'rank': 476,
#      'movement': 0,
#      'points': 131,
#      'competitions_played': 2,
#      'competitor': {'id': 'sr:competitor:19704',
#       'name': 'Martic, Petra',
#       'country': 'Croatia',
#       'country_code': 'HRV',
#       'abbreviation': 'MAR'}},
#     {'rank': 477,
#      'movement': 109,
#      'points': 131,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:264863',
#       'name': 'Novak, Kristina',
#       'country': 'Slovenia',
#       'country_code': 'SVN',
#       'abbreviation': 'NOV'}},
#     {'rank': 478,
#      'movement': -1,
#      'points': 131,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:915371',
#       'name': 'van Den Broek, Isis Louise',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'VAN'}},
#     {'rank': 479,
#      'movement': 1,
#      'points': 130,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:784280',
#       'name': 'Prozorova, Tatiana',
#       'country': 'Neutral',
#       'abbreviation': 'PRO'}},
#     {'rank': 480,
#      'movement': 2,
#      'points': 129,
#      'competitions_played': 4,
#      'competitor': {'id': 'sr:competitor:46651',
#       'name': 'Melnikova, Marina',
#       'country': 'Neutral',
#       'abbreviation': 'MEL'}},
#     {'rank': 481,
#      'movement': 2,
#      'points': 129,
#      'competitions_played': 15,
#      'competitor': {'id': 'sr:competitor:827398',
#       'name': 'Stankovic, Anja',
#       'country': 'Serbia',
#       'country_code': 'SRB',
#       'abbreviation': 'STA'}},
#     {'rank': 482,
#      'movement': 45,
#      'points': 129,
#      'competitions_played': 15,
#      'competitor': {'id': 'sr:competitor:849553',
#       'name': 'Yao, Xinxin',
#       'country': 'China',
#       'country_code': 'CHN',
#       'abbreviation': 'YAO'}},
#     {'rank': 483,
#      'movement': 1,
#      'points': 128,
#      'competitions_played': 4,
#      'competitor': {'id': 'sr:competitor:343160',
#       'name': 'Volynets, Katie',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'VOL'}},
#     {'rank': 484,
#      'movement': 1,
#      'points': 128,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:686597',
#       'name': 'Pavlova, Kira',
#       'country': 'Neutral',
#       'abbreviation': 'PAV'}},
#     {'rank': 485,
#      'movement': 1,
#      'points': 128,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:833330',
#       'name': 'Grechkina, Anastasia',
#       'country': 'Neutral',
#       'abbreviation': 'GRE'}},
#     {'rank': 486,
#      'movement': 44,
#      'points': 127,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:494296',
#       'name': 'Steur, Joelle Lilly Sophie',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'STE'}},
#     {'rank': 487,
#      'movement': 0,
#      'points': 127,
#      'competitions_played': 21,
#      'competitor': {'id': 'sr:competitor:447759',
#       'name': 'Katsumi, Nanari',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'KAT'}},
#     {'rank': 488,
#      'movement': 0,
#      'points': 126,
#      'competitions_played': 4,
#      'competitor': {'id': 'sr:competitor:39425',
#       'name': 'Savinykh, Valeria',
#       'country': 'Neutral',
#       'abbreviation': 'SAV'}},
#     {'rank': 489,
#      'movement': 0,
#      'points': 126,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:69964',
#       'name': 'Estable, Julieta Lara',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'EST'}},
#     {'rank': 490,
#      'movement': 0,
#      'points': 126,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:18350',
#       'name': 'Voracova, Renata',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'VOR'}},
#     {'rank': 491,
#      'movement': 3,
#      'points': 126,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:840734',
#       'name': 'Walker, Brandy',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'WAL'}},
#     {'rank': 492,
#      'movement': -1,
#      'points': 125,
#      'competitions_played': 6,
#      'competitor': {'id': 'sr:competitor:60276',
#       'name': 'Podoroska, Nadia',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'POD'}},
#     {'rank': 493,
#      'movement': -1,
#      'points': 125,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:759784',
#       'name': 'El Aouni, Aya',
#       'country': 'Morocco',
#       'country_code': 'MAR',
#       'abbreviation': 'EL'}},
#     {'rank': 494,
#      'movement': -1,
#      'points': 125,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:378226',
#       'name': 'Crawley, Fiona',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'CRA'}},
#     {'rank': 495,
#      'movement': 0,
#      'points': 125,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:262701',
#       'name': 'Hodzic, Mina',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'HOD'}},
#     {'rank': 496,
#      'movement': 1,
#      'points': 124,
#      'competitions_played': 4,
#      'competitor': {'id': 'sr:competitor:32862',
#       'name': 'Diatchenko, Vitalia',
#       'country': 'Neutral',
#       'abbreviation': 'DIA'}},
#     {'rank': 497,
#      'movement': -38,
#      'points': 124,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:230108',
#       'name': 'McGiffin, Tenika',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'MCG'}},
#     {'rank': 498,
#      'movement': 0,
#      'points': 124,
#      'competitions_played': 15,
#      'competitor': {'id': 'sr:competitor:720627',
#       'name': 'Senic, Natalija',
#       'country': 'Serbia',
#       'country_code': 'SRB',
#       'abbreviation': 'SEN'}},
#     {'rank': 499,
#      'movement': 0,
#      'points': 124,
#      'competitions_played': 21,
#      'competitor': {'id': 'sr:competitor:360054',
#       'name': 'Allen, Kolie',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'ALL'}},
#     {'rank': 500,
#      'movement': 4,
#      'points': 123,
#      'competitions_played': 5,
#      'competitor': {'id': 'sr:competitor:90814',
#       'name': 'Teichmann, Jil',
#       'country': 'Switzerland',
#       'country_code': 'CHE',
#       'abbreviation': 'TEI'}},
#     {'rank': 501,
#      'movement': -1,
#      'points': 123,
#      'competitions_played': 17,
#      'competitor': {'id': 'sr:competitor:299308',
#       'name': 'Smith, Tina Nadine',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'SMI'}}]}]}

# %%
rank=[]
movement=[]
point=[]
competitions_played=[]
competitor_id=[]

# %%
for i in data3['rankings']:
    for j in i.get('competitor_rankings',[]):
        rank.append(j.get('rank',None))
        movement.append(j.get('movement',None))
        point.append(j.get('points',None))
        competitions_played.append(j.get('competitions_played',None))
        competitor = j.get('competitor', {}) 
        competitor_id.append(competitor.get('id', None).split(':')[-1])
        #

# %%
data3_dict={'rank':rank,
            'movement':movement,
            'point':point,
            'competitions_played':competitions_played,
            'competitor_id':competitor_id}

# %%
Competitor_Rankings =pd.DataFrame(data3_dict)

# %%
Competitor_Rankings
# Out:
#      rank  movement  point  competitions_played competitor_id
# 0       1         0   7530                   22         49363
# 1       1         0   7530                   22         51836
# 2       3         0   7075                   30        637970
# 3       4         0   7055                   28         14898
# 4       5         0   6475                   21         87690
# ..    ...       ...    ...                  ...           ...
# 995   497       -38    124                   14        230108
# 996   498         0    124                   15        720627
# 997   499         0    124                   21        360054
# 998   500         4    123                    5         90814
# 999   501        -1    123                   17        299308
#
# [1000 rows x 5 columns]

# %%
data3
# Out:
# {'generated_at': '2025-02-05T11:35:41+00:00',
#  'rankings': [{'type_id': 2,
#    'name': 'ATP',
#    'year': 2025,
#    'week': 6,
#    'gender': 'men',
#    'competitor_rankings': [{'rank': 1,
#      'movement': 0,
#      'points': 7530,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:49363',
#       'name': 'Pavic, Mate',
#       'country': 'Croatia',
#       'country_code': 'HRV',
#       'abbreviation': 'PAV'}},
#     {'rank': 1,
#      'movement': 0,
#      'points': 7530,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:51836',
#       'name': 'Arevalo-Gonzalez, Marcelo',
#       'country': 'El Salvador',
#       'country_code': 'SLV',
#       'abbreviation': 'ARE'}},
#     {'rank': 3,
#      'movement': 0,
#      'points': 7075,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:637970',
#       'name': 'Patten, Henry',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'PAT'}},
#     {'rank': 4,
#      'movement': 0,
#      'points': 7055,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:14898',
#       'name': 'Heliovaara, Harri',
#       'country': 'Finland',
#       'country_code': 'FIN',
#       'abbreviation': 'HEL'}},
#     {'rank': 5,
#      'movement': 0,
#      'points': 6475,
#      'competitions_played': 21,
#      'competitor': {'id': 'sr:competitor:87690',
#       'name': 'Thompson, Jordan',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'THO'}},
#     {'rank': 6,
#      'movement': 0,
#      'points': 6240,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:36593',
#       'name': 'Krawietz, Kevin',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'KRA'}},
#     {'rank': 7,
#      'movement': 0,
#      'points': 6170,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:15568',
#       'name': 'Granollers, Marcel',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'GRA'}},
#     {'rank': 7,
#      'movement': 0,
#      'points': 6170,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:16160',
#       'name': 'Zeballos, Horacio',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'ZEB'}},
#     {'rank': 9,
#      'movement': 0,
#      'points': 6150,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:52293',
#       'name': 'Putz, Tim',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'PUT'}},
#     {'rank': 10,
#      'movement': 0,
#      'points': 5990,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:15310',
#       'name': 'Bolelli, Simone',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'BOL'}},
#     {'rank': 11,
#      'movement': 0,
#      'points': 5990,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:95801',
#       'name': 'Vavassori, Andrea',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'VAV'}},
#     {'rank': 12,
#      'movement': 0,
#      'points': 5750,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:16608',
#       'name': 'Mektic, Nikola',
#       'country': 'Croatia',
#       'country_code': 'HRV',
#       'abbreviation': 'MEK'}},
#     {'rank': 13,
#      'movement': 0,
#      'points': 5550,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:124658',
#       'name': 'Purcell, Max',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'PUR'}},
#     {'rank': 14,
#      'movement': 0,
#      'points': 5545,
#      'competitions_played': 21,
#      'competitor': {'id': 'sr:competitor:50954',
#       'name': 'Koolhof, Wesley',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'KOO'}},
#     {'rank': 15,
#      'movement': 0,
#      'points': 4025,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:16151',
#       'name': 'Venus, Michael',
#       'country': 'New Zealand',
#       'country_code': 'NZL',
#       'abbreviation': 'VEN'}},
#     {'rank': 16,
#      'movement': 0,
#      'points': 3580,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:53785',
#       'name': 'Skupski, Neal',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'SKU'}},
#     {'rank': 17,
#      'movement': 0,
#      'points': 3230,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:55989',
#       'name': 'Withrow, Jackson',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'WIT'}},
#     {'rank': 17,
#      'movement': 0,
#      'points': 3230,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:210736',
#       'name': 'Lammons, Nathaniel',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'LAM'}},
#     {'rank': 19,
#      'movement': 0,
#      'points': 3120,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:59131',
#       'name': 'Glasspool, Lloyd',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'GLA'}},
#     {'rank': 20,
#      'movement': 0,
#      'points': 3105,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:16409',
#       'name': 'Ebden, Matthew',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'EBD'}},
#     {'rank': 21,
#      'movement': 0,
#      'points': 3000,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:15307',
#       'name': 'Bopanna, Rohan',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'BRO'}},
#     {'rank': 22,
#      'movement': 0,
#      'points': 2970,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:38181',
#       'name': 'Molteni, Andres',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'MOL'}},
#     {'rank': 23,
#      'movement': 1,
#      'points': 2875,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:108099',
#       'name': 'Cash, Julian',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'CAS'}},
#     {'rank': 24,
#      'movement': 1,
#      'points': 2870,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:52202',
#       'name': 'Nys, Hugo',
#       'country': 'Monaco',
#       'country_code': 'MCO',
#       'abbreviation': 'NYS'}},
#     {'rank': 25,
#      'movement': 1,
#      'points': 2800,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:47834',
#       'name': 'Murray, Jamie',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'MUR'}},
#     {'rank': 26,
#      'movement': 1,
#      'points': 2790,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:15548',
#       'name': 'Gonzalez, Maximo',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'GON'}},
#     {'rank': 27,
#      'movement': 1,
#      'points': 2760,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:16275',
#       'name': 'Dodig, Ivan',
#       'country': 'Croatia',
#       'country_code': 'HRV',
#       'abbreviation': 'DOD'}},
#     {'rank': 28,
#      'movement': -5,
#      'points': 2750,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:106349',
#       'name': 'Reboul, Fabien',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'REB'}},
#     {'rank': 29,
#      'movement': 0,
#      'points': 2630,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:206889',
#       'name': 'Galloway, Robert',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'GAL'}},
#     {'rank': 30,
#      'movement': 0,
#      'points': 2600,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:112805',
#       'name': 'Zielinski, Jan',
#       'country': 'Poland',
#       'country_code': 'POL',
#       'abbreviation': 'ZIE'}},
#     {'rank': 31,
#      'movement': 0,
#      'points': 2595,
#      'competitions_played': 23,
#      'competitor': {'id': 'sr:competitor:14553',
#       'name': 'Ram, Rajeev',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'RAM'}},
#     {'rank': 32,
#      'movement': 0,
#      'points': 2550,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:14835',
#       'name': 'Roger-Vasselin, Edouard',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'ROG'}},
#     {'rank': 33,
#      'movement': 1,
#      'points': 2485,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:81059',
#       'name': 'Gille, Sander',
#       'country': 'Belgium',
#       'country_code': 'BEL',
#       'abbreviation': 'GIL'}},
#     {'rank': 34,
#      'movement': 1,
#      'points': 2445,
#      'competitions_played': 31,
#      'competitor': {'id': 'sr:competitor:56629',
#       'name': 'Peers, John',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'PEE'}},
#     {'rank': 35,
#      'movement': 1,
#      'points': 2440,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:104917',
#       'name': 'Vliegen, Joran',
#       'country': 'Belgium',
#       'country_code': 'BEL',
#       'abbreviation': 'VLI'}},
#     {'rank': 36,
#      'movement': -3,
#      'points': 2415,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:106559',
#       'name': 'Doumbia, Sadio',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'DOU'}},
#     {'rank': 37,
#      'movement': 0,
#      'points': 2325,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:59324',
#       'name': 'Pavlasek, Adam',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'PAV'}},
#     {'rank': 38,
#      'movement': 0,
#      'points': 2302,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:76263',
#       'name': 'Matos, Rafael',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'MAT'}},
#     {'rank': 39,
#      'movement': 0,
#      'points': 2295,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:16124',
#       'name': 'Melo, Marcelo',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'MEL'}},
#     {'rank': 40,
#      'movement': 0,
#      'points': 2190,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:230186',
#       'name': 'Verbeek, Sem',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'VER'}},
#     {'rank': 41,
#      'movement': 0,
#      'points': 2160,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:25189',
#       'name': 'Krajicek, Austin',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'KRA'}},
#     {'rank': 42,
#      'movement': 0,
#      'points': 2152,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:114831',
#       'name': 'Erler, Alexander',
#       'country': 'Austria',
#       'country_code': 'AUT',
#       'abbreviation': 'ERL'}},
#     {'rank': 43,
#      'movement': 0,
#      'points': 2130,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:74173',
#       'name': 'Salisbury, Joe',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'SAL'}},
#     {'rank': 44,
#      'movement': 0,
#      'points': 2038,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:78793',
#       'name': 'Miedler, Lucas',
#       'country': 'Austria',
#       'country_code': 'AUT',
#       'abbreviation': 'MIE'}},
#     {'rank': 45,
#      'movement': 1,
#      'points': 1931,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:45105',
#       'name': 'Behar, Ariel',
#       'country': 'Uruguay',
#       'country_code': 'URY',
#       'abbreviation': 'BEH'}},
#     {'rank': 46,
#      'movement': 1,
#      'points': 1895,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:22967',
#       'name': 'Bhambri, Yuki',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'BHA'}},
#     {'rank': 47,
#      'movement': 1,
#      'points': 1895,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:70348',
#       'name': 'Goransson, Andre',
#       'country': 'Sweden',
#       'country_code': 'SWE',
#       'abbreviation': 'GOR'}},
#     {'rank': 48,
#      'movement': 1,
#      'points': 1890,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:15305',
#       'name': 'Gonzalez, Santiago',
#       'country': 'Mexico',
#       'country_code': 'MEX',
#       'abbreviation': 'GON'}},
#     {'rank': 49,
#      'movement': -4,
#      'points': 1835,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:47966',
#       'name': 'Olivetti, Albano',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'OLI'}},
#     {'rank': 50,
#      'movement': 1,
#      'points': 1770,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:48646',
#       'name': 'Barrientos, Nicolas',
#       'country': 'Colombia',
#       'country_code': 'COL',
#       'abbreviation': 'BAR'}},
#     {'rank': 51,
#      'movement': -1,
#      'points': 1765,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:66864',
#       'name': 'Arends, Sander',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'ARE'}},
#     {'rank': 52,
#      'movement': 1,
#      'points': 1718,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:62410',
#       'name': 'Johnson, Luke',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'JOH'}},
#     {'rank': 53,
#      'movement': -1,
#      'points': 1680,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:15588',
#       'name': 'Rojer, Jean-Julien',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'ROJ'}},
#     {'rank': 54,
#      'movement': 0,
#      'points': 1606,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:108755',
#       'name': 'Jebens, Hendrik',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'JEB'}},
#     {'rank': 54,
#      'movement': 0,
#      'points': 1606,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:231188',
#       'name': 'Frantzen, Constantin',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'FRA'}},
#     {'rank': 56,
#      'movement': 0,
#      'points': 1580,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:69362',
#       'name': 'Mansouri, Skander',
#       'country': 'Tunisia',
#       'country_code': 'TUN',
#       'abbreviation': 'MAN'}},
#     {'rank': 57,
#      'movement': 0,
#      'points': 1575,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:47295',
#       'name': 'Andreozzi, Guido',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'AND'}},
#     {'rank': 58,
#      'movement': 0,
#      'points': 1467,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:49306',
#       'name': 'Reyes-Varela, Miguel',
#       'country': 'Mexico',
#       'country_code': 'MEX',
#       'abbreviation': 'REY'}},
#     {'rank': 59,
#      'movement': 2,
#      'points': 1460,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:81763',
#       'name': 'Jacq, Gregoire',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'JAC'}},
#     {'rank': 60,
#      'movement': 3,
#      'points': 1435,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:111195',
#       'name': 'Luz, Orlando',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'LUZ'}},
#     {'rank': 61,
#      'movement': -2,
#      'points': 1419,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:127646',
#       'name': 'Cabral, Francisco',
#       'country': 'Portugal',
#       'country_code': 'PRT',
#       'abbreviation': 'CAB'}},
#     {'rank': 62,
#      'movement': -2,
#      'points': 1401,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:25457',
#       'name': 'Nedovyesov, Aleksandr',
#       'country': 'Kazakhstan',
#       'country_code': 'KAZ',
#       'abbreviation': 'NED'}},
#     {'rank': 63,
#      'movement': -1,
#      'points': 1380,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:16198',
#       'name': 'Escobar, Gonzalo',
#       'country': 'Ecuador',
#       'country_code': 'ECU',
#       'abbreviation': 'ESC'}},
#     {'rank': 64,
#      'movement': 6,
#      'points': 1366,
#      'competitions_played': 31,
#      'competitor': {'id': 'sr:competitor:16042',
#       'name': 'Haase, Robin',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'HAA'}},
#     {'rank': 65,
#      'movement': -1,
#      'points': 1316,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:52244',
#       'name': 'Balaji, N. Sriram',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'BAL'}},
#     {'rank': 66,
#      'movement': -1,
#      'points': 1310,
#      'competitions_played': 43,
#      'competitor': {'id': 'sr:competitor:231090',
#       'name': 'Arribage, Theo',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'ARR'}},
#     {'rank': 67,
#      'movement': -1,
#      'points': 1285,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:300540',
#       'name': 'Machac, Tomas',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'MAC'}},
#     {'rank': 68,
#      'movement': -1,
#      'points': 1270,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:203681',
#       'name': 'Korda, Sebastian',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'KOR'}},
#     {'rank': 69,
#      'movement': -1,
#      'points': 1270,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:104421',
#       'name': 'Mies, Andreas',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'MIE'}},
#     {'rank': 70,
#      'movement': 4,
#      'points': 1266,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:121182',
#       'name': 'Guinard, Manuel',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'GUI'}},
#     {'rank': 71,
#      'movement': -2,
#      'points': 1240,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:75813',
#       'name': 'Zhang, Zhizhen',
#       'country': 'China',
#       'country_code': 'CHN',
#       'abbreviation': 'ZHA'}},
#     {'rank': 72,
#      'movement': -1,
#      'points': 1190,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:41475',
#       'name': 'Arneodo, Romain',
#       'country': 'Monaco',
#       'country_code': 'MCO',
#       'abbreviation': 'ARN'}},
#     {'rank': 73,
#      'movement': -1,
#      'points': 1185,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:17038',
#       'name': 'Smith, John-Patrick',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'SMI'}},
#     {'rank': 74,
#      'movement': 1,
#      'points': 1155,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:152900',
#       'name': 'Rikl, Patrik',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'RIK'}},
#     {'rank': 75,
#      'movement': 4,
#      'points': 1132,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:918463',
#       'name': 'Bollipalli, Rithvik Choudary',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'BOL'}},
#     {'rank': 76,
#      'movement': 4,
#      'points': 1130,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:16043',
#       'name': 'Middelkoop, Matwe',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'MID'}},
#     {'rank': 77,
#      'movement': -1,
#      'points': 1120,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:52065',
#       'name': 'Harrison, Christian',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'HAR'}},
#     {'rank': 78,
#      'movement': 3,
#      'points': 1118,
#      'competitions_played': 38,
#      'competitor': {'id': 'sr:competitor:23899',
#       'name': 'King, Evan',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'KIN'}},
#     {'rank': 79,
#      'movement': -6,
#      'points': 1112,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:204781',
#       'name': 'Nouza, Petr',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'NOU'}},
#     {'rank': 80,
#      'movement': -3,
#      'points': 1103,
#      'competitions_played': 41,
#      'competitor': {'id': 'sr:competitor:112969',
#       'name': 'Schnaitter, Jakob',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'SCH'}},
#     {'rank': 80,
#      'movement': -3,
#      'points': 1103,
#      'competitions_played': 41,
#      'competitor': {'id': 'sr:competitor:936355',
#       'name': 'Wallner, Mark',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'WAL'}},
#     {'rank': 82,
#      'movement': 0,
#      'points': 1056,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:287215',
#       'name': 'Seggerman, Ryan',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'SEG'}},
#     {'rank': 83,
#      'movement': 0,
#      'points': 1042,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:76361',
#       'name': 'Kadhe, Arjun',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'KAD'}},
#     {'rank': 84,
#      'movement': 0,
#      'points': 1039,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:223868',
#       'name': 'Matuszewski, Piotr',
#       'country': 'Poland',
#       'country_code': 'POL',
#       'abbreviation': 'MAT'}},
#     {'rank': 85,
#      'movement': 0,
#      'points': 1035,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:52263',
#       'name': 'Hidalgo, Diego',
#       'country': 'Ecuador',
#       'country_code': 'ECU',
#       'abbreviation': 'HID'}},
#     {'rank': 86,
#      'movement': 0,
#      'points': 1030,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:63438',
#       'name': 'McDonald, Mackenzie',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'MCD'}},
#     {'rank': 87,
#      'movement': 1,
#      'points': 1016,
#      'competitions_played': 39,
#      'competitor': {'id': 'sr:competitor:147104',
#       'name': 'Romios, Matthew Christopher',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'ROM'}},
#     {'rank': 88,
#      'movement': -1,
#      'points': 968,
#      'competitions_played': 39,
#      'competitor': {'id': 'sr:competitor:77653',
#       'name': 'Cornea, Victor',
#       'country': 'Romania',
#       'country_code': 'ROU',
#       'abbreviation': 'COR'}},
#     {'rank': 89,
#      'movement': 0,
#      'points': 960,
#      'competitions_played': 7,
#      'competitor': {'id': 'sr:competitor:57163',
#       'name': 'Zverev, Alexander',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'ZVE'}},
#     {'rank': 90,
#      'movement': 14,
#      'points': 920,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:122368',
#       'name': 'Griekspoor, Tallon',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'GRI'}},
#     {'rank': 91,
#      'movement': -1,
#      'points': 915,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:871495',
#       'name': 'Michelsen, Alex',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'MIC'}},
#     {'rank': 92,
#      'movement': -1,
#      'points': 901,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:197678',
#       'name': 'Tsitsipas, Petros',
#       'country': 'Greece',
#       'country_code': 'GRC',
#       'abbreviation': 'TSI'}},
#     {'rank': 93,
#      'movement': 12,
#      'points': 898,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:234124',
#       'name': 'Stevens, Bart',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'STE'}},
#     {'rank': 94,
#      'movement': -1,
#      'points': 898,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:73572',
#       'name': 'Zormann, Marcelo',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'ZOR'}},
#     {'rank': 95,
#      'movement': 2,
#      'points': 885,
#      'competitions_played': 40,
#      'competitor': {'id': 'sr:competitor:16823',
#       'name': 'Romboli, Fernando',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'ROM'}},
#     {'rank': 96,
#      'movement': -2,
#      'points': 882,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:16492',
#       'name': 'Eysseric, Jonathan',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'EYS'}},
#     {'rank': 97,
#      'movement': -2,
#      'points': 878,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:1020797',
#       'name': 'Trhac, Patrik',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'TRH'}},
#     {'rank': 98,
#      'movement': -6,
#      'points': 877,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:16992',
#       'name': 'Willis, Marcus',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'WIL'}},
#     {'rank': 99,
#      'movement': -3,
#      'points': 855,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:808628',
#       'name': 'Shelton, Ben',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'SHE'}},
#     {'rank': 100,
#      'movement': -2,
#      'points': 847,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:299130',
#       'name': 'Hijikata, Rinky',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'HIJ'}},
#     {'rank': 101,
#      'movement': -2,
#      'points': 841,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:121032',
#       'name': 'Stalder, Reese',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'STA'}},
#     {'rank': 102,
#      'movement': -2,
#      'points': 834,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:60920',
#       'name': 'Nedunchezhiyan, Jeevan',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'NED'}},
#     {'rank': 103,
#      'movement': -2,
#      'points': 830,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:98413',
#       'name': 'Drzewiecki, Karol',
#       'country': 'Poland',
#       'country_code': 'POL',
#       'abbreviation': 'DRZ'}},
#     {'rank': 104,
#      'movement': 42,
#      'points': 820,
#      'competitions_played': 5,
#      'competitor': {'id': 'sr:competitor:102339',
#       'name': 'Van de Zandschulp, Botic',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'VAN'}},
#     {'rank': 105,
#      'movement': -3,
#      'points': 789,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:113221',
#       'name': 'Niklas-Salminen, Patrik',
#       'country': 'Finland',
#       'country_code': 'FIN',
#       'abbreviation': 'NIK'}},
#     {'rank': 106,
#      'movement': 0,
#      'points': 760,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:102151',
#       'name': 'Tabilo, Alejandro',
#       'country': 'Chile',
#       'country_code': 'CHL',
#       'abbreviation': 'TAB'}},
#     {'rank': 107,
#      'movement': 2,
#      'points': 757,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:50037',
#       'name': 'Bortolotti, Marco',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'BOR'}},
#     {'rank': 108,
#      'movement': 0,
#      'points': 742,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:16854',
#       'name': 'Molchanov, Denys',
#       'country': 'Ukraine',
#       'country_code': 'UKR',
#       'abbreviation': 'MOL'}},
#     {'rank': 109,
#      'movement': 17,
#      'points': 740,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:838776',
#       'name': 'Tracy, James',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'TRA'}},
#     {'rank': 110,
#      'movement': 1,
#      'points': 739,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:157396',
#       'name': 'Veldheer, Mick',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'VEL'}},
#     {'rank': 111,
#      'movement': 1,
#      'points': 732,
#      'competitions_played': 18,
#      'competitor': {'id': 'sr:competitor:35766',
#       'name': 'Begemann, Andre',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'BEG'}},
#     {'rank': 112,
#      'movement': 1,
#      'points': 730,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:263917',
#       'name': 'Draxl, Liam',
#       'country': 'Canada',
#       'country_code': 'CAN',
#       'abbreviation': 'DRA'}},
#     {'rank': 113,
#      'movement': 11,
#      'points': 729,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:16573',
#       'name': 'Demoliner, Marcelo',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'DEM'}},
#     {'rank': 114,
#      'movement': 0,
#      'points': 726,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:119150',
#       'name': 'Fancutt, Thomas',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'FAN'}},
#     {'rank': 115,
#      'movement': 0,
#      'points': 720,
#      'competitions_played': 15,
#      'competitor': {'id': 'sr:competitor:163480',
#       'name': 'Bublik, Alexander',
#       'country': 'Kazakhstan',
#       'country_code': 'KAZ',
#       'abbreviation': 'BUB'}},
#     {'rank': 116,
#      'movement': -6,
#      'points': 717,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:77011',
#       'name': 'Martos Gornes, Sergio',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'MAR'}},
#     {'rank': 117,
#      'movement': -1,
#      'points': 706,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:145936',
#       'name': 'Kaliyanda Poonacha, Niki',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'KAL'}},
#     {'rank': 118,
#      'movement': -15,
#      'points': 705,
#      'competitions_played': 18,
#      'competitor': {'id': 'sr:competitor:39712',
#       'name': 'Saville, Luke',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'SAV'}},
#     {'rank': 119,
#      'movement': 21,
#      'points': 702,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:52951',
#       'name': 'Pel, David',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'PEL'}},
#     {'rank': 120,
#      'movement': -3,
#      'points': 701,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:37637',
#       'name': 'Zeballos, Federico',
#       'country': 'Bolivia',
#       'country_code': 'BOL',
#       'abbreviation': 'ZEB'}},
#     {'rank': 120,
#      'movement': -3,
#      'points': 701,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:54609',
#       'name': 'Arias, Boris',
#       'country': 'Bolivia',
#       'country_code': 'BOL',
#       'abbreviation': 'ARI'}},
#     {'rank': 122,
#      'movement': -3,
#      'points': 695,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:53759',
#       'name': 'Prashanth, N. Vijay Sundar',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'PRA'}},
#     {'rank': 123,
#      'movement': -2,
#      'points': 684,
#      'competitions_played': 23,
#      'competitor': {'id': 'sr:competitor:305776',
#       'name': 'Soto, Matias',
#       'country': 'Chile',
#       'country_code': 'CHL',
#       'abbreviation': 'SOT'}},
#     {'rank': 124,
#      'movement': 17,
#      'points': 684,
#      'competitions_played': 28,
#      'competitor': {'id': 'sr:competitor:243522',
#       'name': 'Paul, Jakub',
#       'country': 'Switzerland',
#       'country_code': 'CHE',
#       'abbreviation': 'PAU'}},
#     {'rank': 125,
#      'movement': 14,
#      'points': 681,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:393598',
#       'name': 'Cash, Robert',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'CAS'}},
#     {'rank': 126,
#      'movement': -4,
#      'points': 676,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:42151',
#       'name': 'Nam, Ji Sung',
#       'country': 'Republic of Korea',
#       'country_code': 'KOR',
#       'abbreviation': 'NAM'}},
#     {'rank': 127,
#      'movement': -4,
#      'points': 675,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:90080',
#       'name': 'Khachanov, Karen',
#       'country': 'Neutral',
#       'abbreviation': 'KHA'}},
#     {'rank': 128,
#      'movement': -3,
#      'points': 669,
#      'competitions_played': 39,
#      'competitor': {'id': 'sr:competitor:256001',
#       'name': 'Ho, Ray',
#       'country': 'Chinese Taipei',
#       'country_code': 'TPE',
#       'abbreviation': 'RAY'}},
#     {'rank': 129,
#      'movement': 2,
#      'points': 663,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:209202',
#       'name': 'Chandrasekar, Anirudh',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'CHA'}},
#     {'rank': 130,
#      'movement': -3,
#      'points': 659,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:69910',
#       'name': 'Bergevi, Filip',
#       'country': 'Sweden',
#       'country_code': 'SWE',
#       'abbreviation': 'BER'}},
#     {'rank': 131,
#      'movement': -3,
#      'points': 652,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:450383',
#       'name': 'Harper, Cleeve',
#       'country': 'Canada',
#       'country_code': 'CAN',
#       'abbreviation': 'HAR'}},
#     {'rank': 132,
#      'movement': -3,
#      'points': 650,
#      'competitions_played': 2,
#      'competitor': {'id': 'sr:competitor:46391',
#       'name': 'Struff, Jan-Lennard',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'STR'}},
#     {'rank': 133,
#      'movement': -3,
#      'points': 648,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:296270',
#       'name': 'Stevenson, David',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'STE'}},
#     {'rank': 134,
#      'movement': -14,
#      'points': 641,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:405977',
#       'name': 'Schoolkate, Tristan',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'SCH'}},
#     {'rank': 135,
#      'movement': -2,
#      'points': 640,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:14508',
#       'name': 'Mahut, Nicolas',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'MAH'}},
#     {'rank': 136,
#      'movement': -2,
#      'points': 630,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:125006',
#       'name': 'Borges, Nuno',
#       'country': 'Portugal',
#       'country_code': 'PRT',
#       'abbreviation': 'BOR'}},
#     {'rank': 137,
#      'movement': -1,
#      'points': 620,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:25458',
#       'name': 'Martinez, Luis David',
#       'country': 'Venezuela',
#       'country_code': 'VEN',
#       'abbreviation': 'MAR'}},
#     {'rank': 138,
#      'movement': 4,
#      'points': 618,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:234044',
#       'name': 'Kirkov, Vasil',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'KIR'}},
#     {'rank': 139,
#      'movement': -4,
#      'points': 618,
#      'competitions_played': 31,
#      'competitor': {'id': 'sr:competitor:111607',
#       'name': 'Ingildsen, Johannes',
#       'country': 'Denmark',
#       'country_code': 'DNK',
#       'abbreviation': 'ING'}},
#     {'rank': 140,
#      'movement': 12,
#      'points': 616,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:95923',
#       'name': 'Paris, Joshua',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'PAR'}},
#     {'rank': 141,
#      'movement': -34,
#      'points': 610,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:47760',
#       'name': 'Weissborn, Tristan-Samuel',
#       'country': 'Austria',
#       'country_code': 'AUT',
#       'abbreviation': 'WEI'}},
#     {'rank': 142,
#      'movement': -5,
#      'points': 609,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:44637',
#       'name': 'Rodriguez, Cristian',
#       'country': 'Colombia',
#       'country_code': 'COL',
#       'abbreviation': 'ROC'}},
#     {'rank': 143,
#      'movement': 0,
#      'points': 596,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:58877',
#       'name': 'Ramanathan, Ramkumar',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'RAM'}},
#     {'rank': 144,
#      'movement': 1,
#      'points': 592,
#      'competitions_played': 29,
#      'competitor': {'id': 'sr:competitor:240880',
#       'name': 'Hilderbrand, Trey',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'HIL'}},
#     {'rank': 145,
#      'movement': -13,
#      'points': 591,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:134610',
#       'name': 'Blumberg, William',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'BLU'}},
#     {'rank': 146,
#      'movement': 2,
#      'points': 580,
#      'competitions_played': 27,
#      'competitor': {'id': 'sr:competitor:78387',
#       'name': 'Hach Verdugo, Hans',
#       'country': 'Mexico',
#       'country_code': 'MEX',
#       'abbreviation': 'HAC'}},
#     {'rank': 147,
#      'movement': -3,
#      'points': 579,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:548169',
#       'name': 'Yuzuki, Takeru',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'YUZ'}},
#     {'rank': 148,
#      'movement': 3,
#      'points': 575,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:119140',
#       'name': 'Ellis, Blake',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'ELL'}},
#     {'rank': 149,
#      'movement': -2,
#      'points': 566,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:15809',
#       'name': 'Martin, Fabrice',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'MAR'}},
#     {'rank': 150,
#      'movement': 0,
#      'points': 563,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:113889',
#       'name': 'Liutarevich, Ivan',
#       'country': 'Neutral',
#       'abbreviation': 'LIU'}},
#     {'rank': 151,
#      'movement': -13,
#      'points': 548,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:92845',
#       'name': 'Goldhoff, George',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'GOL'}},
#     {'rank': 152,
#      'movement': 1,
#      'points': 538,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:146040',
#       'name': 'Gomez, Federico Agustin',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'GOM'}},
#     {'rank': 153,
#      'movement': 2,
#      'points': 536,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:124708',
#       'name': 'Cukierman, Daniel',
#       'country': 'Israel',
#       'country_code': 'ISR',
#       'abbreviation': 'CUK'}},
#     {'rank': 154,
#      'movement': 2,
#      'points': 530,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:195458',
#       'name': 'Added, Dan',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'ADD'}},
#     {'rank': 155,
#      'movement': -1,
#      'points': 529,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:110707',
#       'name': 'Pichler, David',
#       'country': 'Austria',
#       'country_code': 'AUT',
#       'abbreviation': 'PIC'}},
#     {'rank': 156,
#      'movement': -7,
#      'points': 528,
#      'competitions_played': 36,
#      'competitor': {'id': 'sr:competitor:52260',
#       'name': 'Vega, David',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'VEG'}},
#     {'rank': 157,
#      'movement': 0,
#      'points': 525,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:58989',
#       'name': 'Sabanov, Matej',
#       'country': 'Serbia',
#       'country_code': 'SRB',
#       'abbreviation': 'SAB'}},
#     {'rank': 158,
#      'movement': 0,
#      'points': 525,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:98981',
#       'name': 'Jecan, Alexandru',
#       'country': 'Romania',
#       'country_code': 'ROU',
#       'abbreviation': 'JEC'}},
#     {'rank': 159,
#      'movement': 7,
#      'points': 511,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:216502',
#       'name': 'Broom, Charles',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'BRO'}},
#     {'rank': 160,
#      'movement': 1,
#      'points': 511,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:96859',
#       'name': 'Lock, Benjamin',
#       'country': 'Zimbabwe',
#       'country_code': 'ZWE',
#       'abbreviation': 'LOC'}},
#     {'rank': 161,
#      'movement': 1,
#      'points': 510,
#      'competitions_played': 23,
#      'competitor': {'id': 'sr:competitor:25021',
#       'name': 'Cervantes, Inigo',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'CER'}},
#     {'rank': 162,
#      'movement': 1,
#      'points': 501,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:280601',
#       'name': 'Oberleitner, Neil',
#       'country': 'Austria',
#       'country_code': 'AUT',
#       'abbreviation': 'OBE'}},
#     {'rank': 163,
#      'movement': 1,
#      'points': 500,
#      'competitions_played': 34,
#      'competitor': {'id': 'sr:competitor:145008',
#       'name': 'Uesugi, Kaito',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'UES'}},
#     {'rank': 164,
#      'movement': 1,
#      'points': 495,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:122366',
#       'name': 'Tsitsipas, Stefanos',
#       'country': 'Greece',
#       'country_code': 'GRC',
#       'abbreviation': 'TSI'}},
#     {'rank': 165,
#      'movement': 15,
#      'points': 495,
#      'competitions_played': 23,
#      'competitor': {'id': 'sr:competitor:141882',
#       'name': 'Blancaneaux, Geoffrey',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'BLA'}},
#     {'rank': 166,
#      'movement': 2,
#      'points': 492,
#      'competitions_played': 37,
#      'competitor': {'id': 'sr:competitor:112061',
#       'name': 'Walkow, Szymon',
#       'country': 'Poland',
#       'country_code': 'POL',
#       'abbreviation': 'WAL'}},
#     {'rank': 167,
#      'movement': 2,
#      'points': 490,
#      'competitions_played': 32,
#      'competitor': {'id': 'sr:competitor:297448',
#       'name': 'Kiger, Mac',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'KIG'}},
#     {'rank': 168,
#      'movement': -9,
#      'points': 483,
#      'competitions_played': 33,
#      'competitor': {'id': 'sr:competitor:297502',
#       'name': 'Bayldon, Blake',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'BAY'}},
#     {'rank': 169,
#      'movement': 1,
#      'points': 480,
#      'competitions_played': 5,
#      'competitor': {'id': 'sr:competitor:136042',
#       'name': 'Fritz, Taylor',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'FRI'}},
#     {'rank': 170,
#      'movement': -3,
#      'points': 472,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:227358',
#       'name': 'Walton, Adam',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'WAL'}},
#     {'rank': 171,
#      'movement': 11,
#      'points': 468,
#      'competitions_played': 35,
#      'competitor': {'id': 'sr:competitor:84671',
#       'name': 'Britto, Luis',
#       'country': 'Brazil',
#       'country_code': 'BRA',
#       'abbreviation': 'BRI'}},
#     {'rank': 172,
#      'movement': 2,
#      'points': 462,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:15275',
#       'name': 'Matsui, Toshihide',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'MAT'}},
#     {'rank': 173,
#      'movement': -1,
#      'points': 461,
#      'competitions_played': 30,
#      'competitor': {'id': 'sr:competitor:390480',
#       'name': 'Watanabe, Seita',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'WAT'}},
#     {'rank': 174,
#      'movement': 21,
#      'points': 457,
#      'competitions_played': 18,
#      'competitor': {'id': 'sr:competitor:295508',
#       'name': 'Vrbensky, Michael',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'VRB'}},
#     {'rank': 175,
#      'movement': -2,
#      'points': 457,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:204495',
#       'name': 'Vocel, Matej',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'VOC'}},
#     {'rank': 176,
#      'movement': 15,
#      'points': 456,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:380004',
#       'name': 'Harper, Patrick',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'HAR'}},
#     {'rank': 177,
#      'movement': -17,
#      'points': 453,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:342826',
#       'name': 'Trotter, James Kent',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'TRO'}},
#     {'rank': 178,
#      'movement': -3,
#      'points': 453,
#      'competitions_played': 18,
#      'competitor': {'id': 'sr:competitor:250231',
#       'name': 'Shimizu, Yuta',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'SHI'}},
#     {'rank': 179,
#      'movement': -3,
#      'points': 449,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:59700',
#       'name': 'Isaro, Pruchya',
#       'country': 'Thailand',
#       'country_code': 'THA',
#       'abbreviation': 'ISA'}},
#     {'rank': 180,
#      'movement': -3,
#      'points': 443,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:64920',
#       'name': 'Myneni, Saketh',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'MYN'}},
#     {'rank': 181,
#      'movement': 0,
#      'points': 435,
#      'competitions_played': 31,
#      'competitor': {'id': 'sr:competitor:263865',
#       'name': 'Reynolds, Finn',
#       'country': 'New Zealand',
#       'country_code': 'NZL',
#       'abbreviation': 'REY'}},
#     {'rank': 182,
#      'movement': -11,
#      'points': 430,
#      'competitions_played': 20,
#      'competitor': {'id': 'sr:competitor:77223',
#       'name': 'Martinez, Pedro',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'MAR'}},
#     {'rank': 183,
#      'movement': 1,
#      'points': 429,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:628218',
#       'name': 'Karol, Milos',
#       'country': 'Slovakia',
#       'country_code': 'SVK',
#       'abbreviation': 'KAR'}},
#     {'rank': 184,
#      'movement': 2,
#      'points': 425,
# ...
#       'country': 'Neutral',
#       'abbreviation': 'KOV'}},
#     {'rank': 440,
#      'movement': 3,
#      'points': 146,
#      'competitions_played': 25,
#      'competitor': {'id': 'sr:competitor:185412',
#       'name': 'Labrana, Fernanda',
#       'country': 'Chile',
#       'country_code': 'CHL',
#       'abbreviation': 'LAB'}},
#     {'rank': 441,
#      'movement': 28,
#      'points': 146,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:812476',
#       'name': 'Zaytseva, Ksenia',
#       'country': 'Neutral',
#       'abbreviation': 'ZAY'}},
#     {'rank': 442,
#      'movement': 4,
#      'points': 145,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:831262',
#       'name': 'Yamalapalli, Sahaja',
#       'country': 'India',
#       'country_code': 'IND',
#       'abbreviation': 'YAM'}},
#     {'rank': 443,
#      'movement': 2,
#      'points': 145,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:522258',
#       'name': 'Ricci, Beatrice',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'RIC'}},
#     {'rank': 444,
#      'movement': 4,
#      'points': 144,
#      'competitions_played': 6,
#      'competitor': {'id': 'sr:competitor:517296',
#       'name': 'Falei, Aliona',
#       'country': 'Neutral',
#       'abbreviation': 'FAL'}},
#     {'rank': 445,
#      'movement': 5,
#      'points': 143,
#      'competitions_played': 24,
#      'competitor': {'id': 'sr:competitor:171026',
#       'name': 'Tsygourova, Katerina',
#       'country': 'Switzerland',
#       'country_code': 'CHE',
#       'abbreviation': 'TSY'}},
#     {'rank': 446,
#      'movement': 5,
#      'points': 142,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:1027517',
#       'name': 'Ebeling Koning, Loes',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'EBE'}},
#     {'rank': 447,
#      'movement': 5,
#      'points': 142,
#      'competitions_played': 17,
#      'competitor': {'id': 'sr:competitor:341196',
#       'name': 'Back, Dayeon',
#       'country': 'Republic of Korea',
#       'country_code': 'KOR',
#       'abbreviation': 'BAC'}},
#     {'rank': 448,
#      'movement': -1,
#      'points': 142,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:371556',
#       'name': 'Jeong, Boyoung',
#       'country': 'Republic of Korea',
#       'country_code': 'KOR',
#       'abbreviation': 'JEO'}},
#     {'rank': 449,
#      'movement': -50,
#      'points': 141,
#      'competitions_played': 3,
#      'competitor': {'id': 'sr:competitor:499484',
#       'name': 'Montgomery, Robin',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'MON'}},
#     {'rank': 450,
#      'movement': 3,
#      'points': 141,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:380368',
#       'name': 'Sebestova, Ivana',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'SEB'}},
#     {'rank': 451,
#      'movement': 3,
#      'points': 140,
#      'competitions_played': 7,
#      'competitor': {'id': 'sr:competitor:329535',
#       'name': 'Tauson, Clara',
#       'country': 'Denmark',
#       'country_code': 'DNK',
#       'abbreviation': 'TAU'}},
#     {'rank': 452,
#      'movement': -27,
#      'points': 140,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:655811',
#       'name': 'Avdeeva, Julia',
#       'country': 'Neutral',
#       'abbreviation': 'AVD'}},
#     {'rank': 453,
#      'movement': 2,
#      'points': 140,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:88290',
#       'name': 'Bejenaru, Karola Patricia',
#       'country': 'Romania',
#       'country_code': 'ROU',
#       'abbreviation': 'BEJ'}},
#     {'rank': 454,
#      'movement': 2,
#      'points': 140,
#      'competitions_played': 19,
#      'competitor': {'id': 'sr:competitor:522848',
#       'name': 'Rocchetti, Sofia',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'ROC'}},
#     {'rank': 455,
#      'movement': 41,
#      'points': 139,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:98733',
#       'name': 'Burillo Escorihuela, Irene',
#       'country': 'Spain',
#       'country_code': 'ESP',
#       'abbreviation': 'BUR'}},
#     {'rank': 456,
#      'movement': 2,
#      'points': 139,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:906635',
#       'name': 'Shubladze, Alexandra',
#       'country': 'Neutral',
#       'abbreviation': 'SHU'}},
#     {'rank': 457,
#      'movement': 4,
#      'points': 138,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:880229',
#       'name': 'Cayetano, Eryn',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'CAY'}},
#     {'rank': 458,
#      'movement': 4,
#      'points': 138,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:583869',
#       'name': 'Pavlou, Dimitra',
#       'country': 'Greece',
#       'country_code': 'GRC',
#       'abbreviation': 'PAV'}},
#     {'rank': 459,
#      'movement': 4,
#      'points': 138,
#      'competitions_played': 21,
#      'competitor': {'id': 'sr:competitor:96981',
#       'name': 'Xun, Fang Ying',
#       'country': 'China',
#       'country_code': 'CHN',
#       'abbreviation': 'XUN'}},
#     {'rank': 460,
#      'movement': 5,
#      'points': 137,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:52388',
#       'name': 'Hesse, Amandine',
#       'country': 'France',
#       'country_code': 'FRA',
#       'abbreviation': 'HES'}},
#     {'rank': 461,
#      'movement': 3,
#      'points': 137,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:310982',
#       'name': 'Naklo, Thasaporn',
#       'country': 'Thailand',
#       'country_code': 'THA',
#       'abbreviation': 'NAK'}},
#     {'rank': 462,
#      'movement': 39,
#      'points': 137,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:804342',
#       'name': 'Stoiber, Ranah Akua',
#       'country': 'Great Britain',
#       'country_code': 'GBR',
#       'abbreviation': 'STO'}},
#     {'rank': 463,
#      'movement': 3,
#      'points': 137,
#      'competitions_played': 23,
#      'competitor': {'id': 'sr:competitor:111149',
#       'name': 'Samir, Sandra',
#       'country': 'Egypt',
#       'country_code': 'EGY',
#       'abbreviation': 'SAM'}},
#     {'rank': 464,
#      'movement': 3,
#      'points': 136,
#      'competitions_played': 3,
#      'competitor': {'id': 'sr:competitor:595220',
#       'name': 'Stakusic, Marina',
#       'country': 'Canada',
#       'country_code': 'CAN',
#       'abbreviation': 'STA'}},
#     {'rank': 465,
#      'movement': 3,
#      'points': 136,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:431743',
#       'name': 'Okutoyi, Angella',
#       'country': 'Kenya',
#       'country_code': 'KEN',
#       'abbreviation': 'OKU'}},
#     {'rank': 466,
#      'movement': 4,
#      'points': 136,
#      'competitions_played': 17,
#      'competitor': {'id': 'sr:competitor:476218',
#       'name': 'Kawaguchi, Natsumi',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'KAW'}},
#     {'rank': 467,
#      'movement': 4,
#      'points': 135,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:739667',
#       'name': 'Pedone, Giorgia',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'PED'}},
#     {'rank': 468,
#      'movement': -33,
#      'points': 135,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:569009',
#       'name': 'Ccuno, Romina',
#       'country': 'Peru',
#       'country_code': 'PER',
#       'abbreviation': 'CCU'}},
#     {'rank': 469,
#      'movement': 3,
#      'points': 134,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:342788',
#       'name': 'Curmi, Francesca',
#       'country': 'Malta',
#       'country_code': 'MLT',
#       'abbreviation': 'CUR'}},
#     {'rank': 470,
#      'movement': 3,
#      'points': 133,
#      'competitions_played': 22,
#      'competitor': {'id': 'sr:competitor:265743',
#       'name': 'Burdina, Evgeniya',
#       'country': 'Neutral',
#       'abbreviation': 'BUR'}},
#     {'rank': 471,
#      'movement': 3,
#      'points': 132,
#      'competitions_played': 8,
#      'competitor': {'id': 'sr:competitor:46661',
#       'name': 'Gamiz, Andrea',
#       'country': 'Venezuela',
#       'country_code': 'VEN',
#       'abbreviation': 'GAM'}},
#     {'rank': 472,
#      'movement': -28,
#      'points': 132,
#      'competitions_played': 17,
#      'competitor': {'id': 'sr:competitor:315623',
#       'name': 'Wang, Jiaqi',
#       'country': 'China',
#       'country_code': 'CHN',
#       'abbreviation': 'WAN'}},
#     {'rank': 473,
#      'movement': 2,
#      'points': 132,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:340365',
#       'name': 'Milovanovic, Elena',
#       'country': 'Serbia',
#       'country_code': 'SRB',
#       'abbreviation': 'MIL'}},
#     {'rank': 474,
#      'movement': 7,
#      'points': 132,
#      'competitions_played': 16,
#      'competitor': {'id': 'sr:competitor:858867',
#       'name': 'Pace, Francesca',
#       'country': 'Italy',
#       'country_code': 'ITA',
#       'abbreviation': 'PAC'}},
#     {'rank': 475,
#      'movement': 3,
#      'points': 131,
#      'competitions_played': 2,
#      'competitor': {'id': 'sr:competitor:71034',
#       'name': 'Sramkova, Rebecca',
#       'country': 'Slovakia',
#       'country_code': 'SVK',
#       'abbreviation': 'SRA'}},
#     {'rank': 476,
#      'movement': 0,
#      'points': 131,
#      'competitions_played': 2,
#      'competitor': {'id': 'sr:competitor:19704',
#       'name': 'Martic, Petra',
#       'country': 'Croatia',
#       'country_code': 'HRV',
#       'abbreviation': 'MAR'}},
#     {'rank': 477,
#      'movement': 109,
#      'points': 131,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:264863',
#       'name': 'Novak, Kristina',
#       'country': 'Slovenia',
#       'country_code': 'SVN',
#       'abbreviation': 'NOV'}},
#     {'rank': 478,
#      'movement': -1,
#      'points': 131,
#      'competitions_played': 13,
#      'competitor': {'id': 'sr:competitor:915371',
#       'name': 'van Den Broek, Isis Louise',
#       'country': 'Netherlands',
#       'country_code': 'NLD',
#       'abbreviation': 'VAN'}},
#     {'rank': 479,
#      'movement': 1,
#      'points': 130,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:784280',
#       'name': 'Prozorova, Tatiana',
#       'country': 'Neutral',
#       'abbreviation': 'PRO'}},
#     {'rank': 480,
#      'movement': 2,
#      'points': 129,
#      'competitions_played': 4,
#      'competitor': {'id': 'sr:competitor:46651',
#       'name': 'Melnikova, Marina',
#       'country': 'Neutral',
#       'abbreviation': 'MEL'}},
#     {'rank': 481,
#      'movement': 2,
#      'points': 129,
#      'competitions_played': 15,
#      'competitor': {'id': 'sr:competitor:827398',
#       'name': 'Stankovic, Anja',
#       'country': 'Serbia',
#       'country_code': 'SRB',
#       'abbreviation': 'STA'}},
#     {'rank': 482,
#      'movement': 45,
#      'points': 129,
#      'competitions_played': 15,
#      'competitor': {'id': 'sr:competitor:849553',
#       'name': 'Yao, Xinxin',
#       'country': 'China',
#       'country_code': 'CHN',
#       'abbreviation': 'YAO'}},
#     {'rank': 483,
#      'movement': 1,
#      'points': 128,
#      'competitions_played': 4,
#      'competitor': {'id': 'sr:competitor:343160',
#       'name': 'Volynets, Katie',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'VOL'}},
#     {'rank': 484,
#      'movement': 1,
#      'points': 128,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:686597',
#       'name': 'Pavlova, Kira',
#       'country': 'Neutral',
#       'abbreviation': 'PAV'}},
#     {'rank': 485,
#      'movement': 1,
#      'points': 128,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:833330',
#       'name': 'Grechkina, Anastasia',
#       'country': 'Neutral',
#       'abbreviation': 'GRE'}},
#     {'rank': 486,
#      'movement': 44,
#      'points': 127,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:494296',
#       'name': 'Steur, Joelle Lilly Sophie',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'STE'}},
#     {'rank': 487,
#      'movement': 0,
#      'points': 127,
#      'competitions_played': 21,
#      'competitor': {'id': 'sr:competitor:447759',
#       'name': 'Katsumi, Nanari',
#       'country': 'Japan',
#       'country_code': 'JPN',
#       'abbreviation': 'KAT'}},
#     {'rank': 488,
#      'movement': 0,
#      'points': 126,
#      'competitions_played': 4,
#      'competitor': {'id': 'sr:competitor:39425',
#       'name': 'Savinykh, Valeria',
#       'country': 'Neutral',
#       'abbreviation': 'SAV'}},
#     {'rank': 489,
#      'movement': 0,
#      'points': 126,
#      'competitions_played': 26,
#      'competitor': {'id': 'sr:competitor:69964',
#       'name': 'Estable, Julieta Lara',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'EST'}},
#     {'rank': 490,
#      'movement': 0,
#      'points': 126,
#      'competitions_played': 9,
#      'competitor': {'id': 'sr:competitor:18350',
#       'name': 'Voracova, Renata',
#       'country': 'Czechia',
#       'country_code': 'CZE',
#       'abbreviation': 'VOR'}},
#     {'rank': 491,
#      'movement': 3,
#      'points': 126,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:840734',
#       'name': 'Walker, Brandy',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'WAL'}},
#     {'rank': 492,
#      'movement': -1,
#      'points': 125,
#      'competitions_played': 6,
#      'competitor': {'id': 'sr:competitor:60276',
#       'name': 'Podoroska, Nadia',
#       'country': 'Argentina',
#       'country_code': 'ARG',
#       'abbreviation': 'POD'}},
#     {'rank': 493,
#      'movement': -1,
#      'points': 125,
#      'competitions_played': 11,
#      'competitor': {'id': 'sr:competitor:759784',
#       'name': 'El Aouni, Aya',
#       'country': 'Morocco',
#       'country_code': 'MAR',
#       'abbreviation': 'EL'}},
#     {'rank': 494,
#      'movement': -1,
#      'points': 125,
#      'competitions_played': 10,
#      'competitor': {'id': 'sr:competitor:378226',
#       'name': 'Crawley, Fiona',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'CRA'}},
#     {'rank': 495,
#      'movement': 0,
#      'points': 125,
#      'competitions_played': 12,
#      'competitor': {'id': 'sr:competitor:262701',
#       'name': 'Hodzic, Mina',
#       'country': 'Germany',
#       'country_code': 'DEU',
#       'abbreviation': 'HOD'}},
#     {'rank': 496,
#      'movement': 1,
#      'points': 124,
#      'competitions_played': 4,
#      'competitor': {'id': 'sr:competitor:32862',
#       'name': 'Diatchenko, Vitalia',
#       'country': 'Neutral',
#       'abbreviation': 'DIA'}},
#     {'rank': 497,
#      'movement': -38,
#      'points': 124,
#      'competitions_played': 14,
#      'competitor': {'id': 'sr:competitor:230108',
#       'name': 'McGiffin, Tenika',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'MCG'}},
#     {'rank': 498,
#      'movement': 0,
#      'points': 124,
#      'competitions_played': 15,
#      'competitor': {'id': 'sr:competitor:720627',
#       'name': 'Senic, Natalija',
#       'country': 'Serbia',
#       'country_code': 'SRB',
#       'abbreviation': 'SEN'}},
#     {'rank': 499,
#      'movement': 0,
#      'points': 124,
#      'competitions_played': 21,
#      'competitor': {'id': 'sr:competitor:360054',
#       'name': 'Allen, Kolie',
#       'country': 'USA',
#       'country_code': 'USA',
#       'abbreviation': 'ALL'}},
#     {'rank': 500,
#      'movement': 4,
#      'points': 123,
#      'competitions_played': 5,
#      'competitor': {'id': 'sr:competitor:90814',
#       'name': 'Teichmann, Jil',
#       'country': 'Switzerland',
#       'country_code': 'CHE',
#       'abbreviation': 'TEI'}},
#     {'rank': 501,
#      'movement': -1,
#      'points': 123,
#      'competitions_played': 17,
#      'competitor': {'id': 'sr:competitor:299308',
#       'name': 'Smith, Tina Nadine',
#       'country': 'Australia',
#       'country_code': 'AUS',
#       'abbreviation': 'SMI'}}]}]}

# %%
Competitor_Rankings.to_sql('competitor_rankings_table',engine,if_exists='replace',index=False)
# Out:
# 1000

# %%
competitor_id=[]
name=[]
country=[]
country_code=[]
abbreviation=[]

# %%
for i in data3['rankings']:
    for j in i.get('competitor_rankings',[]):
        competitor=j.get('competitor',{})
        #competitor_id.append(competitor.get('id'))
        competitor_id.append(competitor.get('id').split(':')[-1])

        name.append(competitor.get('name'))
        #point.append(competitor.get('points'))
        country.append(competitor.get('country'))
        country_code.append(competitor.get('country_code'))
        abbreviation.append(competitor.get('abbreviation'))

# %%
data3_dcit2={'competitor_id':competitor_id,
             'name':name,
             'country':country,
             
             'country_code':country_code,
             'abbreviation':abbreviation}

# %%
Competitors =pd.DataFrame(data3_dcit2)

# %%
df_c_t=Competitors.drop_duplicates(subset='competitor_id')

# %%
df_c_t.to_sql('competitors_table',engine,if_exists='replace',index=False)
# Out:
# 1000
